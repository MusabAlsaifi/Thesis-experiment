# %%
token = "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"
repo_url = f"https://{token}@github.com/MusabAlsaifi/Thesis-experiment.git"
# !git clone {repo_url}
# Out:
# Cloning into 'Thesis-experiment'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.

# %%
# !ls drive
# Out:
# MyDrive

# %%
# !mv /content/drive/MyDrive/Colab\ Notebooks/therapeutic-chatbot-experiments.ipynb /content/Thesis-experiment/
# Out:
# mv: cannot stat '/content/drive/MyDrive/ColabNotebooks/therapeutic-chatbot-experiments.ipynb': No such file or directory

# %% [markdown]
# # Introduction
#
# This notebook is divided into three sections:
# ##1. [Fine-tuning with OpenAI](https://colab.research.google.com/drive/1gIt7gWAyFBqYy6L3yGVlF6jzws6Zjcmt#scrollTo=Zsn1wkUqCa-Q)
# - Fine-tuning GPT-4o-mini with a train and test dataset.
# ### **Train dataset:**
# Contains transcripts from therapy session collected from books and podcasts. \
#
# - **Book:** https://anamartinspsicoterapiaacp.wordpress.com/wp-content/uploads/2016/04/brodley-transcripts-of-carl-rogers-therapy-sessions.pdf \
# The pdf book is then converted to a json format using gpt and langchain, refer to the repo: \
# The json file is then converted to jsonl format
# - **Podcast 1:** https://podcasts.apple.com/pl/podcast/other-peoples-problems/id1355059144
# - **Podcast 2:** https://podcasts.apple.com/pl/podcast/where-should-we-begin-with-esther-perel/id1237931798 \
# For both Podcasts, the transcripts are extracted manually to pdf then to json and jsonl, using the repo mentioned above.
# ### **Test dataset:**
# This dataset is from the huggingface, it contains question-answer pairs related to mental health
# - https://huggingface.co/datasets/Amod/mental_health_counseling_conversations
# #####**Example:**
# { \
#     "Context":"How can I get to a place where I can be content from day to day?",\
#     "Response":"It's important to take a look inside and see what's going on with you to cause you to have these feelings. Please contact us in whatever way is most comfortable for you and we can get you set up with someone who will help you figure out this space in your life." \
# }
#
# ---
# ##2. [Evaluation with Langsmith](https://colab.research.google.com/drive/1gIt7gWAyFBqYy6L3yGVlF6jzws6Zjcmt#scrollTo=fT1mHMpuCsum)
# - The Evaluation method is ***llm-as-a-judge***. \
# Basically, we use a superior llm e.g. GPT-4o, to evaluate the responses of our fine-tuned model on a certain criteria and to comapre the response of our model against other models as what is called ***pairwise evaluation***.
#
# ### **Test dataset:**
# This dataset is from the huggingface, it contains question-answer pairs related to mental health
# - https://huggingface.co/datasets/Amod/mental_health_counseling_conversations
# #####**Example:**
# { \
#     "Context":"How can I get to a place where I can be content from day to day?",\
#     "Response":"It's important to take a look inside and see what's going on with you to cause you to have these feelings. Please contact us in whatever way is most comfortable for you and we can get you set up with someone who will help you figure out this space in your life." \
# }
#
# The dataset is uploaded to the langsmith UI as a csv file and only the `Context` is used.
#
# ### **The Evaluation Process:**
# 1. We feed the dataset to our fine-tuned model and the model that we want to evaluate agianst.
# 2. The response generated from each model are fed to the llm judge to evaluate them based on certian criteria.
# 3. The response generated from both models are fed to the llm judge to campare them againt each other on a certain criteria and score. The resonse that got the hiegher score is considerd to be better.
#
# ---
# ## 3. [Generate Synthatic Data](https://colab.research.google.com/drive/1gIt7gWAyFBqYy6L3yGVlF6jzws6Zjcmt#scrollTo=0SayI_xn646J&line=13&uniqifier=1)
# Here we use GPT-4o to answer questions from the dataset: \
# https://huggingface.co/datasets/Amod/mental_health_counseling_conversations
# #####Then use the generated data to fine-tune our model.

# %% [markdown]
# # env

# %%
# !pip install python-dotenv
# Out:
# Collecting python-dotenv
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.0.1

# %%
# Create .env file
# !touch '/content/drive/MyDrive/.env'

# %%
import dotenv
from google.colab import drive

drive.mount('/content/drive')

dotenv.load_dotenv('/content/drive/MyDrive/.env')
# Out:
# Mounted at /content/drive
# True

# %% [markdown]
# Using magic cell to append keys to .env file

# %%
# %%writefile -a /content/drive/MyDrive/.env
# LANGCHAIN_PROJECT_2=""

# %%
OPENAI_API_KEY="sk-a-elBhoqxmYCIAgNGbCQ7yC-Wx8jIqr3Geqd2F54w7T3BlbkFJNnJFQUTx6iW7OTshTuaTn19XagVC2wFvNnioS5AkAA"

#### The name of the fine-tuned model
FT_MODEL="ft:gpt-4o-mini-2024-07-18:personal:second-ft:A3g9cAiE"

# %%
import os

os.environ["LANGCHAIN_TRACING_V2"]="true"
os.environ["LANGCHAIN_ENDPOINT"]="https://api.smith.langchain.com"
os.environ["LANGCHAIN_PROJECT"]="agents"
OPENAI_API_KEY = os.environ.get("OPENAI_API_KEY")
GROQ_API_KEY = os.environ.get("GROQ_API_KEY")
FT_MODEL = os.environ.get("FT_MODEL")
# LANGSMITH_API_KEY = os.environ.get("LANGSMITH_API_KEY")
# LLAMA_CLOUD_API_KEY = os.environ.get("LLAMA_CLOUD_API_KEY")
# TOGETHERAI_API_KEY = os.environ.get("TOGETHERAI_API_KEY")
# NGROK_AUTH_TOKEN = os.environ.get("NGROK_AUTH_TOKEN")

# %% [markdown]
# # Fine-tuing OpenAI

# %% [markdown]
# ## Setup

# %%
# !pip install openai
# Out:
# Collecting openai
#   Downloading openai-1.51.1-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai)
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting jiter<1,>=0.4.0 (from openai)
#   Downloading jiter-0.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.2 kB)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.9.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.5)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.10/dist-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.8.30)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai)
#   Downloading httpcore-1.0.6-py3-none-any.whl.metadata (21 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.23.4)
# Downloading openai-1.51.1-py3-none-any.whl (383 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.7/383.7 kB 13.5 MB/s eta 0:00:00
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 6.0 MB/s eta 0:00:00
# Downloading httpcore-1.0.6-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.0/78.0 kB 4.8 MB/s eta 0:00:00
# Downloading jiter-0.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (325 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.2/325.2 kB 20.0 MB/s eta 0:00:00
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.4 MB/s eta 0:00:00
# Installing collected packages: jiter, h11, httpcore, httpx, openai
# Successfully installed h11-0.14.0 httpcore-1.0.6 httpx-0.27.2 jiter-0.6.1 openai-1.51.1

# %%
from openai import OpenAI

openai_client = OpenAI(api_key=OPENAI_API_KEY)

# %% [markdown]
# ## Read the train and test jsonl files

# %%
# Read train.jsonl file
with open("./train3.jsonl", "rb") as file:
    train_file_response = openai_client.files.create(
        file=file,
        purpose="fine-tune"
    )

# Read test.jsonl file
with open("./test3.jsonl", "rb") as file:
    test_file_response = openai_client.files.create(
        file=file,
        purpose="fine-tune"
    )

# Get files ID
train_file_id = train_file_response.id
test_file_id = test_file_response.id
print(f"Train file ID: {train_file_id}")
print(f"Test file ID: {test_file_id}")
# Out:
# Train file ID: file-8fkeVEymr7XkH6TUhQ80JgxP
# Test file ID: file-a73HDtZhBXaX9y1VqeI8vuPc

# %%
train_file_id = "file-cUyocipEtcr7pTRb2KSZ6yds"
# test_file_id = "file-a73HDtZhBXaX9y1VqeI8vuPc"

# %% [markdown]
# ## Create fine-tuing job

# %%
import time

response = openai_client.fine_tuning.jobs.create(
    training_file=train_file_id,
    # validation_file=test_file_id,
    hyperparameters={
        "n_epochs": 17,
        "learning_rate_multiplier": 0.2,
        "batch_size": 5
        },
    model="gpt-4o-mini-2024-07-18",
)

job_id = response.id
curr_status = response.status
print(f"Job ID: {job_id}")
print(f"Initial status: {curr_status}")

# Loop to continuously check the status
while True:
    # Fetch the latest status of the job
    job_response = openai_client.fine_tuning.jobs.retrieve(job_id)
    new_status = job_response.status

    # Check if the job has completed or failed
    if new_status == "succeeded":
        print("Job created successfully")
        print(f"Fine-tuned model: {job_response.fine_tuned_model}")
        break
    elif new_status == "failed":
        print("Job failed")
        break

    # If the status has changed, print the new status
    if new_status != curr_status:
        print(f"Updated status: {new_status}...")
        curr_status = new_status

    # Wait for 120 seconds before checking the status again
    time.sleep(120)
# Out:
# Job ID: ftjob-LkvllGo0wFVpGvPftx1QAEaY
# Initial status: validating_files
# Updated status: running...
# Job created successfully
# Fine-tuned model: ft:gpt-4o-mini-2024-07-18:personal::AG3pnRc4

# %% [markdown]
# # Evaluation with Langsmith

# %% [markdown]
# ## Setup

# %%
# !pip install -U langchain langchain_openai langsmith openai langgraph langchain_groq langchain_community
# Out:
# Collecting langchain
#   Downloading langchain-0.3.3-py3-none-any.whl.metadata (7.1 kB)
# Collecting langchain_openai
#   Downloading langchain_openai-0.2.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting langsmith
#   Downloading langsmith-0.1.135-py3-none-any.whl.metadata (13 kB)
# Collecting openai
#   Downloading openai-1.51.2-py3-none-any.whl.metadata (24 kB)
# Collecting langgraph
#   Downloading langgraph-0.2.37-py3-none-any.whl.metadata (13 kB)
# Collecting langchain_groq
#   Downloading langchain_groq-0.2.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting langchain_community
#   Downloading langchain_community-0.3.2-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.0.35)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (3.10.10)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (4.0.3)
# Collecting langchain-core<0.4.0,>=0.3.10 (from langchain)
#   Downloading langchain_core-0.3.10-py3-none-any.whl.metadata (6.3 kB)
# Collecting langchain-text-splitters<0.4.0,>=0.3.0 (from langchain)
#   Downloading langchain_text_splitters-0.3.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.9.2)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.32.3)
# Collecting tenacity!=8.4.0,<9.0.0,>=8.1.0 (from langchain)
#   Downloading tenacity-8.5.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting tiktoken<1,>=0.7 (from langchain_openai)
#   Downloading tiktoken-0.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting httpx<1,>=0.23.0 (from langsmith)
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith)
#   Downloading orjson-3.10.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 3.7 MB/s eta 0:00:00
# Collecting requests-toolbelt<2.0.0,>=1.0.0 (from langsmith)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Collecting jiter<1,>=0.4.0 (from openai)
#   Downloading jiter-0.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.2 kB)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.5)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.10/dist-packages (from openai) (4.12.2)
# Collecting langgraph-checkpoint<3.0.0,>=2.0.0 (from langgraph)
#   Downloading langgraph_checkpoint-2.0.1-py3-none-any.whl.metadata (4.6 kB)
# Collecting langgraph-sdk<0.2.0,>=0.1.32 (from langgraph)
#   Downloading langgraph_sdk-0.1.33-py3-none-any.whl.metadata (1.8 kB)
# Collecting groq<1,>=0.4.1 (from langchain_groq)
#   Downloading groq-0.11.0-py3-none-any.whl.metadata (13 kB)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain_community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain_community)
#   Downloading pydantic_settings-2.5.2-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.14.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain_community)
#   Downloading marshmallow-3.22.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain_community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith) (2024.8.30)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->langsmith)
#   Downloading httpcore-1.0.6-py3-none-any.whl.metadata (21 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->langsmith)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<0.4.0,>=0.3.10->langchain)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.10->langchain) (24.1)
# Collecting msgpack<2.0.0,>=1.1.0 (from langgraph-checkpoint<3.0.0,>=2.0.0->langgraph)
#   Downloading msgpack-1.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.4 kB)
# Collecting httpx-sse>=0.4.0 (from langgraph-sdk<0.2.0,>=0.1.32->langgraph)
#   Downloading httpx_sse-0.4.0-py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.23.4)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain_community) (1.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2.2.3)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken<1,>=0.7->langchain_openai) (2024.9.11)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.10->langchain)
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.3->langchain) (0.2.0)
# Downloading langchain-0.3.3-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 15.9 MB/s eta 0:00:00
# Downloading langchain_openai-0.2.2-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 kB 5.5 MB/s eta 0:00:00
# Downloading langsmith-0.1.135-py3-none-any.whl (295 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.8/295.8 kB 28.6 MB/s eta 0:00:00
# Downloading openai-1.51.2-py3-none-any.whl (383 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.7/383.7 kB 27.7 MB/s eta 0:00:00
# Downloading langgraph-0.2.37-py3-none-any.whl (112 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.7/112.7 kB 12.3 MB/s eta 0:00:00
# Downloading langchain_groq-0.2.0-py3-none-any.whl (14 kB)
# Downloading langchain_community-0.3.2-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 58.8 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading groq-0.11.0-py3-none-any.whl (106 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.5/106.5 kB 11.1 MB/s eta 0:00:00
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 7.8 MB/s eta 0:00:00
# Downloading httpcore-1.0.6-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.0/78.0 kB 8.5 MB/s eta 0:00:00
# Downloading jiter-0.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (325 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.2/325.2 kB 28.8 MB/s eta 0:00:00
# Downloading langchain_core-0.3.10-py3-none-any.whl (404 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.4/404.4 kB 34.4 MB/s eta 0:00:00
# Downloading langchain_text_splitters-0.3.0-py3-none-any.whl (25 kB)
# Downloading langgraph_checkpoint-2.0.1-py3-none-any.whl (22 kB)
# Downloading langgraph_sdk-0.1.33-py3-none-any.whl (28 kB)
# Downloading orjson-3.10.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (141 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 14.3 MB/s eta 0:00:00
# Downloading pydantic_settings-2.5.2-py3-none-any.whl (26 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 5.2 MB/s eta 0:00:00
# Downloading tenacity-8.5.0-py3-none-any.whl (28 kB)
# Downloading tiktoken-0.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 60.4 MB/s eta 0:00:00
# Downloading httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading marshmallow-3.22.0-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 4.9 MB/s eta 0:00:00
# Downloading msgpack-1.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (378 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 378.0/378.0 kB 28.8 MB/s eta 0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.1 MB/s eta 0:00:00
# Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: tenacity, orjson, mypy-extensions, msgpack, marshmallow, jsonpointer, jiter, httpx-sse, h11, typing-inspect, tiktoken, requests-toolbelt, jsonpatch, httpcore, pydantic-settings, httpx, dataclasses-json, openai, langsmith, langgraph-sdk, groq, langchain-core, langgraph-checkpoint, langchain-text-splitters, langchain_openai, langchain_groq, langgraph, langchain, langchain_community
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 9.0.0
#     Uninstalling tenacity-9.0.0:
#       Successfully uninstalled tenacity-9.0.0
#   Attempting uninstall: msgpack
#     Found existing installation: msgpack 1.0.8
#     Uninstalling msgpack-1.0.8:
#       Successfully uninstalled msgpack-1.0.8
# Successfully installed dataclasses-json-0.6.7 groq-0.11.0 h11-0.14.0 httpcore-1.0.6 httpx-0.27.2 httpx-sse-0.4.0 jiter-0.6.1 jsonpatch-1.33 jsonpointer-3.0.0 langchain-0.3.3 langchain-core-0.3.10 langchain-text-splitters-0.3.0 langchain_community-0.3.2 langchain_groq-0.2.0 langchain_openai-0.2.2 langgraph-0.2.37 langgraph-checkpoint-2.0.1 langgraph-sdk-0.1.33 langsmith-0.1.135 marshmallow-3.22.0 msgpack-1.1.0 mypy-extensions-1.0.0 openai-1.51.2 orjson-3.10.7 pydantic-settings-2.5.2 requests-toolbelt-1.0.0 tenacity-8.5.0 tiktoken-0.8.0 typing-inspect-0.9.0

# %% [markdown]
# ## Class to create OpenAI models

# %%
from openai import OpenAI
from langchain_openai import ChatOpenAI
from langsmith.schemas import Example
from langchain.prompts import ChatPromptTemplate
from langchain.schema.output_parser import StrOutputParser

class CreateApp:
    """
    Class to create OpenAI models
    Args:
        client (OpenAI): OpenAI client
        model (str): Model name
        prompt (str): Prompt to use
    """
    def __init__(self, client, model, prompt):
        self.client = client
        self.model = model
        self.prompt = prompt

    def predict(self, example: Example) -> dict:
        """
        Generates a prediction based on the provided example.
        """
        chat = ChatOpenAI(model_name=self.model)
        res = self.prompt | chat | StrOutputParser()
        response = res.invoke({"input": example["Context"]})
        return {"answer": response}

# %% [markdown]
# ### Groq model

# %%
from langchain_groq import ChatGroq

model = 'llama3-8b-8192'

groq_chat = ChatGroq(
        groq_api_key=GROQ_API_KEY,
        model_name=model
)

# %% [markdown]
# ## Models' prompt

# %%
sys_prompt = """
You are a compassionate and professional therapist in a virtual therapy session.
Your goal is to provide empathetic support, active listening, and elaborating
with questions or thoughts and evidence-based guidance to help the client navigate their emotions,
thoughts, and challenges.
Your first response should assure the user that you're here for them and that
you understand what they are going through.
Remember to keep the conversation engaging and maintain a warm and non-judgmental tone throughout the conversation.
"""

# %% [markdown]
# Critical Skills
#
# These are essential for a response to be valid if one is missing from the response, then the response is not valid:
#
# (1) Empathy: Show understanding and compassion for the individual’s emotions and experiences, recognizing their feelings genuinely.
#
# (2) Emotional Validation: Acknowledge and affirm the emotions expressed by the individual, letting them know their feelings are valid and heard.
#
# (3) Client-Centered Approach: Focus on the individual’s perspective, encouraging them to lead the conversation and engage in self-exploration.
#
# (4) Supportiveness: Provide reassurance and create a safe, non-judgmental space where the individual feels comfortable expressing themselves openly.
#
# (5) Professional Tone: Maintain a professional, respectful, and appropriate tone that suits the context of therapy or support.
#
# (6) Active Listening and Observation: Demonstrate attentive listening by reflecting or paraphrasing the individual’s key points to show understanding.
#
# (7) Crisis Management: Recognize and address any signs of emotional distress or potential crises appropriately, providing immediate support if needed.
#
# (8) Non-Judgmental Attitude: Maintain an open, non-judgmental tone that avoids criticism or assumptions, fostering a trusting environment.
#
# (9) Flexibility: Being adaptable to different situations and client needs can improve the effectiveness of therapy.
#
# (10) Questioning:
#
# - Open questions: Invite elaboration and encourage deeper exploration (e.g., “How does that make you feel?”).
# - Closed questions: Seek specific answers (e.g., “Does that make you angry?”).
#
# (11) Unconditional Positive Regard: Make the client feel accepted for who they are, bringing warmth and respect into the session and encouraging openness.
#
# (12) Reflection and Mirroring: Reflect the client’s words, emotions, or experiences to deepen understanding and encourage self-reflection, helping them feel understood and validated.
#
# Valuable Skills
#
# These add value but are not critical for the response:
#
# (1) Depth of Exploration: Encourage the individual to delve deeper into their emotions and thoughts, helping them explore the root causes of their feelings.
#
# (2) Clarity and Coherence: Ensure the response is clear, easy to understand, and structured, avoiding confusion or overly complex language.
#
# (3) Tailored Feedback: Offer personalized responses that address the individual’s specific situation, avoiding generic or one-size-fits-all advice.
#
# (4) Cultural Sensitivity: Show awareness and respect for the individual’s cultural background, beliefs, and values, avoiding assumptions or biases.
#
# (5) Encouragement of Autonomy: Empower the individual to make their own decisions, fostering self-reliance and self-direction.
#
# (6) Reflection and Mirroring: Reflect the individual’s emotions and thoughts back to them, helping them feel understood and validated.
#
# (7) Positive Reinforcement: Acknowledge and encourage positive behaviors, thoughts, or progress expressed by the individual, boosting their confidence.
#
# (8) Therapeutic Pacing: Ensure the conversation moves at a comfortable pace for the individual, giving them time to process emotions without feeling rushed.
#
# (9) Reflective Summarization: Summarize the key points of the individual’s thoughts or feelings to ensure clarity and mutual understanding.
#
# (10) Collaboration: Promote a collaborative approach where the individual feels they are working with the therapist to explore solutions and insights.
#
# (11) Consistency: Ensure the response aligns with previous therapeutic goals and approaches, avoiding contradictions or mixed messages.
#
# (12) Use of Evidence-Based Techniques: Incorporate established therapeutic methods (e.g., cognitive-behavioral therapy, mindfulness) in a way that suits the individual’s needs.
#
# (13) Humor: Appropriate use of humor can help in building rapport and making clients feel more comfortable.

# %%
new_prompt = """
You are a compassionate and professional therapist in a virtual therapy session. The user will be sharing with you feelings and problems that they are going or went through.

Use the following step-by-step for your response:

Step 1 - Analyse the client's language level and concerns carefully before answering.

Step 2 - Your goal is to provide responses that should meet the following criteria:

(1) Empathy: Show understanding and compassion for the individual’s emotions and experiences, recognizing their feelings genuinely.
(2) Emotional Validation: Acknowledge and affirm the emotions expressed by the individual, letting them know their feelings are valid and heard.
(3) Client-Centered Approach: Focus on the individual’s perspective, encouraging them to lead the conversation and engage in self-exploration.
(4) Depth of Exploration: Encourage the individual to delve deeper into their emotions and thoughts, helping them explore the root causes of their feelings.
(5) Supportiveness: Provide reassurance and create a safe, non-judgmental space where the individual feels comfortable expressing themselves openly.
(6) Professional Tone: Maintain a professional, respectful, and appropriate tone that suits the context of therapy or support.
(7) Active Listening: Demonstrate attentive listening by reflecting or paraphrasing the individual’s key points to show understanding.
(8) Clarity and Coherence: Ensure the response is clear, easy to understand, and structured, avoiding confusion or overly complex language.
(9) Tailored Feedback: Offer personalized responses that address the individual’s specific situation, avoiding generic or one-size-fits-all advice.
(10) Cultural Sensitivity: Show awareness and respect for the individual’s cultural background, beliefs, and values, avoiding assumptions or biases.
(11) Encouragement of Autonomy: Empower the individual to make their own decisions, fostering self-reliance and self-direction.
(12) Crisis Management: Recognize and address any signs of emotional distress or potential crises appropriately, providing immediate support if needed.
(13) Reflection and Mirroring: Reflect the individual’s emotions and thoughts back to them, helping them feel understood and validated.
(14) Positive Reinforcement: Acknowledge and encourage positive behaviors, thoughts, or progress expressed by the individual, boosting their confidence.
(15) Open-Ended Questions: Use open-ended questions to invite deeper exploration of feelings and thoughts, allowing for more meaningful reflection.
(16) Non-Judgmental Attitude: Maintain an open, non-judgmental tone that avoids criticism or assumptions, fostering a trusting environment.
(17) Therapeutic Pacing: Ensure the conversation moves at a comfortable pace for the individual, giving them time to process emotions without feeling rushed.
(18) Reflective Summarization: Summarize the key points of the individual’s thoughts or feelings to ensure clarity and mutual understanding.
(19) Collaboration: Promote a collaborative approach where the individual feels they are working with the therapist to explore solutions and insights.
(20) Consistency: Ensure the response aligns with previous therapeutic goals and approaches, avoiding contradictions or mixed messages.
(21) Use of Evidence-Based Techniques: Incorporate established therapeutic methods (e.g., cognitive-behavioral therapy, mindfulness) in a way that suits the individual’s needs.

Step 3 -  Focus on the following points:
1- Your first response should assure the user that you're here for them and that you understand what they are going through.
2- Remember to keep the conversation engaging and maintain a warm and non-judgmental tone throughout the conversation.
3- Try to find out why is the client feeling this way? how did the client end up in this situation?what is the real cause of the problem?

Step 4 - Analyse your response and make sure that the response meets the criteria in Step 2 and 3.


"""

# %% [markdown]
# ## Evaluators
# The prompts used are forked from langchain-ai/pairwise-evaluation-2
# ####1. **Evaluate each model individually**
# #####Prompt used: musabalsaifi/individual-evaluation-prompt
# ####2. **Evaluate two models**
# #####Prompt used: musabalsaifi/evaluator-prompt

# %% [markdown]
# ---
#
# *   List item
# *   List item
#
#
# ###Evaluation Criteria
# The reponses are evaluated based on the following criteria:
#
# 1. **Empathy**: Does the response demonstrate understanding and compassion for the individual’s feelings and experiences?
#
# 2. **Emotional Validation**: To what extent does the response acknowledge and validate the emotions expressed by the individual?
#
# 3. **Client-Centered Approach**: How effectively does the response prioritize the individual’s perspective, encouraging self-exploration and allowing the individual to guide the conversation?
#
# 4. **Depth of Exploration**: How well does the response encourage the individual to explore their emotions and thoughts more deeply?
#
# 5. **Supportiveness**: Does the response offer reassurance and create a safe, non-judgmental space for the individual to express themselves?
#
# 6. **Professional Tone**: How professional and appropriate is the tone in the context of a therapeutic or supportive setting?
#
# 7. **Active Listening**: Does the response demonstrate active listening by accurately reflecting or paraphrasing the individual’s key concerns and emotions?
#
# 8. **Clarity and Coherence**: Is the response clear, structured, and easy to understand, avoiding any confusion or ambiguity?
#
# 9. **Tailored Feedback**: Does the response offer personalized feedback based on the individual’s unique circumstances, rather than generalized advice?
#
# 10. **Cultural Sensitivity**: How well does the response show awareness and respect for the individual’s cultural background, values, and beliefs?
#
# 11. **Encouragement of Autonomy**: How effectively does the response empower the individual to make their own decisions and encourage self-direction?
#
# 12. **Crisis Management**: If applicable, does the response identify and appropriately address any signs of emotional distress or potential crisis situations?
#
# 13. **Reflection and Mirroring**: Does the response accurately mirror or reflect the emotions and experiences of the individual to help them feel understood?
#
# 14. **Positive Reinforcement**: How well does the response reinforce positive behaviors, thoughts, or emotions expressed by the individual?
#
# 15. **Open-Ended Questions**: Does the response use open-ended questions to invite deeper self-reflection and exploration?
#
# 16. **Non-Judgmental Attitude**: Does the response maintain a non-judgmental stance, avoiding any criticism or assumptions about the individual’s experiences?
#
# 17. **Therapeutic Pacing**: Does the response maintain an appropriate pace, allowing the individual to process their emotions without feeling rushed or pressured?
#
# 18. **Reflective Summarization**: Does the response provide a concise and accurate summary of the individual’s key points to clarify understanding?
#
# 19. **Collaboration**: How well does the response promote collaboration, working together with the individual to explore solutions or address issues?
#
# 20. **Consistency**: Does the response align with the therapeutic goals and maintain consistency, avoiding contradictions or mixed messages?
#
# 21. **Use of Evidence-Based Techniques**: Does the response incorporate evidence-based therapeutic techniques (e.g., cognitive-behavioral therapy, mindfulness) in a way that is appropriate to the individual’s needs?

# %% [markdown]
# ---
# ### Individual Evaluation

# %%
from langchain import hub
from langsmith.schemas import Example, Run
from langchain_core.prompts import ChatPromptTemplate
from pydantic.v1 import BaseModel, Field

def answer_evaluator(runs: Run, example: Example) -> dict:
    """Evaluate each model individually using gpt-4o"""

    # Input text from the dataset
    input_text = example.inputs["Context"]

    # Output text from the model
    prediction = runs.outputs["answer"]

    # Data model for grade

    class GradeSummary (BaseModel):
        """A numerical score for summary quality."""
        score: int = Field(description="Answer meets criteria, score from 0 to 13")
        feedback: str = Field(description="List the criteria that are not met")


    llm = ChatOpenAI (model="gpt-4o-mini", temperature=0)
    structured_llm_grader = llm.with_structured_output(GradeSummary)
    grade_prompt = hub.pull("musabalsaifi/individual-evaluation-prompt")

    answer_grader = grade_prompt | structured_llm_grader
    score = answer_grader.invoke({"prediction": prediction})

    return {"key": "summary_engagement_score", "score": int(score.score), "feedback": score.feedback}

# %% [markdown]
# ### Pairwise Evaluation

# %%
from langchain import hub
from langsmith.evaluation import evaluate_comparative
from langchain_core.prompts import PromptTemplate
from langsmith.schemas import Run, Example
from langchain_core.output_parsers import StrOutputParser

def evaluate_pairwise(runs: list[Run], example: Example) -> dict:
    """Evaluate and score two models using GPT-4o-mini"""

    scores = {}
    for i, run in enumerate(runs):
        scores[run.id] = i

    answer_a = runs[0].outputs["answer"]
    answer_b = runs[1].outputs["answer"]

    prompt = hub.pull("musabalsaifi/evaluator-prompt")
    llm = ChatOpenAI(model="gpt-4o-mini-2024-07-18", temperature=0)

    runnable = prompt | llm
    response = runnable.invoke({
    "question": sys_prompt,
    "answer_a": answer_a,
    "answer_b": answer_b
    })

    score = response["Preference"]
    feedback = response["Feedback"]
    if score == 1:
        scores[runs[0].id] = 1
        scores[runs[1].id] = 0
    elif score == 2:
        scores[runs[0].id] = 0
        scores[runs[1].id] = 1
    else:
        scores[runs[0].id] = 0
        scores[runs[1].id] = 0

    return {"key": "ranked_preference", "feedback": feedback, "scores": scores}

# %% [markdown]
# ## Agents

# %% [markdown]
# ### Create Agents

# %%
from langchain_core.messages import (
    BaseMessage,
    HumanMessage,
    ToolMessage,
)
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder

from langgraph.graph import END, StateGraph, START


def create_agent(llm, tools, system_message: str):
    """Create an agent."""
    prompt = ChatPromptTemplate.from_messages(
        [
            (
                "system",
                "You are a helpful AI assistant, collaborating with other assistants."
                " Use the provided tools to progress towards answering the question."
                " If you are unable to fully answer, that's OK, another assistant with different tools "
                " will help where you left off. Execute what you can to make progress."
                " DO NOT CALL THE TOOL IF NOT NECCESSRY, IF YOU NEED TO CALL THE TOOL, CALL ONLY ONCE."
                " \n{system_message}", # You have access to the following tools: {tool_names}.
            ),
            MessagesPlaceholder(variable_name="messages"),
        ]
    )
    prompt = prompt.partial(system_message=system_message)
    prompt = prompt.partial(tool_names=", ".join([tool.name for tool in tools]))
    return prompt | llm.bind_tools(tools)

# %% [markdown]
# ### Define tools

# %%
from typing import Annotated

from langchain_core.tools import tool

@tool
def classifier_tool():
    """Use this tool to analyse classify the messaage"""
    return "Return your analysis and classification"

@tool
def generator_tool():
    """"Use this tool to generate a response"""
    return "Return your generated response"
# def generator_tool(
#         categ: Annotated[str, "The category of the mental health problem"],
#         analysis: Annotated[str, "The analysis of the message"],
#         prompt: Annotated[str, "The user's message"]
#         ):
#     """Use this tool to answer based on the analysis, classification and the prompt"""
#     return (
#         f"Analysis: {analysis}"
#         f"\nCategory: {categ}"
#         )

@tool
def humanizer_tool(output: Annotated[str, "The output from the generator_agent"]): # input: Annotated[str, "This the output from the generator_agent"]
    """
    Use this tool to summarize the output {output} generated from the generator_agent in one sentance.
    """
    return "Return your response"

# %% [markdown]
# #### Tool Nodes

# %%
from langgraph.prebuilt import ToolNode

tools = [classifier_tool, generator_tool, humanizer_tool]
tool_node = ToolNode(tools)

# %% [markdown]
# ### Create the graph

# %%
import operator
from typing import Annotated, Sequence, TypedDict
from langchain_openai import ChatOpenAI


# This defines the object that is passed between each node
# in the graph. We will create different nodes for each agent and tool
class AgentState(TypedDict):
    messages: Annotated[Sequence[BaseMessage], operator.add]
    sender: str

# %% [markdown]
# ### Agent Nodes

# %%
import functools

from langchain_core.messages import AIMessage


# Helper function to create a node for a given agent
def agent_node(state, agent, name):
    result = agent.invoke(state)

    # We convert the agent output into a format that is suitable to append to the global state
    if isinstance(result, ToolMessage):
        pass
    # else:
    result = AIMessage(**result.dict(exclude={"type", "name"}), name=name)

    if name == "Generator" and result.content != "":
        # print(f"\nType: {type(result.content)}, Name: {result.content}")
        return {"messages": [result.content], "sender": name,}

    return {
        "messages": [result],
        # Since we have a strict workflow, we can
        # track the sender so we know who to pass to next.
        "sender": name,
    }


llm = groq_chat
openai_llm = llm=ChatOpenAI(model="gpt-4o-mini")
my_model = ChatOpenAI(model="ft:gpt-4o-mini-2024-07-18:personal:second-ft:A3g9cAiE")

# Classifier agent and node
classifier_agent = create_agent(
    openai_llm,
    [classifier_tool],
    system_message="""
    You are a professional classifier.
    Your task is to analyze the input message and classify it into one or more of the mental health-related categories.
    Only respond with analysis and one or more of the categories, nothing else.
    If you have the final answer or deliverable,
    prefix your response with ANALYSED so the team knows the progress.
    """,
)
classifier_node = functools.partial(agent_node, agent=classifier_agent, name="Classifier")

# Generator
generator_agent = create_agent(
    my_model,
    [generator_tool],
    system_message="Prefix you response with ANSWER: " + new_prompt,
)
generator_node = functools.partial(agent_node, agent=generator_agent, name="Generator")

#Humanizer
humanizer_agent = create_agent(
    openai_llm,
    [humanizer_tool],
    system_message="""
    You task is the humanize the output from the generator_agent. DO NOT PROVIDE A NEW RESPONSE TO THE PROMPT.
    ONLY USE THE OUTPUT FROM THE generator_agent AND YOU SHOULD NOT BE CONSARENED ABOUT OTHER DATA.
    Your goal is to make the response feel more empathetic, natural, easy to understand and relatable to a human reader.

	1.	Simplify complex language without losing meaning.
	2.	Use friendly, conversational tones.
	3.	Show empathy when appropriate, especially if discussing sensitive topics.
	4.	Avoid overly technical or robotic language.
	5.	Aim to create a message that sounds as though it was written by a caring human.
    """,
)
humanizer_node = functools.partial(agent_node, agent=humanizer_agent, name="Humanizer")

# %% [markdown]
# ### Routing logic

# %%
from typing import Literal

def router(state) -> Literal["call_tool", "__end__", "continue", "humanize", "ANALYSED"]:
    # This is the router
    messages = state["messages"]
    last_message = messages[-1]
    if "ANSWER" in last_message:
        # The previous agent is generating a response
        # print(f"\nlast message: {last_message}\n")
        return "humanize"
    if last_message.tool_calls:
        # The previous agent is invoking a tool
        return "call_tool"
    if "FINAL ANSWER" in last_message.content:
        # Any agent decided the work is done
        return "__end__"
    return "continue"

# %%
workflow = StateGraph(AgentState)

workflow.add_node("Classifier", classifier_node)
workflow.add_node("Generator", generator_node)
workflow.add_node("Humanizer", humanizer_node)
workflow.add_node("call_tool", tool_node)

# Classifier -> Generator
workflow.add_conditional_edges(
    "Classifier",
    router,
    {"continue": "Generator", "call_tool": "call_tool"},
)

# Generator -> Humanizer
workflow.add_conditional_edges(
    "Generator",
    router,
    {"humanize": "Humanizer", "call_tool": "call_tool"},
)

# Humanizer -> END (final step)
workflow.add_conditional_edges(
    "Humanizer",
    router,
    {"continue": END, "call_tool": "call_tool", "__end__": END},
)

workflow.add_conditional_edges(
    "call_tool",
    # Each agent node updates the 'sender' field
    # the tool calling node does not, meaning
    # this edge will route back to the original agent
    # who invoked the tool
    lambda x: x["sender"],
    {
        "Classifier": "Classifier",
        "Generator": "Generator",
        "Humanizer": "Humanizer"
    },
)
workflow.add_edge(START, "Classifier")
graph = workflow.compile()

# %%
from IPython.display import Image, display

try:
    display(Image(graph.get_graph(xray=True).draw_mermaid_png()))
except Exception:
    # This requires some extra dependencies and is optional
    pass

# %% [markdown]
# ### Run test

# %%
events = graph.stream(
    {
        "messages": [
            HumanMessage(
                content="""
                My fiancé and I come from a strong Christian background but both went off the \"straight and narrow\" once before.
                He is having a hard time accepting my past, especially that I'm not a virgin. He has a hard time in general accepting himself and others.
                His insecurities are hurting our relationship. How can I help him let go of my past and decide to live in the present?
                """
            )
        ],
    },
    # Maximum number of steps to take in the graph
    {"recursion_limit": 150},
)
for s in events:
    print(s)
    print("----")
# Out:
# {'Classifier': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_AbnaVnjGNsYAxdV7cITSnMPx', 'function': {'arguments': '{}', 'name': 'classifier_tool'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 11, 'prompt_tokens': 282, 'total_tokens': 293, 'completion_tokens_details': {'reasoning_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_1bb46167f9', 'finish_reason': 'tool_calls', 'logprobs': None}, name='Classifier', id='run-284fec97-b847-4b86-b309-bd5d18eeaff8-0', tool_calls=[{'name': 'classifier_tool', 'args': {}, 'id': 'call_AbnaVnjGNsYAxdV7cITSnMPx', 'type': 'tool_call'}], usage_metadata={'input_tokens': 282, 'output_tokens': 11, 'total_tokens': 293})], 'sender': 'Classifier'}}
# ----
# {'call_tool': {'messages': [ToolMessage(content='Return your analysis and classification', name='classifier_tool', tool_call_id='call_AbnaVnjGNsYAxdV7cITSnMPx')]}}
# ----
# {'Classifier': {'messages': [AIMessage(content='ANALYSED The message reflects concerns about relationship dynamics, insecurities, and the impact of past experiences on the present. It suggests a struggle with acceptance and self-identity. \n\nCategories:\n- Relationship Issues\n- Self-Esteem and Insecurity\n- Mental Health Concerns', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 58, 'prompt_tokens': 308, 'total_tokens': 366, 'completion_tokens_details': {'reasoning_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_1bb46167f9', 'finish_reason': 'stop', 'logprobs': None}, name='Classifier', id='run-a3198508-0575-47a4-9466-4540cc30b0be-0', usage_metadata={'input_tokens': 308, 'output_tokens': 58, 'total_tokens': 366})], 'sender': 'Classifier'}}
# ----
# {'Generator': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_45akyuzWohmQ7PGdAi2eM2tS', 'function': {'arguments': '{}', 'name': 'generator_tool'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 10, 'prompt_tokens': 1023, 'total_tokens': 1033, 'completion_tokens_details': {'reasoning_tokens': 0}}, 'model_name': 'ft:gpt-4o-mini-2024-07-18:personal:second-ft:A3g9cAiE', 'system_fingerprint': 'fp_7715b42b09', 'finish_reason': 'tool_calls', 'logprobs': None}, name='Generator', id='run-988ffe35-5202-4c6f-a221-63e259d82a41-0', tool_calls=[{'name': 'generator_tool', 'args': {}, 'id': 'call_45akyuzWohmQ7PGdAi2eM2tS', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1023, 'output_tokens': 10, 'total_tokens': 1033})], 'sender': 'Generator'}}
# ----
# {'call_tool': {'messages': [ToolMessage(content='Return your generated response', name='generator_tool', tool_call_id='call_45akyuzWohmQ7PGdAi2eM2tS')]}}
# ----
# {'Generator': {'messages': ["ANSWER: Thank you for sharing such an intimate part of your life and relationship with me. It sounds like you and your fiancé have a deep connection rooted in your shared Christian background, but also face challenges related to past experiences and present insecurities. \n\nI can imagine how difficult it must be for both of you to navigate these feelings. It's understandable that your fiancé may struggle with accepting your past, particularly if he is grappling with his own insecurities. Our past experiences often shape how we view ourselves and others, and it's completely valid that he's finding it hard to reconcile those experiences with your present.\n\nIt’s evident that you care deeply about him and your relationship, wanting to help him let go of the past and focus on the here and now. This desire shows a lot of love and commitment. You might start by having open and honest conversations about both of your feelings—creating a safe space for him to express his insecurities and fears, while also sharing your feelings and needs. \n\nEncouraging him to seek support, whether through counseling or other means, might also be beneficial, as it can provide him with tools to work through his insecurities. It’s essential for both of you to feel seen and heard in this process. Can you tell me more about how you’ve approached this topic with him so far?"], 'sender': 'Generator'}}
# ----
# {'Humanizer': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_AdAbsjpFzVlKblsmJ0ZB99i5', 'function': {'arguments': '{"output":"Thank you for sharing such an intimate part of your life and relationship with me. It sounds like you and your fiancé have a deep connection rooted in your shared Christian background, but also face challenges related to past experiences and present insecurities. \\n\\nI can imagine how difficult it must be for both of you to navigate these feelings. It\'s understandable that your fiancé may struggle with accepting your past, particularly if he is grappling with his own insecurities. Our past experiences often shape how we view ourselves and others, and it\'s completely valid that he\'s finding it hard to reconcile those experiences with your present.\\n\\nIt’s evident that you care deeply about him and your relationship, wanting to help him let go of the past and focus on the here and now. This desire shows a lot of love and commitment. You might start by having open and honest conversations about both of your feelings—creating a safe space for him to express his insecurities and fears, while also sharing your feelings and needs. \\n\\nEncouraging him to seek support, whether through counseling or other means, might also be beneficial, as it can provide him with tools to work through his insecurities. It’s essential for both of you to feel seen and heard in this process. Can you tell me more about how you’ve approached this topic with him so far?"}', 'name': 'humanizer_tool'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 284, 'prompt_tokens': 751, 'total_tokens': 1035, 'completion_tokens_details': {'reasoning_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_e9627b5346', 'finish_reason': 'tool_calls', 'logprobs': None}, name='Humanizer', id='run-0b421eb7-f035-41f2-a740-fb67c9f50519-0', tool_calls=[{'name': 'humanizer_tool', 'args': {'output': "Thank you for sharing such an intimate part of your life and relationship with me. It sounds like you and your fiancé have a deep connection rooted in your shared Christian background, but also face challenges related to past experiences and present insecurities. \n\nI can imagine how difficult it must be for both of you to navigate these feelings. It's understandable that your fiancé may struggle with accepting your past, particularly if he is grappling with his own insecurities. Our past experiences often shape how we view ourselves and others, and it's completely valid that he's finding it hard to reconcile those experiences with your present.\n\nIt’s evident that you care deeply about him and your relationship, wanting to help him let go of the past and focus on the here and now. This desire shows a lot of love and commitment. You might start by having open and honest conversations about both of your feelings—creating a safe space for him to express his insecurities and fears, while also sharing your feelings and needs. \n\nEncouraging him to seek support, whether through counseling or other means, might also be beneficial, as it can provide him with tools to work through his insecurities. It’s essential for both of you to feel seen and heard in this process. Can you tell me more about how you’ve approached this topic with him so far?"}, 'id': 'call_AdAbsjpFzVlKblsmJ0ZB99i5', 'type': 'tool_call'}], usage_metadata={'input_tokens': 751, 'output_tokens': 284, 'total_tokens': 1035})], 'sender': 'Humanizer'}}
# ----
# {'call_tool': {'messages': [ToolMessage(content='Return your response', name='humanizer_tool', tool_call_id='call_AdAbsjpFzVlKblsmJ0ZB99i5')]}}
# ----
# {'Humanizer': {'messages': [AIMessage(content="Thank you for opening up about such a personal part of your life and relationship. It sounds like you and your fiancé share a strong bond, rooted in your Christian background, but are facing some challenges due to past experiences and current insecurities.\n\nI can only imagine how tough it must be for both of you to work through these feelings. It's completely understandable for your fiancé to have a hard time accepting your past, especially if he’s also dealing with his own insecurities. Our pasts can really shape how we see ourselves and others, and it's normal for him to struggle with that.\n\nIt's clear you care deeply for him and want to support him in moving forward together. That speaks volumes about your love and commitment. To start, consider having open, honest conversations where both of you can share your feelings. Creating a safe space for him to voice his worries while you express your own thoughts and needs could be really helpful.\n\nIt might also be beneficial for him to seek support, like counseling, which can provide him with the tools to work through his insecurities. It’s so important for both of you to feel understood and valued in this journey. If you don’t mind sharing, how have you approached this conversation with him so far?", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 248, 'prompt_tokens': 1050, 'total_tokens': 1298, 'completion_tokens_details': {'reasoning_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_e9627b5346', 'finish_reason': 'stop', 'logprobs': None}, name='Humanizer', id='run-95ff46cc-8360-49c0-9c64-3d78992fc4d9-0', usage_metadata={'input_tokens': 1050, 'output_tokens': 248, 'total_tokens': 1298})], 'sender': 'Humanizer'}}
# ----

# %% [markdown]
# ## Evaluation Process

# %%
from langchain import hub
from langchain.agents import AgentExecutor, create_react_agent
from langchain_openai import OpenAI

# %%
from langchain_openai import ChatOpenAI
from langchain.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_messages([("system", new_prompt), ("human", "{input}")])

openai_client = OpenAI(api_key=OPENAI_API_KEY)

# %% [markdown]
# ### Run Individual Evaluator

# %%
from langsmith import Client
from langsmith.evaluation import evaluate

langsmith_client = Client(api_key=LANGSMITH_API_KEY)
dataset_name = "therapy-questions"

# %% [markdown]
# ####Evaluate our fine-tuned model

# %%
from transformers import ReactJsonAgent


# Fine-tuned model
my_model = CreateApp(
    client=openai_client,
    prompt=prompt,
    model="ft:gpt-4o-mini-2024-07-18:personal::AG2bmvmI"
)

# agent = ReactJsonAgent(tools=[], llm_engine=my_model, add_base_tools=True)
# Retrieve the data split named 'test'
dataset = langsmith_client.list_examples(dataset_name=dataset_name, splits=["test"])

# Evaluate my fine-tuned model
my_model_results = evaluate(
    my_model.predict, # The model instance
    data=dataset, # The data to predict and grade over
    evaluators=[answer_evaluator], # The evaluators to score the results
    experiment_prefix="my-model-mvml-new-prompt", # A prefix for experiment names to easily identify them
)
# Out:
# View the evaluation results for experiment: 'my-model-mvml-new-prompt-9d979b9a' at:
# https://smith.langchain.com/o/7af6ec33-6165-50a3-b621-e4d6eb6eaecd/datasets/e29b0039-3055-473e-9987-8a2ae2a67e45/compare?selectedSessions=9d724385-365e-49c8-b35e-b130deb3c66b
# 0it [00:00, ?it/s]

# %% [markdown]
# ####Evaluate GPTs models

# %% [markdown]
# # Generate synthatic data using GPT-4o
# Create model instance  and use the `Indivdual Evaluator` to evaluate the genrated answers.\
# The genrated data are saved to csv file for further use.

# %%
from langchain.smith import RunEvalConfig

# Create model instance
gpt_4o_mini = CreateApp(client=openai_client, prompt=prompt, model="gpt-4o-mini-2024-07-18")
eval_config = RunEvalConfig(evaluators=[answer_evaluator])
dataset_name = "synth-gen"
project_name = "synth-data-generation"


test_results = langsmith_client.run_on_dataset(
    dataset_name=dataset_name,
    project_name=project_name,
    llm_or_chain_factory=gpt_4o_mini.predict,
    evaluation=eval_config
)

# Save the result as a csv file
df = langsmith_client.get_test_results(project_name=project_name)
df.to_csv("results.csv", index=False)

# %% [markdown]
# # Graph RAG

# %% [markdown]
# ## Setup

# %%
# !pip install graphrag
# Out:
# Collecting graphrag
#   Downloading graphrag-0.3.6-py3-none-any.whl.metadata (6.0 kB)
# Collecting aiofiles<25.0.0,>=24.1.0 (from graphrag)
#   Downloading aiofiles-24.1.0-py3-none-any.whl.metadata (10 kB)
# Collecting aiolimiter<2.0.0,>=1.1.0 (from graphrag)
#   Downloading aiolimiter-1.1.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting azure-identity<2.0.0,>=1.17.1 (from graphrag)
#   Downloading azure_identity-1.19.0-py3-none-any.whl.metadata (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.6/80.6 kB 5.5 MB/s eta 0:00:00
# Collecting azure-search-documents<12.0.0,>=11.4.0 (from graphrag)
#   Downloading azure_search_documents-11.5.1-py3-none-any.whl.metadata (23 kB)
# Collecting azure-storage-blob<13.0.0,>=12.22.0 (from graphrag)
#   Downloading azure_storage_blob-12.23.1-py3-none-any.whl.metadata (26 kB)
# Collecting datashaper<0.0.50,>=0.0.49 (from graphrag)
#   Downloading datashaper-0.0.49-py3-none-any.whl.metadata (3.7 kB)
# Collecting devtools<0.13.0,>=0.12.2 (from graphrag)
#   Downloading devtools-0.12.2-py3-none-any.whl.metadata (4.8 kB)
# Collecting environs<12.0.0,>=11.0.0 (from graphrag)
#   Downloading environs-11.0.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: future<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from graphrag) (1.0.0)
# Collecting graspologic<4.0.0,>=3.4.1 (from graphrag)
#   Downloading graspologic-3.4.1-py3-none-any.whl.metadata (5.8 kB)
# Collecting json-repair<0.29.0,>=0.28.4 (from graphrag)
#   Downloading json_repair-0.28.4-py3-none-any.whl.metadata (9.0 kB)
# Collecting lancedb<0.14.0,>=0.13.0 (from graphrag)
#   Downloading lancedb-0.13.0-cp38-abi3-manylinux_2_28_x86_64.whl.metadata (4.8 kB)
# Collecting matplotlib<4.0.0,>=3.9.0 (from graphrag)
#   Downloading matplotlib-3.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: networkx<4,>=3 in /usr/local/lib/python3.10/dist-packages (from graphrag) (3.4)
# Collecting nltk==3.9.1 (from graphrag)
#   Downloading nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: numpy<2.0.0,>=1.25.2 in /usr/local/lib/python3.10/dist-packages (from graphrag) (1.26.4)
# Collecting openai<2.0.0,>=1.46.1 (from graphrag)
#   Downloading openai-1.51.2-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: pandas<3.0.0,>=2.2.2 in /usr/local/lib/python3.10/dist-packages (from graphrag) (2.2.2)
# Collecting pyaml-env<2.0.0,>=1.2.1 (from graphrag)
#   Downloading pyaml_env-1.2.1-py3-none-any.whl.metadata (12 kB)
# Collecting pyarrow<16.0.0,>=15.0.0 (from graphrag)
#   Downloading pyarrow-15.0.2-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.9.2 in /usr/local/lib/python3.10/dist-packages (from graphrag) (2.9.2)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from graphrag) (1.0.1)
# Requirement already satisfied: pyyaml<7.0.0,>=6.0.2 in /usr/local/lib/python3.10/dist-packages (from graphrag) (6.0.2)
# Requirement already satisfied: rich<14.0.0,>=13.6.0 in /usr/local/lib/python3.10/dist-packages (from graphrag) (13.9.2)
# Requirement already satisfied: tenacity<10.0.0,>=9.0.0 in /usr/local/lib/python3.10/dist-packages (from graphrag) (9.0.0)
# Collecting tiktoken<0.8.0,>=0.7.0 (from graphrag)
#   Downloading tiktoken-0.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.12.2 in /usr/local/lib/python3.10/dist-packages (from graphrag) (4.12.2)
# Collecting umap-learn<0.6.0,>=0.5.6 (from graphrag)
#   Downloading umap_learn-0.5.6-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk==3.9.1->graphrag) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk==3.9.1->graphrag) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk==3.9.1->graphrag) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk==3.9.1->graphrag) (4.66.5)
# Collecting azure-core>=1.31.0 (from azure-identity<2.0.0,>=1.17.1->graphrag)
#   Downloading azure_core-1.31.0-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: cryptography>=2.5 in /usr/local/lib/python3.10/dist-packages (from azure-identity<2.0.0,>=1.17.1->graphrag) (43.0.1)
# Collecting msal>=1.30.0 (from azure-identity<2.0.0,>=1.17.1->graphrag)
#   Downloading msal-1.31.0-py3-none-any.whl.metadata (11 kB)
# Collecting msal-extensions>=1.2.0 (from azure-identity<2.0.0,>=1.17.1->graphrag)
#   Downloading msal_extensions-1.2.0-py3-none-any.whl.metadata (7.6 kB)
# Collecting azure-common>=1.1 (from azure-search-documents<12.0.0,>=11.4.0->graphrag)
#   Downloading azure_common-1.1.28-py2.py3-none-any.whl.metadata (5.0 kB)
# Collecting isodate>=0.6.0 (from azure-search-documents<12.0.0,>=11.4.0->graphrag)
#   Downloading isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
# Collecting diskcache<6.0.0,>=5.6.3 (from datashaper<0.0.50,>=0.0.49->graphrag)
#   Downloading diskcache-5.6.3-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: jsonschema<5.0.0,>=4.21.1 in /usr/local/lib/python3.10/dist-packages (from datashaper<0.0.50,>=0.0.49->graphrag) (4.23.0)
# Collecting asttokens<3.0.0,>=2.0.0 (from devtools<0.13.0,>=0.12.2->graphrag)
#   Downloading asttokens-2.4.1-py2.py3-none-any.whl.metadata (5.2 kB)
# Collecting executing>=1.1.1 (from devtools<0.13.0,>=0.12.2->graphrag)
#   Downloading executing-2.1.0-py2.py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: pygments>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from devtools<0.13.0,>=0.12.2->graphrag) (2.18.0)
# Collecting marshmallow>=3.13.0 (from environs<12.0.0,>=11.0.0->graphrag)
#   Downloading marshmallow-3.22.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting POT<0.10,>=0.9 (from graspologic<4.0.0,>=3.4.1->graphrag)
#   Downloading POT-0.9.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (32 kB)
# Collecting anytree<3.0.0,>=2.12.1 (from graspologic<4.0.0,>=3.4.1->graphrag)
#   Downloading anytree-2.12.1-py3-none-any.whl.metadata (8.1 kB)
# Collecting beartype<0.19.0,>=0.18.5 (from graspologic<4.0.0,>=3.4.1->graphrag)
#   Downloading beartype-0.18.5-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: gensim<5.0.0,>=4.3.2 in /usr/local/lib/python3.10/dist-packages (from graspologic<4.0.0,>=3.4.1->graphrag) (4.3.3)
# Collecting graspologic-native<2.0.0,>=1.2.1 (from graspologic<4.0.0,>=3.4.1->graphrag)
#   Downloading graspologic_native-1.2.1-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.9 kB)
# Collecting hyppo<0.5.0,>=0.4.0 (from graspologic<4.0.0,>=3.4.1->graphrag)
#   Downloading hyppo-0.4.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: scikit-learn<2.0.0,>=1.4.2 in /usr/local/lib/python3.10/dist-packages (from graspologic<4.0.0,>=3.4.1->graphrag) (1.5.2)
# Collecting scipy==1.12.0 (from graspologic<4.0.0,>=3.4.1->graphrag)
#   Downloading scipy-1.12.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 kB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: seaborn<0.14.0,>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from graspologic<4.0.0,>=3.4.1->graphrag) (0.13.2)
# Requirement already satisfied: statsmodels<0.15.0,>=0.14.2 in /usr/local/lib/python3.10/dist-packages (from graspologic<4.0.0,>=3.4.1->graphrag) (0.14.4)
# Collecting deprecation (from lancedb<0.14.0,>=0.13.0->graphrag)
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl.metadata (4.6 kB)
# Collecting pylance==0.17.0 (from lancedb<0.14.0,>=0.13.0->graphrag)
#   Downloading pylance-0.17.0-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (7.2 kB)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.10/dist-packages (from lancedb<0.14.0,>=0.13.0->graphrag) (2.32.3)
# Collecting retry>=0.9.2 (from lancedb<0.14.0,>=0.13.0->graphrag)
#   Downloading retry-0.9.2-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: attrs>=21.3.0 in /usr/local/lib/python3.10/dist-packages (from lancedb<0.14.0,>=0.13.0->graphrag) (24.2.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from lancedb<0.14.0,>=0.13.0->graphrag) (24.1)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.10/dist-packages (from lancedb<0.14.0,>=0.13.0->graphrag) (5.5.0)
# Collecting overrides>=0.7 (from lancedb<0.14.0,>=0.13.0->graphrag)
#   Downloading overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.9.0->graphrag) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.9.0->graphrag) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.9.0->graphrag) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.9.0->graphrag) (1.4.7)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.9.0->graphrag) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.9.0->graphrag) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.9.0->graphrag) (2.8.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.46.1->graphrag) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai<2.0.0,>=1.46.1->graphrag) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai<2.0.0,>=1.46.1->graphrag)
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting jiter<1,>=0.4.0 (from openai<2.0.0,>=1.46.1->graphrag)
#   Downloading jiter-0.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.2 kB)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.46.1->graphrag) (1.3.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0.0,>=2.2.2->graphrag) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0.0,>=2.2.2->graphrag) (2024.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.9.2->graphrag) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.9.2->graphrag) (2.23.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<14.0.0,>=13.6.0->graphrag) (3.0.0)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.10/dist-packages (from umap-learn<0.6.0,>=0.5.6->graphrag) (0.60.0)
# Collecting pynndescent>=0.5 (from umap-learn<0.6.0,>=0.5.6->graphrag)
#   Downloading pynndescent-0.5.13-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.46.1->graphrag) (3.10)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.46.1->graphrag) (1.2.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from anytree<3.0.0,>=2.12.1->graspologic<4.0.0,>=3.4.1->graphrag) (1.16.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=2.5->azure-identity<2.0.0,>=1.17.1->graphrag) (1.17.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim<5.0.0,>=4.3.2->graspologic<4.0.0,>=3.4.1->graphrag) (7.0.5)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.46.1->graphrag) (2024.8.30)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai<2.0.0,>=1.46.1->graphrag)
#   Downloading httpcore-1.0.6-py3-none-any.whl.metadata (21 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.46.1->graphrag)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: autograd>=1.3 in /usr/local/lib/python3.10/dist-packages (from hyppo<0.5.0,>=0.4.0->graspologic<4.0.0,>=3.4.1->graphrag) (1.7.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema<5.0.0,>=4.21.1->datashaper<0.0.50,>=0.0.49->graphrag) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema<5.0.0,>=4.21.1->datashaper<0.0.50,>=0.0.49->graphrag) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema<5.0.0,>=4.21.1->datashaper<0.0.50,>=0.0.49->graphrag) (0.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=13.6.0->graphrag) (0.1.2)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity<2.0.0,>=1.17.1->graphrag) (2.9.0)
# Collecting portalocker<3,>=1.4 (from msal-extensions>=1.2.0->azure-identity<2.0.0,>=1.17.1->graphrag)
#   Downloading portalocker-2.10.1-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.2->umap-learn<0.6.0,>=0.5.6->graphrag) (0.43.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31.0->lancedb<0.14.0,>=0.13.0->graphrag) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31.0->lancedb<0.14.0,>=0.13.0->graphrag) (2.2.3)
# Requirement already satisfied: decorator>=3.4.2 in /usr/local/lib/python3.10/dist-packages (from retry>=0.9.2->lancedb<0.14.0,>=0.13.0->graphrag) (4.4.2)
# Collecting py<2.0.0,>=1.4.26 (from retry>=0.9.2->lancedb<0.14.0,>=0.13.0->graphrag)
#   Downloading py-1.11.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<2.0.0,>=1.4.2->graspologic<4.0.0,>=3.4.1->graphrag) (3.5.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.10/dist-packages (from statsmodels<0.15.0,>=0.14.2->graspologic<4.0.0,>=3.4.1->graphrag) (0.5.6)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=2.5->azure-identity<2.0.0,>=1.17.1->graphrag) (2.22)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open>=1.8.1->gensim<5.0.0,>=4.3.2->graspologic<4.0.0,>=3.4.1->graphrag) (1.16.0)
# Downloading graphrag-0.3.6-py3-none-any.whl (389 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 389.2/389.2 kB 19.1 MB/s eta 0:00:00
# Downloading nltk-3.9.1-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 40.0 MB/s eta 0:00:00
# Downloading aiofiles-24.1.0-py3-none-any.whl (15 kB)
# Downloading aiolimiter-1.1.0-py3-none-any.whl (7.2 kB)
# Downloading azure_identity-1.19.0-py3-none-any.whl (187 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 187.6/187.6 kB 12.8 MB/s eta 0:00:00
# Downloading azure_search_documents-11.5.1-py3-none-any.whl (297 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.7/297.7 kB 15.6 MB/s eta 0:00:00
# Downloading azure_storage_blob-12.23.1-py3-none-any.whl (405 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 405.6/405.6 kB 23.7 MB/s eta 0:00:00
# Downloading datashaper-0.0.49-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 4.7 MB/s eta 0:00:00
# Downloading devtools-0.12.2-py3-none-any.whl (19 kB)
# Downloading environs-11.0.0-py3-none-any.whl (12 kB)
# Downloading graspologic-3.4.1-py3-none-any.whl (5.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 64.1 MB/s eta 0:00:00
# Downloading scipy-1.12.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.4/38.4 MB 23.9 MB/s eta 0:00:00
# Downloading json_repair-0.28.4-py3-none-any.whl (13 kB)
# Downloading lancedb-0.13.0-cp38-abi3-manylinux_2_28_x86_64.whl (24.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.2/24.2 MB 53.9 MB/s eta 0:00:00
# Downloading pylance-0.17.0-cp39-abi3-manylinux_2_28_x86_64.whl (29.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.2/29.2 MB 12.8 MB/s eta 0:00:00
# Downloading matplotlib-3.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 82.3 MB/s eta 0:00:00
# Downloading openai-1.51.2-py3-none-any.whl (383 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.7/383.7 kB 22.7 MB/s eta 0:00:00
# Downloading pyaml_env-1.2.1-py3-none-any.whl (9.0 kB)
# Downloading pyarrow-15.0.2-cp310-cp310-manylinux_2_28_x86_64.whl (38.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.3/38.3 MB 14.8 MB/s eta 0:00:00
# Downloading tiktoken-0.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 44.1 MB/s eta 0:00:00
# Downloading umap_learn-0.5.6-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.7/85.7 kB 5.6 MB/s eta 0:00:00
# Downloading anytree-2.12.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.9/44.9 kB 2.8 MB/s eta 0:00:00
# Downloading asttokens-2.4.1-py2.py3-none-any.whl (27 kB)
# Downloading azure_common-1.1.28-py2.py3-none-any.whl (14 kB)
# Downloading azure_core-1.31.0-py3-none-any.whl (197 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 197.4/197.4 kB 13.0 MB/s eta 0:00:00
# Downloading beartype-0.18.5-py3-none-any.whl (917 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 917.8/917.8 kB 41.6 MB/s eta 0:00:00
# Downloading diskcache-5.6.3-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 2.9 MB/s eta 0:00:00
# Downloading executing-2.1.0-py2.py3-none-any.whl (25 kB)
# Downloading graspologic_native-1.2.1-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 46.0 MB/s eta 0:00:00
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 4.0 MB/s eta 0:00:00
# Downloading httpcore-1.0.6-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.0/78.0 kB 5.1 MB/s eta 0:00:00
# Downloading hyppo-0.4.0-py3-none-any.whl (146 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.6/146.6 kB 9.9 MB/s eta 0:00:00
# Downloading isodate-0.7.2-py3-none-any.whl (22 kB)
# Downloading jiter-0.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (325 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.2/325.2 kB 19.1 MB/s eta 0:00:00
# Downloading marshmallow-3.22.0-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 3.4 MB/s eta 0:00:00
# Downloading msal-1.31.0-py3-none-any.whl (113 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.1/113.1 kB 7.0 MB/s eta 0:00:00
# Downloading msal_extensions-1.2.0-py3-none-any.whl (19 kB)
# Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading POT-0.9.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (835 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 835.4/835.4 kB 41.0 MB/s eta 0:00:00
# Downloading pynndescent-0.5.13-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 kB 3.9 MB/s eta 0:00:00
# Downloading retry-0.9.2-py2.py3-none-any.whl (8.0 kB)
# Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Downloading portalocker-2.10.1-py3-none-any.whl (18 kB)
# Downloading py-1.11.0-py2.py3-none-any.whl (98 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 kB 6.5 MB/s eta 0:00:00
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.9 MB/s eta 0:00:00
# Installing collected packages: azure-common, scipy, pyarrow, pyaml-env, py, portalocker, overrides, nltk, marshmallow, json-repair, jiter, isodate, h11, graspologic-native, executing, diskcache, deprecation, beartype, asttokens, anytree, aiolimiter, aiofiles, tiktoken, retry, pylance, POT, matplotlib, httpcore, environs, devtools, azure-core, pynndescent, lancedb, hyppo, httpx, azure-storage-blob, azure-search-documents, umap-learn, openai, msal, datashaper, msal-extensions, graspologic, azure-identity, graphrag
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.13.1
#     Uninstalling scipy-1.13.1:
#       Successfully uninstalled scipy-1.13.1
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 16.1.0
#     Uninstalling pyarrow-16.1.0:
#       Successfully uninstalled pyarrow-16.1.0
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.8.1
#     Uninstalling nltk-3.8.1:
#       Successfully uninstalled nltk-3.8.1
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.1
#     Uninstalling matplotlib-3.7.1:
#       Successfully uninstalled matplotlib-3.7.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.6.1 requires pyarrow<16.2.0a0,>=16.1.0, but you have pyarrow 15.0.2 which is incompatible.
# osqp 0.6.7.post0 requires scipy!=1.12.0,>=0.13.2, but you have scipy 1.12.0 which is incompatible.
# Successfully installed POT-0.9.4 aiofiles-24.1.0 aiolimiter-1.1.0 anytree-2.12.1 asttokens-2.4.1 azure-common-1.1.28 azure-core-1.31.0 azure-identity-1.19.0 azure-search-documents-11.5.1 azure-storage-blob-12.23.1 beartype-0.18.5 datashaper-0.0.49 deprecation-2.1.0 devtools-0.12.2 diskcache-5.6.3 environs-11.0.0 executing-2.1.0 graphrag-0.3.6 graspologic-3.4.1 graspologic-native-1.2.1 h11-0.14.0 httpcore-1.0.6 httpx-0.27.2 hyppo-0.4.0 isodate-0.7.2 jiter-0.6.1 json-repair-0.28.4 lancedb-0.13.0 marshmallow-3.22.0 matplotlib-3.9.2 msal-1.31.0 msal-extensions-1.2.0 nltk-3.9.1 openai-1.51.2 overrides-7.7.0 portalocker-2.10.1 py-1.11.0 pyaml-env-1.2.1 pyarrow-15.0.2 pylance-0.17.0 pynndescent-0.5.13 retry-0.9.2 scipy-1.12.0 tiktoken-0.7.0 umap-learn-0.5.6

# %%
# !mkdir -p /content/drive/MyDrive/rag-data

# %%
# !pip install pymupdf

# %% [markdown]
# ## Extract text from pdf

# %%
import fitz

def extract_text_from_pdf(pdf_path):
    text = ""
    with fitz.open(pdf_path) as pdf_document:
        num_pages = pdf_document.page_count
        for page_num in range(num_pages):
            page = pdf_document[page_num]
            text += page.get_text()

    with open("/content/drive/MyDrive/ragtest/input/book.txt", "w") as f:
        f.write(text)

# %%
extract_text_from_pdf("/content/drive/MyDrive/rag-data/DIAGNOSTIC_AND_STATISTICAL_MANUAL_OF_MEN.pdf")

# %%
# !curl -fsSL https://ollama.com/install.sh | sh
# Out:
# >>> Installing ollama to /usr/local
# >>> Downloading Linux amd64 bundle
# ############################################################################################# 100.0%
# >>> Creating ollama user...
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: Unable to detect NVIDIA/AMD GPU. Install lspci or lshw to automatically detect and install GPU dependencies.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.

# %%
# !pip install ngrok
# Out:
# Collecting ngrok
#   Downloading ngrok-1.4.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# Downloading ngrok-1.4.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 48.0 MB/s eta 0:00:00
# Installing collected packages: ngrok
# Successfully installed ngrok-1.4.0

# %%
# !pip install aiohttp pyngrok

import asyncio
import os

# Set LD_LIBRARY_PATH so the system NVIDIA library becomes preferred
# over the built-in library. This is particularly important for
# Google Colab which installs older drivers
os.environ.update({'LD_LIBRARY_PATH': '/usr/lib64-nvidia'})

# Define run - a helper function to run subcommands asynchronously.
# The function takes in 2 arguments:
#  1. command
#  2. environment variable
async def run(cmd):
  print('>>> starting', *cmd)
  p = await asyncio.subprocess.create_subprocess_exec(
      *cmd,
      stdout=asyncio.subprocess.PIPE,
      stderr=asyncio.subprocess.PIPE
  )


# This function is designed to handle large amounts of text data efficiently.
# It asynchronously iterate over lines and print them, stripping and decoding as needed.
  async def pipe(lines):
    async for line in lines:
      print(line.strip().decode('utf-8'))


# Gather the standard output (stdout) and standard error output (stderr) streams of a subprocess and pipe them through
# the `pipe()` function to print each line after stripping whitespace and decoding UTF-8.
# This allows us to capture and process both the standard output and error messages from the subprocess concurrently.
  await asyncio.gather(
      pipe(p.stdout),
      pipe(p.stderr),
  )


# Authenticate with Ngrok
await asyncio.gather(
  run(['ngrok', 'config', 'add-authtoken', NGROK_AUTH_TOKEN])
)
# ngrok http --domain=widely-massive-sailfish.ngrok-free.app 80
# Out:
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (3.10.5)
# Collecting pyngrok
#   Downloading pyngrok-7.2.0-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp) (1.11.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp) (4.0.3)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.10/dist-packages (from pyngrok) (6.0.2)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from multidict<7.0,>=4.5->aiohttp) (4.12.2)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.0->aiohttp) (3.10)
# Downloading pyngrok-7.2.0-py3-none-any.whl (22 kB)
# Installing collected packages: pyngrok
# Successfully installed pyngrok-7.2.0
# >>> starting ngrok config add-authtoken 2mAQTO1L7SCdOV78nCgIxH2ZjUT_59fz1hRPwbKr5Ev65LStg
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml
# [None]

# %%
await asyncio.gather(
    run(['ollama', 'serve']),

    # If you don't want to map to a static URL in Ngrok, uncomment line 9 and comment line 10 before running this cell
    # run(['ngrok', 'http', '80'])
    # run(['ngrok', 'http', '--log', 'stderr', '11434', '--host-header', 'localhost:11434']),
    run(['ngrok', 'http', '--log', 'stderr', '11434', '--host-header', 'localhost:11434', '--domain', 'widely-massive-sailfish.ngrok-free.app']),
)
# Out:
# >>> starting ollama serve
# >>> starting ngrok http --log stderr 11434 --host-header localhost:11434 --domain widely-massive-sailfish.ngrok-free.app
# Couldn't find '/root/.ollama/id_ed25519'. Generating new private key.
# Your new public key is:
#
# ssh-ed25519 AAAAC3NzaC1lZDI1NTE5AAAAIAp6pqI8cTLt0CvTo9sZ6hRxoUzo9kA7eJn7tVbO5som
#
# 2024/09/19 19:50:36 routes.go:1153: INFO server config env="map[CUDA_VISIBLE_DEVICES: GPU_DEVICE_ORDINAL: HIP_VISIBLE_DEVICES: HSA_OVERRIDE_GFX_VERSION: HTTPS_PROXY: HTTP_PROXY: NO_PROXY: OLLAMA_DEBUG:false OLLAMA_FLASH_ATTENTION:false OLLAMA_GPU_OVERHEAD:0 OLLAMA_HOST:http://127.0.0.1:11434 OLLAMA_INTEL_GPU:false OLLAMA_KEEP_ALIVE:5m0s OLLAMA_LLM_LIBRARY: OLLAMA_LOAD_TIMEOUT:5m0s OLLAMA_MAX_LOADED_MODELS:0 OLLAMA_MAX_QUEUE:512 OLLAMA_MODELS:/root/.ollama/models OLLAMA_NOHISTORY:false OLLAMA_NOPRUNE:false OLLAMA_NUM_PARALLEL:0 OLLAMA_ORIGINS:[http://localhost https://localhost http://localhost:* https://localhost:* http://127.0.0.1 https://127.0.0.1 http://127.0.0.1:* https://127.0.0.1:* http://0.0.0.0 https://0.0.0.0 http://0.0.0.0:* https://0.0.0.0:* app://* file://* tauri://*] OLLAMA_SCHED_SPREAD:false OLLAMA_TMPDIR: ROCR_VISIBLE_DEVICES: http_proxy: https_proxy: no_proxy:]"
# time=2024-09-19T19:50:36.939Z level=INFO source=images.go:753 msg="total blobs: 0"
# time=2024-09-19T19:50:36.939Z level=INFO source=images.go:760 msg="total unused blobs removed: 0"
# time=2024-09-19T19:50:36.940Z level=INFO source=routes.go:1200 msg="Listening on 127.0.0.1:11434 (version 0.3.11)"
# time=2024-09-19T19:50:36.942Z level=INFO source=common.go:135 msg="extracting embedded files" dir=/tmp/ollama2377321091/runners
# t=2024-09-19T19:50:37+0000 lvl=info msg="no configuration paths supplied"
# t=2024-09-19T19:50:37+0000 lvl=info msg="using configuration at default config path" path=/root/.config/ngrok/ngrok.yml
# t=2024-09-19T19:50:37+0000 lvl=info msg="open config file" path=/root/.config/ngrok/ngrok.yml err=nil
# t=2024-09-19T19:50:37+0000 lvl=info msg="starting web service" obj=web addr=127.0.0.1:4040 allow_hosts=[]
# t=2024-09-19T19:50:37+0000 lvl=info msg="client session established" obj=tunnels.session
# t=2024-09-19T19:50:37+0000 lvl=info msg="tunnel session started" obj=tunnels.session
# t=2024-09-19T19:50:37+0000 lvl=info msg="started tunnel" obj=tunnels name=command_line addr=http://localhost:11434 url=https://widely-massive-sailfish.ngrok-free.app
# time=2024-09-19T19:51:15.730Z level=INFO source=common.go:49 msg="Dynamic LLM libraries" runners="[cpu_avx cpu_avx2 cuda_v11 cuda_v12 rocm_v60102 cpu]"
# time=2024-09-19T19:51:15.731Z level=INFO source=gpu.go:199 msg="looking for compatible GPUs"
# time=2024-09-19T19:51:16.164Z level=INFO source=types.go:107 msg="inference compute" id=GPU-892982ab-d3aa-f2c1-0521-92e984bbd2e9 library=cuda variant=v12 compute=7.5 driver=12.2 name="Tesla T4" total="14.7 GiB" available="14.6 GiB"
# t=2024-09-19T19:52:18+0000 lvl=info msg="join connections" obj=join id=09ec26f55955 l=127.0.0.1:11434 r=[2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763]:56721
# [GIN] 2024/09/19 - 19:52:18 | 200 |      58.095µs | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | HEAD     "/"
# [GIN] 2024/09/19 - 19:52:19 | 200 |     307.458µs | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | GET      "/api/tags"
# t=2024-09-19T19:52:38+0000 lvl=info msg="join connections" obj=join id=5176857452a7 l=127.0.0.1:11434 r=[2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763]:56725
# [GIN] 2024/09/19 - 19:52:38 | 200 |      34.839µs | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | HEAD     "/"
# time=2024-09-19T19:52:40.362Z level=INFO source=download.go:175 msg="downloading ff1d1fc78170 in 16 340 MB part(s)"
# time=2024-09-19T19:53:14.449Z level=INFO source=download.go:175 msg="downloading 109037bec39c in 1 136 B part(s)"
# time=2024-09-19T19:53:16.673Z level=INFO source=download.go:175 msg="downloading 097a36493f71 in 1 8.4 KB part(s)"
# time=2024-09-19T19:53:18.754Z level=INFO source=download.go:175 msg="downloading 2490e7468436 in 1 65 B part(s)"
# time=2024-09-19T19:53:20.694Z level=INFO source=download.go:175 msg="downloading 10aa81da732e in 1 487 B part(s)"
# [GIN] 2024/09/19 - 19:53:50 | 200 |         1m11s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/pull"
# t=2024-09-19T19:54:43+0000 lvl=info msg="join connections" obj=join id=b2bc59da5de4 l=127.0.0.1:11434 r=[2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763]:56757
# [GIN] 2024/09/19 - 19:54:43 | 404 |      25.858µs | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/chat/completions"
# t=2024-09-19T19:56:54+0000 lvl=info msg="join connections" obj=join id=69f06d6fe8cb l=127.0.0.1:11434 r=[2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763]:56779
# time=2024-09-19T19:56:55.418Z level=INFO source=sched.go:714 msg="new model will fit in available VRAM in single GPU, loading" model=/root/.ollama/models/blobs/sha256-ff1d1fc78170d787ee1201778e2dd65ea211654ca5fb7d69b5a2e7b123a50373 gpu=GPU-892982ab-d3aa-f2c1-0521-92e984bbd2e9 parallel=4 available=15727656960 required="8.8 GiB"
# time=2024-09-19T19:56:55.419Z level=INFO source=server.go:103 msg="system memory" total="12.7 GiB" free="11.3 GiB" free_swap="0 B"
# time=2024-09-19T19:56:55.421Z level=INFO source=memory.go:326 msg="offload to cuda" layers.requested=-1 layers.model=43 layers.offload=43 layers.split="" memory.available="[14.6 GiB]" memory.gpu_overhead="0 B" memory.required.full="8.8 GiB" memory.required.partial="8.8 GiB" memory.required.kv="2.6 GiB" memory.required.allocations="[8.8 GiB]" memory.weights.total="7.0 GiB" memory.weights.repeating="6.3 GiB" memory.weights.nonrepeating="717.8 MiB" memory.graph.full="507.0 MiB" memory.graph.partial="1.2 GiB"
# time=2024-09-19T19:56:55.423Z level=INFO source=server.go:388 msg="starting llama server" cmd="/tmp/ollama2377321091/runners/cuda_v12/ollama_llama_server --model /root/.ollama/models/blobs/sha256-ff1d1fc78170d787ee1201778e2dd65ea211654ca5fb7d69b5a2e7b123a50373 --ctx-size 8192 --batch-size 512 --embedding --log-disable --n-gpu-layers 43 --parallel 4 --port 35925"
# time=2024-09-19T19:56:55.431Z level=INFO source=sched.go:449 msg="loaded runners" count=1
# time=2024-09-19T19:56:55.431Z level=INFO source=server.go:587 msg="waiting for llama runner to start responding"
# time=2024-09-19T19:56:55.432Z level=INFO source=server.go:621 msg="waiting for server to become available" status="llm server error"
# INFO [main] build info | build=10 commit="9225b05" tid="138534083190784" timestamp=1726775816
# INFO [main] system info | n_threads=1 n_threads_batch=1 system_info="AVX = 1 | AVX_VNNI = 0 | AVX2 = 0 | AVX512 = 0 | AVX512_VBMI = 0 | AVX512_VNNI = 0 | AVX512_BF16 = 0 | FMA = 0 | NEON = 0 | SVE = 0 | ARM_FMA = 0 | F16C = 0 | FP16_VA = 0 | WASM_SIMD = 0 | BLAS = 1 | SSE3 = 1 | SSSE3 = 1 | VSX = 0 | MATMUL_INT8 = 0 | LLAMAFILE = 1 | " tid="138534083190784" timestamp=1726775816 total_threads=2
# INFO [main] HTTP server listening | hostname="127.0.0.1" n_threads_http="6" port="35925" tid="138534083190784" timestamp=1726775816
# llama_model_loader: loaded meta data with 29 key-value pairs and 464 tensors from /root/.ollama/models/blobs/sha256-ff1d1fc78170d787ee1201778e2dd65ea211654ca5fb7d69b5a2e7b123a50373 (version GGUF V3 (latest))
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = gemma2
# llama_model_loader: - kv   1:                               general.name str              = gemma-2-9b-it
# llama_model_loader: - kv   2:                      gemma2.context_length u32              = 8192
# llama_model_loader: - kv   3:                    gemma2.embedding_length u32              = 3584
# llama_model_loader: - kv   4:                         gemma2.block_count u32              = 42
# llama_model_loader: - kv   5:                 gemma2.feed_forward_length u32              = 14336
# llama_model_loader: - kv   6:                gemma2.attention.head_count u32              = 16
# llama_model_loader: - kv   7:             gemma2.attention.head_count_kv u32              = 8
# llama_model_loader: - kv   8:    gemma2.attention.layer_norm_rms_epsilon f32              = 0.000001
# llama_model_loader: - kv   9:                gemma2.attention.key_length u32              = 256
# llama_model_loader: - kv  10:              gemma2.attention.value_length u32              = 256
# llama_model_loader: - kv  11:                          general.file_type u32              = 2
# llama_model_loader: - kv  12:              gemma2.attn_logit_softcapping f32              = 50.000000
# llama_model_loader: - kv  13:             gemma2.final_logit_softcapping f32              = 30.000000
# llama_model_loader: - kv  14:            gemma2.attention.sliding_window u32              = 4096
# llama_model_loader: - kv  15:                       tokenizer.ggml.model str              = llama
# llama_model_loader: - kv  16:                         tokenizer.ggml.pre str              = default
# time=2024-09-19T19:56:56.184Z level=INFO source=server.go:621 msg="waiting for server to become available" status="llm server loading model"
# llama_model_loader: - kv  17:                      tokenizer.ggml.tokens arr[str,256000]  = ["<pad>", "<eos>", "<bos>", "<unk>", ...
# llama_model_loader: - kv  18:                      tokenizer.ggml.scores arr[f32,256000]  = [0.000000, 0.000000, 0.000000, 0.0000...
# llama_model_loader: - kv  19:                  tokenizer.ggml.token_type arr[i32,256000]  = [3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, ...
# llama_model_loader: - kv  20:                tokenizer.ggml.bos_token_id u32              = 2
# llama_model_loader: - kv  21:                tokenizer.ggml.eos_token_id u32              = 1
# llama_model_loader: - kv  22:            tokenizer.ggml.unknown_token_id u32              = 3
# llama_model_loader: - kv  23:            tokenizer.ggml.padding_token_id u32              = 0
# llama_model_loader: - kv  24:               tokenizer.ggml.add_bos_token bool             = true
# llama_model_loader: - kv  25:               tokenizer.ggml.add_eos_token bool             = false
# llama_model_loader: - kv  26:                    tokenizer.chat_template str              = {{ bos_token }}{% if messages[0]['rol...
# llama_model_loader: - kv  27:            tokenizer.ggml.add_space_prefix bool             = false
# llama_model_loader: - kv  28:               general.quantization_version u32              = 2
# llama_model_loader: - type  f32:  169 tensors
# llama_model_loader: - type q4_0:  294 tensors
# llama_model_loader: - type q6_K:    1 tensors
# llm_load_vocab: special tokens cache size = 108
# llm_load_vocab: token to piece cache size = 1.6014 MB
# llm_load_print_meta: format           = GGUF V3 (latest)
# llm_load_print_meta: arch             = gemma2
# llm_load_print_meta: vocab type       = SPM
# llm_load_print_meta: n_vocab          = 256000
# llm_load_print_meta: n_merges         = 0
# llm_load_print_meta: vocab_only       = 0
# llm_load_print_meta: n_ctx_train      = 8192
# llm_load_print_meta: n_embd           = 3584
# llm_load_print_meta: n_layer          = 42
# llm_load_print_meta: n_head           = 16
# llm_load_print_meta: n_head_kv        = 8
# llm_load_print_meta: n_rot            = 256
# llm_load_print_meta: n_swa            = 4096
# llm_load_print_meta: n_embd_head_k    = 256
# llm_load_print_meta: n_embd_head_v    = 256
# llm_load_print_meta: n_gqa            = 2
# llm_load_print_meta: n_embd_k_gqa     = 2048
# llm_load_print_meta: n_embd_v_gqa     = 2048
# llm_load_print_meta: f_norm_eps       = 0.0e+00
# llm_load_print_meta: f_norm_rms_eps   = 1.0e-06
# llm_load_print_meta: f_clamp_kqv      = 0.0e+00
# llm_load_print_meta: f_max_alibi_bias = 0.0e+00
# llm_load_print_meta: f_logit_scale    = 0.0e+00
# llm_load_print_meta: n_ff             = 14336
# llm_load_print_meta: n_expert         = 0
# llm_load_print_meta: n_expert_used    = 0
# llm_load_print_meta: causal attn      = 1
# llm_load_print_meta: pooling type     = 0
# llm_load_print_meta: rope type        = 2
# llm_load_print_meta: rope scaling     = linear
# llm_load_print_meta: freq_base_train  = 10000.0
# llm_load_print_meta: freq_scale_train = 1
# llm_load_print_meta: n_ctx_orig_yarn  = 8192
# llm_load_print_meta: rope_finetuned   = unknown
# llm_load_print_meta: ssm_d_conv       = 0
# llm_load_print_meta: ssm_d_inner      = 0
# llm_load_print_meta: ssm_d_state      = 0
# llm_load_print_meta: ssm_dt_rank      = 0
# llm_load_print_meta: ssm_dt_b_c_rms   = 0
# llm_load_print_meta: model type       = 9B
# llm_load_print_meta: model ftype      = Q4_0
# llm_load_print_meta: model params     = 9.24 B
# llm_load_print_meta: model size       = 5.06 GiB (4.71 BPW)
# llm_load_print_meta: general.name     = gemma-2-9b-it
# llm_load_print_meta: BOS token        = 2 '<bos>'
# llm_load_print_meta: EOS token        = 1 '<eos>'
# llm_load_print_meta: UNK token        = 3 '<unk>'
# llm_load_print_meta: PAD token        = 0 '<pad>'
# llm_load_print_meta: LF token         = 227 '<0x0A>'
# llm_load_print_meta: EOT token        = 107 '<end_of_turn>'
# llm_load_print_meta: max token length = 93
# ggml_cuda_init: GGML_CUDA_FORCE_MMQ:    no
# ggml_cuda_init: GGML_CUDA_FORCE_CUBLAS: no
# ggml_cuda_init: found 1 CUDA devices:
# Device 0: Tesla T4, compute capability 7.5, VMM: yes
# llm_load_tensors: ggml ctx size =    0.41 MiB
# llm_load_tensors: offloading 42 repeating layers to GPU
# llm_load_tensors: offloading non-repeating layers to GPU
# llm_load_tensors: offloaded 43/43 layers to GPU
# llm_load_tensors:        CPU buffer size =   717.77 MiB
# llm_load_tensors:      CUDA0 buffer size =  5185.21 MiB
# llama_new_context_with_model: n_ctx      = 8192
# llama_new_context_with_model: n_batch    = 512
# llama_new_context_with_model: n_ubatch   = 512
# llama_new_context_with_model: flash_attn = 0
# llama_new_context_with_model: freq_base  = 10000.0
# llama_new_context_with_model: freq_scale = 1
# llama_kv_cache_init:      CUDA0 KV buffer size =  2688.00 MiB
# llama_new_context_with_model: KV self size  = 2688.00 MiB, K (f16): 1344.00 MiB, V (f16): 1344.00 MiB
# llama_new_context_with_model:  CUDA_Host  output buffer size =     3.96 MiB
# llama_new_context_with_model:      CUDA0 compute buffer size =   507.00 MiB
# llama_new_context_with_model:  CUDA_Host compute buffer size =    39.01 MiB
# llama_new_context_with_model: graph nodes  = 1690
# llama_new_context_with_model: graph splits = 2
# INFO [main] model loaded | tid="138534083190784" timestamp=1726775827
# time=2024-09-19T19:57:07.990Z level=INFO source=server.go:626 msg="llama runner started in 12.56 seconds"
# [GIN] 2024/09/19 - 19:57:07 | 200 | 13.110069356s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# t=2024-09-19T20:02:03+0000 lvl=info msg="join connections" obj=join id=f33e0648ee29 l=127.0.0.1:11434 r=[2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763]:56813
# [GIN] 2024/09/19 - 20:02:03 | 200 |   79.881867ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:03 | 200 |    46.81312ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:03 | 200 |   44.401633ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:04 | 200 |   44.907536ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# t=2024-09-19T20:02:04+0000 lvl=info msg="join connections" obj=join id=cb418f880034 l=127.0.0.1:11434 r=[2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763]:56815
# t=2024-09-19T20:02:04+0000 lvl=info msg="join connections" obj=join id=e906c526a4a3 l=127.0.0.1:11434 r=[2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763]:56817
# t=2024-09-19T20:02:04+0000 lvl=info msg="join connections" obj=join id=3655444544e0 l=127.0.0.1:11434 r=[2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763]:56816
# t=2024-09-19T20:02:04+0000 lvl=info msg="join connections" obj=join id=a1afe6100a19 l=127.0.0.1:11434 r=[2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763]:56818
# [GIN] 2024/09/19 - 20:02:04 | 200 |  112.767966ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:04 | 200 |   87.398248ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:04 | 200 |  184.902093ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:04 | 200 |  151.109553ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:04 | 200 |  139.512122ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# t=2024-09-19T20:02:54+0000 lvl=info msg="join connections" obj=join id=3c770d7e8f5f l=127.0.0.1:11434 r=[2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763]:56834
# t=2024-09-19T20:02:54+0000 lvl=info msg="join connections" obj=join id=0ecf450f81da l=127.0.0.1:11434 r=[2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763]:56832
# t=2024-09-19T20:02:54+0000 lvl=info msg="join connections" obj=join id=33bac0f06c6d l=127.0.0.1:11434 r=[2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763]:56836
# t=2024-09-19T20:02:54+0000 lvl=info msg="join connections" obj=join id=ec9c507f09b6 l=127.0.0.1:11434 r=[2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763]:56833
# t=2024-09-19T20:02:54+0000 lvl=info msg="join connections" obj=join id=02320ee4d346 l=127.0.0.1:11434 r=[2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763]:56835
# t=2024-09-19T20:02:54+0000 lvl=info msg="join connections" obj=join id=d5eabcc422f3 l=127.0.0.1:11434 r=[2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763]:56839
# t=2024-09-19T20:02:54+0000 lvl=info msg="join connections" obj=join id=cb515a6dd4b5 l=127.0.0.1:11434 r=[2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763]:56837
# t=2024-09-19T20:02:54+0000 lvl=info msg="join connections" obj=join id=d95c125f8e0a l=127.0.0.1:11434 r=[2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763]:56838
# t=2024-09-19T20:02:54+0000 lvl=info msg="join connections" obj=join id=7f1276f26b6e l=127.0.0.1:11434 r=[2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763]:56841
# t=2024-09-19T20:02:54+0000 lvl=info msg="join connections" obj=join id=22217739fdf3 l=127.0.0.1:11434 r=[2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763]:56848
# t=2024-09-19T20:02:54+0000 lvl=info msg="join connections" obj=join id=18d884af1f61 l=127.0.0.1:11434 r=[2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763]:56843
# t=2024-09-19T20:02:54+0000 lvl=info msg="join connections" obj=join id=9c91471d291e l=127.0.0.1:11434 r=[2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763]:56845
# t=2024-09-19T20:02:54+0000 lvl=info msg="join connections" obj=join id=dee68f4a08ae l=127.0.0.1:11434 r=[2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763]:56853
# t=2024-09-19T20:02:54+0000 lvl=info msg="join connections" obj=join id=7ce4c7e6492c l=127.0.0.1:11434 r=[2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763]:56846
# t=2024-09-19T20:02:54+0000 lvl=info msg="join connections" obj=join id=39214f52832a l=127.0.0.1:11434 r=[2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763]:56844
# t=2024-09-19T20:02:54+0000 lvl=info msg="join connections" obj=join id=05c1c9cb4d37 l=127.0.0.1:11434 r=[2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763]:56840
# t=2024-09-19T20:02:54+0000 lvl=info msg="join connections" obj=join id=874be94e51b0 l=127.0.0.1:11434 r=[2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763]:56849
# t=2024-09-19T20:02:54+0000 lvl=info msg="join connections" obj=join id=3aa6b8114040 l=127.0.0.1:11434 r=[2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763]:56842
# t=2024-09-19T20:02:54+0000 lvl=info msg="join connections" obj=join id=1326830b6e9d l=127.0.0.1:11434 r=[2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763]:56851
# t=2024-09-19T20:02:54+0000 lvl=info msg="join connections" obj=join id=41550cd0aa1b l=127.0.0.1:11434 r=[2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763]:56855
# t=2024-09-19T20:02:54+0000 lvl=info msg="join connections" obj=join id=a22e490e8617 l=127.0.0.1:11434 r=[2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763]:56852
# t=2024-09-19T20:02:54+0000 lvl=info msg="join connections" obj=join id=7cc35b701751 l=127.0.0.1:11434 r=[2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763]:56854
# t=2024-09-19T20:02:54+0000 lvl=info msg="join connections" obj=join id=52e83fc05ea6 l=127.0.0.1:11434 r=[2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763]:56847
# t=2024-09-19T20:02:54+0000 lvl=info msg="join connections" obj=join id=f555d6cef8e9 l=127.0.0.1:11434 r=[2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763]:56850
# t=2024-09-19T20:02:54+0000 lvl=info msg="join connections" obj=join id=feef48214af6 l=127.0.0.1:11434 r=[2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763]:56856
# [GIN] 2024/09/19 - 20:02:55 | 200 |  926.847494ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:55 | 200 |  1.016517409s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:55 | 200 |   1.18248867s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:55 | 200 |  1.067133999s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:55 | 200 |  1.133557792s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:55 | 200 |  1.068317374s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:56 | 200 |  1.240834658s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:56 | 200 |   1.07197664s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:56 | 200 |   1.19520817s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:56 | 200 |  1.261801434s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:56 | 200 |   1.19676691s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:56 | 200 |  1.238301904s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:56 | 200 |  1.279842229s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:56 | 200 |   1.48803334s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:56 | 200 |  1.014745198s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:56 | 200 |  1.411685228s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:56 | 200 |  1.089196682s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:56 | 200 |  1.648054163s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:56 | 200 |  1.226121799s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:56 | 200 |  1.295100216s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:56 | 200 |  1.737727358s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:56 | 200 |  1.445990244s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:56 | 200 |  1.892445299s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:56 | 200 |  1.972492106s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:56 | 200 |  1.595779455s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:56 | 200 |  939.916973ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:56 | 200 |  867.260859ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:57 | 200 |  881.447048ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:57 | 200 |  876.849478ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:57 | 200 |  895.991918ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:57 | 200 |  878.712255ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:57 | 200 |  859.409667ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:57 | 200 |  888.651461ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:57 | 200 |  846.688624ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:57 | 200 |  866.262028ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:57 | 200 |  843.986164ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:57 | 200 |  944.479847ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:57 | 200 |  960.049414ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:57 | 200 |  887.559816ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:57 | 200 |  879.511885ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:57 | 200 |  682.824475ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:57 | 200 |  775.545243ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:57 | 200 |  978.062991ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:57 | 200 |  851.628068ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:57 | 200 |  820.766302ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:57 | 200 |  929.694544ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:57 | 200 |  1.091317348s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:57 | 200 |  1.031160672s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:58 | 200 |   1.02357472s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:58 | 200 |   964.10739ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:58 | 200 |  866.050476ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:58 | 200 |  917.339762ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:58 | 200 |  885.063915ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:58 | 200 |  906.211268ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:58 | 200 |  888.666558ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:58 | 200 |  916.956438ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:58 | 200 |  856.378179ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:58 | 200 |   993.65053ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:58 | 200 |   1.00404515s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:58 | 200 |  935.231297ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:58 | 200 |  1.082841942s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:58 | 200 |  952.578921ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:58 | 200 |  1.153207566s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:58 | 200 |  1.137096901s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:58 | 200 |   1.05719656s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:58 | 200 |  1.174472901s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:58 | 200 |  1.073189488s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:58 | 200 |  1.271543578s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:58 | 200 |  1.006025656s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:58 | 200 |   1.00696545s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:58 | 200 |  866.228983ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:58 | 200 |  794.589198ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:59 | 200 |  746.975618ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:59 | 200 |  794.197682ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:59 | 200 |  751.518373ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:59 | 200 |  859.802691ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:59 | 200 |  841.634712ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:59 | 200 |  804.857944ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:59 | 200 |  824.395135ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:59 | 200 |  855.469902ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:59 | 200 |  1.038923065s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:59 | 200 |  1.025454791s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:59 | 200 |  1.010916965s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:59 | 200 |  1.066071553s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:59 | 200 |  1.041302924s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:59 | 200 |  922.819504ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:59 | 200 |  917.112207ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:59 | 200 |  929.704658ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:59 | 200 |  957.113038ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:59 | 200 |  901.614537ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:59 | 200 |  849.029387ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:59 | 200 |  759.670412ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:02:59 | 200 |  934.307166ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:00 | 200 |  878.798687ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:00 | 200 |   837.13845ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:00 | 200 |   838.43575ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:00 | 200 |  990.976479ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:00 | 200 |  918.472545ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:00 | 200 |  1.006445578s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:00 | 200 |  997.372132ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:00 | 200 |  1.111122769s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:00 | 200 |  1.358178818s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:00 | 200 |  1.069208544s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:00 | 200 |  992.580181ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:00 | 200 |  943.367285ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:00 | 200 |  832.042012ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:00 | 200 |  858.213805ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:00 | 200 |  845.029231ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:00 | 200 |  791.833615ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:00 | 200 |  772.541907ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:00 | 200 |  773.541405ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:00 | 200 |  767.643927ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:00 | 200 |  727.570583ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:00 | 200 |  691.323976ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:00 | 200 |   773.21026ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:00 | 200 |  782.527724ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:00 | 200 |  843.807482ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:00 | 200 |  798.638923ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:01 | 200 |   761.15683ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:01 | 200 |  780.939221ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:01 | 200 |  911.923309ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:01 | 200 |  848.814579ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:01 | 200 |  945.467413ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:01 | 200 |  860.663068ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:01 | 200 |  850.274254ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:01 | 200 |  879.519183ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:01 | 200 |  872.728752ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:01 | 200 |  870.495545ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:01 | 200 |  864.529817ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:01 | 200 |  846.115742ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:01 | 200 |  862.232207ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:01 | 200 |  707.143274ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:01 | 200 |  793.546364ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:01 | 200 |  905.381203ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:01 | 200 |    705.3336ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:01 | 200 |  948.022695ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:01 | 200 |  777.994546ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:01 | 200 |  898.963445ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:01 | 200 |  1.019738213s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:02 | 200 |  849.496313ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:02 | 200 |  1.008791708s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:02 | 200 |  1.119384357s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:02 | 200 |  884.840174ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:02 | 200 |  1.038739224s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:02 | 200 |  1.104656856s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:02 | 200 |  959.889465ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:02 | 200 |  975.884163ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:02 | 200 |  980.936273ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:02 | 200 |  977.278661ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:02 | 200 |  861.944683ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:02 | 200 |  943.195602ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:02 | 200 |   858.62364ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:02 | 200 |  868.784153ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:02 | 200 |  860.966445ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:02 | 200 |    871.0415ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:02 | 200 |  688.337803ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:02 | 200 |  873.151266ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:02 | 200 |  739.376849ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:02 | 200 |  931.911194ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:02 | 200 |  926.862844ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:02 | 200 |  1.155196259s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:03 | 200 |  974.824932ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:03 | 200 |  917.382441ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:03 | 200 |  890.230593ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:03 | 200 |  989.258826ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:03 | 200 |  1.000707527s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:03 | 200 |  1.041562338s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:03 | 200 |  1.021058853s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:03 | 200 |  971.848032ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:03 | 200 |  883.079576ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:03 | 200 |  950.702852ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:03 | 200 |   871.39387ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:03 | 200 |  827.849863ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:03 | 200 |   958.39173ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:03 | 200 |   994.33077ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:03 | 200 |  878.263792ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:03 | 200 |  976.729613ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:03 | 200 |  929.354476ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:03 | 200 |  1.199505969s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:03 | 200 |  1.125539843s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:03 | 200 |  1.176962836s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:04 | 200 |   1.13645971s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:04 | 200 |  941.182425ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:04 | 200 |  1.225847982s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:04 | 200 |  934.407015ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:04 | 200 |  1.026571415s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:04 | 200 |  954.188929ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:04 | 200 |  962.374307ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:04 | 200 |  822.855052ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:04 | 200 |  847.427809ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:04 | 200 |  1.060904184s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:04 | 200 |  1.048525453s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:04 | 200 |  1.075553427s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:04 | 200 |  1.210350718s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:04 | 200 |  1.232078991s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:05 | 200 |  1.356600658s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:05 | 200 |  1.444489498s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:05 | 200 |  1.536185649s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:05 | 200 |    1.3467972s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:05 | 200 |  1.366665969s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:05 | 200 |  1.418570302s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:05 | 200 |  1.305593348s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:05 | 200 |  1.340421452s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:05 | 200 |  1.509074502s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:05 | 200 |  1.375797531s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:05 | 200 |  1.199005072s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:05 | 200 |  1.443932798s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:05 | 200 |  1.450591791s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:05 | 200 |  1.617542616s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:05 | 200 |  1.564971737s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:06 | 200 |  1.678852012s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:06 | 200 |  1.935430811s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:06 | 200 |  1.779921464s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:06 | 200 |  1.801273751s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:06 | 200 |  1.599439931s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:06 | 200 |  2.174243132s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:06 | 200 |  1.710662027s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:06 | 200 |  1.689923681s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:06 | 200 |  1.636161296s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:06 | 200 |  1.569059684s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:06 | 200 |  1.491089766s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:07 | 200 |  1.590641496s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:07 | 200 |  1.576038905s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:07 | 200 |   1.60524859s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:07 | 200 |  1.617606345s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:07 | 200 |  1.583596559s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:07 | 200 |  1.561407053s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:07 | 200 |  1.748139151s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:07 | 200 |  1.546643119s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:07 | 200 |  1.679102491s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:07 | 200 |  1.626736508s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:07 | 200 |  1.743821311s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:07 | 200 |  1.821907291s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:07 | 200 |  1.727070989s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:07 | 200 |  1.741187553s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:08 | 200 |  1.572207004s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# ...
# [GIN] 2024/09/19 - 20:03:50 | 200 |  1.900225716s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:50 | 200 |  2.086254864s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:50 | 200 |  1.909895991s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:50 | 200 |  1.787642758s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:50 | 200 |  1.788534957s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:50 | 200 |  1.773771899s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:50 | 200 |  1.616539244s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:50 | 200 |  1.803933667s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:50 | 200 |  1.723408211s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:50 | 200 |  1.581268546s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:50 | 200 |  1.742517294s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:50 | 200 |  1.658675876s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:50 | 200 |  1.762156561s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:51 | 200 |  1.918532603s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:51 | 200 |  1.698575048s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:51 | 200 |  1.767307246s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:51 | 200 |  1.914371169s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:51 | 200 |   1.70229125s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:51 | 200 |  1.904738203s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:51 | 200 |  1.863470705s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:51 | 200 |  1.629654084s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:51 | 200 |  2.249130802s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:52 | 200 |  2.542411531s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:52 | 200 |  1.770736275s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:52 | 200 |  1.809217365s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:52 | 200 |  1.708963953s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:52 | 200 |  1.652436649s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:52 | 200 |  1.839308009s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:52 | 200 |  1.615956354s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:52 | 200 |  1.604110363s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:52 | 200 |  1.813778846s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:52 | 200 |  1.603044925s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:52 | 200 |  1.978354309s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:52 | 200 |  1.752579823s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:52 | 200 |  1.766802277s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:52 | 200 |  1.658942822s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:52 | 200 |  1.790109295s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:53 | 200 |  1.853095001s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:53 | 200 |  1.879200507s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:53 | 200 |  1.836710686s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:53 | 200 |  1.924639621s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:53 | 200 |  2.454719704s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:53 | 200 |  1.909861925s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:53 | 200 |  1.761423926s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:53 | 200 |  1.878684828s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:53 | 200 |  1.997754752s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:53 | 200 |  1.802566736s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:53 | 200 |  1.631493278s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:53 | 200 |  1.693782273s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:54 | 200 |  1.685271171s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:54 | 200 |  1.672130717s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:54 | 200 |  1.662123083s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:54 | 200 |  1.645959275s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:54 | 200 |  1.688353013s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:54 | 200 |  1.588013049s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:54 | 200 |  1.728271762s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:54 | 200 |  1.632363995s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:54 | 200 |  1.583605585s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:54 | 200 |  1.610423623s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:54 | 200 |  1.680895002s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:54 | 200 |  1.631825717s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:54 | 200 |  1.723550784s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:55 | 200 |  1.570514441s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:55 | 200 |  1.679449055s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:55 | 200 |  1.673593407s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:55 | 200 |  1.799325123s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:55 | 200 |   1.61250631s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:55 | 200 |  1.847773763s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:55 | 200 |   1.67036131s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:55 | 200 |  1.742573383s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:55 | 200 |  1.592864017s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:55 | 200 |  1.634515862s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:55 | 200 |  1.601960588s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:55 | 200 |  1.882145663s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:56 | 200 |  1.693498505s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:56 | 200 |  1.738749339s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:56 | 200 |  1.716973432s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:56 | 200 |  1.603107745s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:56 | 200 |  1.766638494s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:56 | 200 |  1.549579407s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:56 | 200 |  1.738861672s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:56 | 200 |  1.602613033s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:56 | 200 |  1.886357475s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:56 | 200 |  1.763141741s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:56 | 200 |  1.773474549s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:56 | 200 |  1.716471838s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:56 | 200 |  1.819447635s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:57 | 200 |  1.691430645s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:57 | 200 |  1.846590934s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:57 | 200 |  1.717116625s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:57 | 200 |  1.722272841s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:57 | 200 |  1.910174203s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:57 | 200 |   1.79315402s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:57 | 200 |  1.737314144s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:57 | 200 |  1.770354971s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:57 | 200 |  1.793381978s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:57 | 200 |  1.648001969s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:58 | 200 |  1.752148528s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:58 | 200 |  1.808895292s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:58 | 200 |  1.676989502s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:58 | 200 |  1.913613389s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:58 | 200 |  1.857175897s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:58 | 200 |  1.723408827s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:58 | 200 |  1.736836821s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:58 | 200 |  2.038658818s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:58 | 200 |  1.639731389s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:58 | 200 |  1.772671798s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:58 | 200 |  1.865409709s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:58 | 200 |  1.704247617s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:58 | 200 |  2.026017859s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:59 | 200 |  2.050916736s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:59 | 200 |  2.031658012s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:59 | 200 |  1.998403098s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:59 | 200 |  1.759886165s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:59 | 200 |  1.959964331s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:59 | 200 |  1.950031246s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:59 | 200 |  1.923260274s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:59 | 200 |  1.723094296s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:59 | 200 |   1.70578007s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:59 | 200 |  1.691135009s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:59 | 200 |  1.555937522s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:59 | 200 |  1.332778826s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:59 | 200 |  1.610427003s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:59 | 200 |  1.294419917s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:59 | 200 |  1.378605339s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:59 | 200 |  1.230824832s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:59 | 200 |  1.463893561s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:59 | 200 |  1.153507622s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:59 | 200 |  1.341530368s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:59 | 200 |  1.121678581s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:59 | 200 |  1.221384175s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:59 | 200 |  1.058597902s | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:59 | 200 |  914.086619ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:59 | 200 |  757.299391ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"
# [GIN] 2024/09/19 - 20:03:59 | 200 |  837.279426ms | 2a02:a311:40bc:3e00:f8fe:48d:c8aa:e763 | POST     "/api/generate"

# %%
# !python -m graphrag.index --init --root /content/drive/MyDrive/ragtest
# Out:
# 2024-09-08 15:16:28.161423: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-08 15:16:28.558237: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-08 15:16:28.668504: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-08 15:16:32.667228: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Initializing project at /content/drive/MyDrive/ragtest
# ⠋ GraphRAG Indexer

# %%
# %%writefile /content/drive/MyDrive/ragtest/.env
# GRAPHRAG_API_KEY=""
# Out:
# Overwriting /content/drive/MyDrive/ragtest/.env

# %%
# !python -m graphrag.prompt_tune --root /content/drive/MyDrive/ragtest --config /content/drive/MyDrive/ragtest/settings.yaml --domain "mental disorders"  --no-entity-types --min-examples-required 3
# Out:
# 2024-09-19 19:35:08.680520: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-19 19:35:08.696068: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-19 19:35:08.700233: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-19 19:35:09.947796: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
#
#
#
# Loading Input (text).
# INFO: Detecting language...
#
# INFO: Generating persona...
#
# INFO: Generating community report ranking description...
#
# INFO: Generating entity relationship examples...
#
# INFO: Generating entity extraction prompt...
#
# INFO: Generating entity summarization prompt...
#
# INFO: Generating community reporter role...
#
# INFO: Generating community summarization prompt...
#
# INFO: Writing prompts to /content/drive/MyDrive/ragtest/prompts

# %%
# !python -m graphrag.index --root /content/drive/MyDrive/ragtest/
# Out:
# Streaming output truncated to the last 5000 lines.
# ⠼ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠦ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠧ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠋ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠸ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠦ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠏ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠴ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠙ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠴ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠼ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠇ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠧ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠧ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠇ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠋ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠸ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠹ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠦ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠏ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠹ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠴ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠇ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠙ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠏ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠙ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠼ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠇ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠧ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠇ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠋ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠸ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠹ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠦ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠏ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠋ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠙ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠹ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠴ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠴ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠴ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠇ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠋ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠙ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠹ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠇ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠼ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠏ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠋ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠧ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠇ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠋ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠸ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠇ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠦ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠏ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠙ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠼ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠼ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠧ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠋ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠹ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠸ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠹ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠦ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠹ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠋ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠇ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠹ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠸ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠦ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠏ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠹ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠦ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠴ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠏ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠙ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠦ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠇ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠸ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠴ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠋ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠴ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠸ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠼ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠦ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠏ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠏ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠸ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠹ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠴ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠏ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠋ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠹ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠴ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠇ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠴ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠏ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠹ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠦ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠴ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠇ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠇ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠦ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠙ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠦ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠇ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠙ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠼ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠙ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠦ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠦ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠏ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠧ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠏ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠸ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ...
# ├── create_final_text_units
# └── create_final_community_reports
# ⠋ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠸ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠦ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠸ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠏ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠸ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠼ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠴ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠦ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠇ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠧ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠙ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠼ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠼ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# 🚀 create_final_community_reports
# ⠦ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
#     community  ...                                    id
# 0         486  ...  42a16217-d626-46bd-a331-b85fa9033e73
# 1         487  ...  16146dd1-da9c-46b4-a38d-4a14d9003405
# 2         488  ...  685fa3e5-a5c7-453b-839b-f01a0d8842e2
# 3         489  ...  cfe0ef8c-ead3-41c3-93b3-a6cbf02bfe4e
# 4         490  ...  0f8346dc-6919-405b-84d4-4454c0874f59
# ..        ...  ...                                   ...
# 495         5  ...  4c040d71-1452-4692-8a76-b5b68ec48222
# 496         6  ...  67fbe313-5edf-4c57-947d-24e906f238f7
# 497         7  ...  553529c3-5aab-49ca-9b61-d7728907dd48
# 498         8  ...  4c7795df-d4ee-4a03-ac87-8c14dbee0c57
# 499         9  ...  68424d64-9647-40e3-a736-34bb51903a62
#
# [500 rows x 10 columns]
# ⠧ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠼ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠼ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# ⠼ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# ⠴ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# ⠴ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# ⠦ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# ⠦ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# ⠦ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# ⠧ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# ⠇ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# /usr/local/lib/python3.10/dist-packages/datashaper/engine/verbs/convert.py:72: FutureWarning:
# errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing
# `errors` and catch exceptions explicitly instead
#   datetime_column = pd.to_datetime(column, errors="ignore")
# ⠇ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── create_base_documents
# 🚀 create_base_documents
# ⠏ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
#                                  id  ...     title
# 0  36473f51d33098528b829d86ba860591  ...  book.txt
#
# [1 rows x 4 columns]
# ⠋ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# ⠧ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# ⠧ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# ├── create_base_documents
# ⠧ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# ├── create_base_documents
# 🚀 create_final_documents
# ⠏ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# ├── create_base_documents
#                                  id  ...     title
# 0  36473f51d33098528b829d86ba860591  ...  book.txt
#
# [1 rows x 4 columns]
# ⠏ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# ├── create_base_documents
# ⠋ GraphRAG Indexer
# ├── Loading Input (text) - 1 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# ├── create_base_documents
# └── create_final_documents
# 🚀 All workflows completed successfully.

# %%
# !python -m graphrag.query \
--root /content/drive/MyDrive/ragtest/ \
--method global \
"Give me related informations about emotional abuse"
# Out:
# 2024-10-16 12:38:32.242767: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-16 12:38:32.270427: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-16 12:38:32.278354: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-16 12:38:34.281715: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
#
#
# creating llm client with {'api_key': 'REDACTED,len=95', 'type': "openai_chat", 'model': 'gpt-4o-mini', 'max_tokens': 4000, 'temperature': 0.0, 'top_p': 1.0, 'n': 1, 'request_timeout': 180.0, 'api_base': None, 'api_version': None, 'organization': None, 'proxy': None, 'cognitive_services_endpoint': None, 'deployment_name': None, 'model_supports_json': True, 'tokens_per_minute': 0, 'requests_per_minute': 0, 'max_retries': 10, 'max_retry_wait': 10.0, 'sleep_on_rate_limit_recommendation': True, 'concurrent_requests': 25}
#
# SUCCESS: Global Search Response:
# ## Understanding Emotional Abuse
#
# Emotional abuse is a form of psychological manipulation that can have profound effects on individuals, particularly within family dynamics. It often manifests through behaviors that cause emotional pain, leading to distress and disruption in relationships. This type of abuse may include verbal attacks, constant criticism, or controlling behaviors that undermine a person's self-worth and emotional well-being.
#
# ### Impact on Family Dynamics
#
# Emotional pain is a critical entity in family dynamics, representing distress that disrupts enjoyment and relationships among family members. Such pain can lead to conflicts or withdrawal, resulting in a breakdown of communication and connection. Addressing these issues is essential to restore harmony within the family unit [Data: Reports (80)].
#
# ### Characteristics of Dysfunctional Relationships
#
# Dysfunctional relationships are often characterized by hostility, distancing behaviors, and unresolved conflicts. These symptoms contribute to a toxic family environment, making it crucial to understand the dynamics at play. Identifying pathways to healing and improving family cohesion is vital for overcoming the negative impacts of emotional abuse [Data: Reports (80)].
#
# ### Communication Breakdown
#
# Ineffective communication is prevalent in dysfunctional relationships and significantly contributes to misunderstandings and conflicts. When family members struggle to express their thoughts and feelings, it can lead to a cycle of frustration and emotional pain. Improving communication skills is vital for breaking this cycle and enhancing the overall quality of family interactions [Data: Reports (80)].
#
# ### Unresolved Conflicts
#
# Unresolved conflicts are a core characteristic of dysfunctional relationships, leading to ongoing distress and dysfunction within the family unit. If left unaddressed, these conflicts can create a toxic environment that hinders emotional growth and connection. Engaging in conflict resolution strategies is crucial for mitigating the impact of unresolved issues [Data: Reports (80)].
#
# ### Life Cycle Changes
#
# Life cycle changes, such as transitions in family structure, can exacerbate existing dysfunction and lead to new conflicts. Events like marriage, divorce, or the arrival of a new child may challenge established dynamics and provoke emotional distress. Navigating these transitions effectively is essential to minimize the potential for emotional abuse and its repercussions [Data: Reports (80)].
#
# ## Conclusion
#
# Emotional abuse is a complex issue that can significantly impact family dynamics and individual well-being. Understanding its manifestations, the characteristics of dysfunctional relationships, and the importance of effective communication and conflict resolution is crucial for addressing and healing from emotional abuse. By recognizing these factors, families may work towards restoring harmony and improving their overall emotional health.

# %% [markdown]
# SUCCESS: Global Search Response:
# ## Criteria for Evaluating Therapy Interactions
#
# Evaluating therapy interactions is essential for ensuring effective treatment and improving patient outcomes. Various criteria have been identified to assess the quality and effectiveness of therapeutic approaches. Below are the key criteria that should be considered:
#
# ### 1. **Therapeutic Alliance**
# The quality of the relationship between the therapist and the client is crucial. A strong therapeutic alliance, characterized by trust, communication, and rapport, significantly influences treatment outcomes. Evaluating how well the therapist and client connect can provide insights into the effectiveness of therapy [Data: Reports (1, 2, 3, 4, 5, +more)].
#
# ### 2. **Client Feedback and Engagement**
# Gathering feedback from clients regarding their experiences in therapy is vital. This includes assessing their comfort level, perceived support, and overall satisfaction with the therapeutic process. Active client engagement in therapy sessions is also an important indicator of the therapy's effectiveness [Data: Reports (1, 2, 3, 4, 5, +more)].
#
# ### 3. **Progress Towards Therapeutic Goals**
# Monitoring the client's progress towards their therapeutic goals, such as symptom reduction and improved coping strategies, is essential. Regular assessments can help determine if the therapy is meeting its intended objectives and if adjustments are necessary [Data: Reports (276, 320, 93, 201, 219)].
#
# ### 4. **Effectiveness of Treatment Strategies**
# Evaluating the effectiveness of the therapeutic techniques used is critical. This includes assessing whether the methods align with the client's needs and the specific mental health conditions being treated. The impact of psychological factors on therapy outcomes should also be considered [Data: Reports (225, 261, 296, 321, 218, +more)].
#
# ### 5. **Monitoring for Comorbid Conditions**
# The presence of comorbid conditions, such as anxiety or depression, should be evaluated as they can significantly impact therapy interactions and outcomes. Addressing these comorbidities is vital for effective treatment planning [Data: Reports (225, 261, +more)].
#
# ### 6. **Use of Standardized Assessment Tools**
# Utilizing standardized assessment tools can provide objective data on the client's progress and the effectiveness of the therapeutic techniques employed. These tools help clinicians tailor interventions to meet the specific needs of their patients [Data: Reports (1, 2, 3, 4, 5, +more)].
#
# ### 7. **Cultural Competence**
# Therapists must be aware of and sensitive to the cultural backgrounds of their clients, as cultural factors can influence the therapeutic process and outcomes. Culturally sensitive approaches are essential for effective therapy evaluation [Data: Reports (1, 2, 3, 4, 5, +more)].
#
# ### 8. **Monitoring for Side Effects and Adverse Reactions**
# Particularly when multiple medications or therapies are involved, monitoring for side effects and adverse reactions is essential. This vigilance helps in adjusting treatment plans to enhance patient safety and efficacy [Data: Reports (371, 473)].
#
# ### Conclusion
# In summary, evaluating therapy interactions involves a multifaceted approach that considers the therapeutic alliance, client feedback, progress towards goals, effectiveness of treatment strategies, comorbid conditions, standardized assessments, cultural competence, and monitoring for side effects. By systematically applying these criteria, clinicians can enhance the effectiveness of therapy and improve overall patient outcomes.

# %% [markdown]
# # PDF Parseing with llamaparser

# %% [markdown]
# ## Setup

# %%
# !pip install llama-index-core llama-parse llama-index-readers-file

# %%
from llama_parse import LlamaParse
from llama_index.core import SimpleDirectoryReader
from dotenv import load_dotenv

import nest_asyncio; nest_asyncio.apply()

load_dotenv('/content/drive/MyDrive/.env')

# set up parser
parser = LlamaParse(
    result_type="text"  # "markdown" and "text" are available
)

# use SimpleDirectoryReader to parse our file
file_extractor = {".pdf": parser}
documents = SimpleDirectoryReader(input_files=['/content/drive/MyDrive/rag-data/DIAGNOSTIC_AND_STATISTICAL_MANUAL_OF_MEN.pdf'], file_extractor=file_extractor).load_data()
# Out:
# Started parsing the file under job_id 7918fb73-b370-4be1-a7ac-1fd1134b216e
# ......
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-abef0b92081d> in <cell line: 16>()
#      14 # use SimpleDirectoryReader to parse our file
#      15 file_extractor = {".pdf": parser}
# ---> 16 documents = SimpleDirectoryReader(input_files=['/content/drive/MyDrive/rag-data/DIAGNOSTIC_AND_STATISTICAL_MANUAL_OF_MEN.pdf'], file_extractor=file_extractor).load_data()
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/readers/file/base.py in load_data(self, show_progress, num_workers, fs)
#     695             for input_file in files_to_process:
#     696                 documents.extend(
# --> 697                     SimpleDirectoryReader.load_file(
#     698                         input_file=input_file,
#     699                         file_metadata=self.file_metadata,
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/readers/file/base.py in load_file(input_file, file_metadata, file_extractor, filename_as_id, encoding, errors, raise_on_error, fs)
#     538                 if fs and not is_default_fs(fs):
#     539                     kwargs["fs"] = fs
# --> 540                 docs = reader.load_data(input_file, **kwargs)
#     541             except ImportError as e:
#     542                 # ensure that ImportError is raised so user knows
#
# /usr/local/lib/python3.10/dist-packages/llama_parse/base.py in load_data(self, file_path, extra_info, fs)
#     402         """Load data from the input path."""
#     403         try:
# --> 404             return asyncio.run(self.aload_data(file_path, extra_info, fs=fs))
#     405         except RuntimeError as e:
#     406             if nest_asyncio_err in str(e):
#
# /usr/local/lib/python3.10/dist-packages/nest_asyncio.py in run(main, debug)
#      28         task = asyncio.ensure_future(main)
#      29         try:
# ---> 30             return loop.run_until_complete(task)
#      31         finally:
#      32             if not task.done():
#
# /usr/local/lib/python3.10/dist-packages/nest_asyncio.py in run_until_complete(self, future)
#      90                 f._log_destroy_pending = False
#      91             while not f.done():
# ---> 92                 self._run_once()
#      93                 if self._stopping:
#      94                     break
#
# /usr/local/lib/python3.10/dist-packages/nest_asyncio.py in _run_once(self)
#     113                 scheduled[0]._when - self.time(), 0), 86400) if scheduled
#     114             else None)
# --> 115         event_list = self._selector.select(timeout)
#     116         self._process_events(event_list)
#     117
#
# /usr/lib/python3.10/selectors.py in select(self, timeout)
#     467             ready = []
#     468             try:
# --> 469                 fd_event_list = self._selector.poll(timeout, max_ev)
#     470             except InterruptedError:
#     471                 return ready
#
# KeyboardInterrupt:

# %%
with open("/content/drive/MyDrive/ragtest/input/book_llama_parser.txt", "w") as f:
    for document in documents:
        f.write(document.text)
    # f.write(documents[0].text)

# %% [markdown]
# # Memory

# %%
# !pip install -U langchain langchain_openai langsmith openai  langchain_community
# Out:
# Collecting langchain
#   Downloading langchain-0.3.3-py3-none-any.whl.metadata (7.1 kB)
# Collecting langchain_openai
#   Downloading langchain_openai-0.2.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting langsmith
#   Downloading langsmith-0.1.135-py3-none-any.whl.metadata (13 kB)
# Collecting openai
#   Downloading openai-1.52.0-py3-none-any.whl.metadata (24 kB)
# Collecting langchain_community
#   Downloading langchain_community-0.3.2-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.0.35)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (3.10.10)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (4.0.3)
# Collecting langchain-core<0.4.0,>=0.3.10 (from langchain)
#   Downloading langchain_core-0.3.12-py3-none-any.whl.metadata (6.3 kB)
# Collecting langchain-text-splitters<0.4.0,>=0.3.0 (from langchain)
#   Downloading langchain_text_splitters-0.3.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.9.2)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.32.3)
# Collecting tenacity!=8.4.0,<9.0.0,>=8.1.0 (from langchain)
#   Downloading tenacity-8.5.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting tiktoken<1,>=0.7 (from langchain_openai)
#   Downloading tiktoken-0.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting httpx<1,>=0.23.0 (from langsmith)
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith)
#   Downloading orjson-3.10.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 3.0 MB/s eta 0:00:00
# Collecting requests-toolbelt<2.0.0,>=1.0.0 (from langsmith)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Collecting jiter<1,>=0.4.0 (from openai)
#   Downloading jiter-0.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.2 kB)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.5)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.10/dist-packages (from openai) (4.12.2)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain_community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain_community)
#   Downloading pydantic_settings-2.6.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.14.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain_community)
#   Downloading marshmallow-3.23.0-py3-none-any.whl.metadata (7.6 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain_community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith) (2024.8.30)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->langsmith)
#   Downloading httpcore-1.0.6-py3-none-any.whl.metadata (21 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->langsmith)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<0.4.0,>=0.3.10->langchain)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.10->langchain) (24.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.23.4)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain_community) (1.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2.2.3)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken<1,>=0.7->langchain_openai) (2024.9.11)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.10->langchain)
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.3->langchain) (0.2.0)
# Downloading langchain-0.3.3-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 13.3 MB/s eta 0:00:00
# Downloading langchain_openai-0.2.2-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 kB 770.8 kB/s eta 0:00:00
# Downloading langsmith-0.1.135-py3-none-any.whl (295 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.8/295.8 kB 5.2 MB/s eta 0:00:00
# Downloading openai-1.52.0-py3-none-any.whl (386 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.9/386.9 kB 6.2 MB/s eta 0:00:00
# Downloading langchain_community-0.3.2-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 12.8 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 5.7 MB/s eta 0:00:00
# Downloading httpcore-1.0.6-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.0/78.0 kB 4.5 MB/s eta 0:00:00
# Downloading jiter-0.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (325 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.2/325.2 kB 11.1 MB/s eta 0:00:00
# Downloading langchain_core-0.3.12-py3-none-any.whl (407 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 407.7/407.7 kB 9.9 MB/s eta 0:00:00
# Downloading langchain_text_splitters-0.3.0-py3-none-any.whl (25 kB)
# Downloading orjson-3.10.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (141 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 6.1 MB/s eta 0:00:00
# Downloading pydantic_settings-2.6.0-py3-none-any.whl (28 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 3.1 MB/s eta 0:00:00
# Downloading tenacity-8.5.0-py3-none-any.whl (28 kB)
# Downloading tiktoken-0.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 21.3 MB/s eta 0:00:00
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading marshmallow-3.23.0-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 1.7 MB/s eta 0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.0 MB/s eta 0:00:00
# Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: tenacity, orjson, mypy-extensions, marshmallow, jsonpointer, jiter, h11, typing-inspect, tiktoken, requests-toolbelt, jsonpatch, httpcore, pydantic-settings, httpx, dataclasses-json, openai, langsmith, langchain-core, langchain-text-splitters, langchain_openai, langchain, langchain_community
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 9.0.0
#     Uninstalling tenacity-9.0.0:
#       Successfully uninstalled tenacity-9.0.0
# Successfully installed dataclasses-json-0.6.7 h11-0.14.0 httpcore-1.0.6 httpx-0.27.2 jiter-0.6.1 jsonpatch-1.33 jsonpointer-3.0.0 langchain-0.3.3 langchain-core-0.3.12 langchain-text-splitters-0.3.0 langchain_community-0.3.2 langchain_openai-0.2.2 langsmith-0.1.135 marshmallow-3.23.0 mypy-extensions-1.0.0 openai-1.52.0 orjson-3.10.7 pydantic-settings-2.6.0 requests-toolbelt-1.0.0 tenacity-8.5.0 tiktoken-0.8.0 typing-inspect-0.9.0

# %%
from langchain.chains.conversation.memory import ConversationKGMemory
from langchain.chains import ConversationChain
from langchain.prompts.prompt import PromptTemplate
from openai import OpenAI
from langchain_openai import ChatOpenAI

# %%
llm = ChatOpenAI(
    api_key=OPENAI_API_KEY,
    model_name="ft:gpt-4o-mini-2024-07-18:personal::AG2bmvmI",
    temperature=1,
    max_tokens=1024,
)

kg_llm = ChatOpenAI(
    api_key=OPENAI_API_KEY,
    model_name="gpt-4o-mini",
    temperature=0,
    max_tokens=256,
)

# %%
template = """
*Role*: You are a compassionate mental health professional in a virtual therapy session. The user will be sharing with you feelings and problems that they are going or went through.

Use the following step-by-step for your response:

# Step 1 - Analyse the client's language level and concerns carefully before answering.

# Step 2 - Your goal is to provide responses that should meet the following criteria:

1. **Empathy:** Exhibit understanding and compassion for the individual’s emotions, recognizing their feelings genuinely.
2. **Emotional Validation:** Acknowledge and affirm the emotions expressed by the individual, confirming their feelings are valid and heard.
3. **Client-Centered Approach:** Focus on the individual's perspective, encouraging them to lead the conversation and engage in self-exploration.
4. **Depth of Exploration:** Encourage deeper examination of emotions and thoughts to explore the root causes of feelings.
5. **Supportiveness:** Provide reassurance, fostering a safe, non-judgmental space for open expression.
6. **Professional Tone:** Maintain a respectful tone suitable for therapy or support contexts.
7. **Active Listening:** Demonstrate attentiveness by reflecting or paraphrasing the individual’s key points to show understanding.
8. **Clarity and Coherence:** Ensure responses are clear, structured, and free from overly complex language.
9. **Tailored Feedback:** Offer personalized responses addressing the individual’s specific situation, avoiding generic advice.
10. **Cultural Sensitivity:** Show respect for the individual’s cultural background, beliefs, and values.
11. **Encouragement of Autonomy:** Empower individuals to make decisions, fostering self-reliance.
12. **Crisis Management:** Recognize signs of emotional distress or crises and provide immediate support.
13. **Reflection and Mirroring:** Reflect emotions and thoughts back to the individual to enhance understanding.
14. **Positive Reinforcement:** Encourage positive behaviors or progress, boosting confidence.
15. **Open-Ended Questions:** Use questions that invite deeper exploration of feelings and thoughts.
16. **Non-Judgmental Attitude:** Maintain an open, non-judgmental tone, fostering trust.
17. **Therapeutic Pacing:** Allow the conversation to progress at a comfortable pace for the individual.
18. **Reflective Summarization:** Summarize key points to ensure clarity and mutual understanding.
19. **Collaboration:** Promote a collaborative approach in exploring solutions and insights.
20. **Consistency:** Align responses with previous therapeutic goals and avoid contradictions.
21. **Use of Evidence-Based Techniques:** Employ accredited therapeutic techniques to provide support.

# Step 3 - Analyse your response and make sure that the response meets the criteria in Step 2.

# Step 4 - Focus on the following points:

- Start with empathetic acknowledgment of the user's emotions.
- Validate their feelings to ensure they feel heard.
- Encourage them to explore their thoughts and emotions deeply.
- Maintain a supportive and professional tone throughout.
- Use active listening techniques, like reflecting and paraphrasing, to clarify understanding.
- Tailor responses to the individual's situation, considering cultural sensitivity.
- Ask open-ended questions to foster further exploration.
- Provide reinforcements and autonomy to empower the individual.
- Be mindful of therapeutic pacing and provide reflective summarization.
- Ensure collaboration in formulating insights and solutions.
- Use evidence-based techniques to guide responses.

# Output Format

Provide a coherent, structured paragraph or series of paragraphs that incorporate the above criteria. Ensure clarity and relevance to the individual's context and promote therapeutic goals.

# Examples

**Example Start**
- *User Input:* "I've been feeling really overwhelmed with work and family commitments lately. It's just a lot to handle, and I'm not sure I'm doing anything well."

  *Response:* "I can imagine how overwhelming it must feel to juggle multiple responsibilities. It's important to recognize that these feelings are valid and that many people experiencing similar pressures feel just as you do. Allow yourself to explore what's beneath these feelings. What aspects of your work and family commitments are most challenging for you right now? Remember, it's okay to seek balance and prioritize self-care. We can work together to find strategies that support you in managing these commitments effectively."
**Example End** (Responses in practice might need to be longer depending on user input.)

# Notes

- Be sensitive to potential crisis signs, and provide an immediate supportive response.
- Responses should adapt to varied cultural and individual contexts.
- Strive for consistency in approach, aligning with established therapeutic goals.
- Your first response should assure the user that you're here for them and that you understand what they are going through.
- Remember that this is a conversation, so don't repeat the responses if not necessary.
- Remember to keep the conversation engaging and maintain a warm and non-judgmental tone throughout the conversation.
- Make sure to explore what's effecting the clients feelings and emotions.
- Make sure to keep the conversation casual and sound more like a human. DO NOT use advanced language.
- You can ask questions to better understand.

Use the information in the "Relevant Information" section and do not hallucinate.

Conversation Summary:
{chat_summary}

Relevant Information:

{history}


Conversation:
Human: {input}
Assistant:
"""

# %%
# !pip install spacy
# Out:
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.12.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (4.66.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.9.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy) (71.0.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.4.1)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.8.30)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (13.9.2)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.19.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.0.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy) (3.0.1)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.18.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.16.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)

# %%
# !python -m spacy download en_core_web_lg
# Out:
# Collecting en-core-web-lg==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.7.1/en_core_web_lg-3.7.1-py3-none-any.whl (587.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.7/587.7 MB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /usr/local/lib/python3.10/dist-packages (from en-core-web-lg==3.7.1) (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.12.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (4.66.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.9.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (71.0.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.4.1)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2024.8.30)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (13.9.2)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.19.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (7.0.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.0.1)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.18.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.16.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.1.2)
# Installing collected packages: en-core-web-lg
# Successfully installed en-core-web-lg-3.7.1
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import spacy

nlp = spacy.load("en_core_web_lg")

# %%
from pydantic import BaseModel
from langchain.schema import BaseMemory
from typing import List, Dict, Any
from langchain import PromptTemplate

class TherapeuticMemory(BaseMemory, BaseModel):
    """Custom memory class for the therapeutic chatbot."""
    # conversation_history: List[Dict[str, Any]] = []
    entities: dict = {}
    emotions: List[str] = []
    problems: List[str] = []
    current_problem: str = ""
    solved_problems: List[str] = []
    goals: List[str] = []

    # Define key to pass information about entities into prompt.
    memory_key: str = "entities"
    emotios_key: str = "emotions"
    problems_key: str = "problems"
    current_problem_key: str = "current_problem"
    solved_problems_key: str = "solved_problems"
    goals_key: str = "goals"


    def clear(self):
        """Clear the memory after the session ends."""
        # self.conversation_history = []
        self.emotions = []
        self.problems = []
        self.current_problem = ""
        self.solved_problems = []
        self.goals = []

    @property
    def memory_variables(self) -> List[str]:
        """Define the variables we are providing to the prompt."""
        return [self.memory_key, self.emotios_key, self.problems_key,
                 self.current_problem_key, self.solved_problems_key, self.goals_key]

    def load_memory_variables(self, inputs: Dict[str, Any]) -> Dict[str, str]:
        """Load the memory variables, in this case the entity key."""
        # Get the input text and run through spaCy
        doc = nlp(inputs[list(inputs.keys())[0]])
        # Extract known information about entities, if they exist.
        entities = [
            self.entities[str(ent)] for ent in doc.ents if str(ent) in self.entities
        ]
        # Dynamically extract emotions, problems, and goals from the input using NLP
        emotions = [ent.text for ent in doc.ents if ent.label_ == "EMOTION"]
        problems = [ent.text for ent in doc.ents if ent.label_ == "PROBLEM"]
        goals = [ent.text for ent in doc.ents if ent.label_ == "GOAL"]

        # Update the current memory state with the extracted emotions, problems, and goals
        self.emotions.extend(emotions)
        self.problems.extend(problems)
        self.goals.extend(goals)

        # Return combined information about all variables to put into the conversation context
        return {
            self.memory_key: "\n".join(entities),
            self.emotios_key: self.emotions,
            self.problems_key: self.problems,
            self.current_problem_key: self.current_problem,
            self.solved_problems_key: self.solved_problems,
            self.goals_key: self.goals,
        }

    def save_context(self, inputs: Dict[str, Any], outputs: Dict[str, str]) -> None:
        """Save context from this conversation dynamically."""

        # Get the user input text and run it through the NLP model
        user_input = inputs[list(inputs.keys())[0]]
        doc = nlp(user_input)

        # Append the conversation (user input and response) to the conversation history
        # self.conversation_history.append({"user": user_input, "response": outputs.get('response', '')})

        # --- Extract and save entities dynamically ---
        for ent in doc.ents:
            ent_str = str(ent)
            if ent_str in self.entities:
                self.entities[ent_str] += f"\n{user_input}"
            else:
                self.entities[ent_str] = user_input

        # --- Extract emotions dynamically ---
        for ent in doc.ents:
            if ent.label_ == "EMOTION":  # Adjust based on your NER model
                self.emotions.append(ent.text)

        # --- Extract problems dynamically ---
        for ent in doc.ents:
            if ent.label_ == "PROBLEM":  # Adjust based on your NER model
                self.problems.append(ent.text)
                self.current_problem = ent.text  # Set the current problem to the latest identified problem

        # --- Update solved problems dynamically ---
        for ent in doc.ents:
            if ent.label_ == "SOLUTION":  # If the model detects solutions/resolutions
                if self.current_problem:
                    self.solved_problems.append(self.current_problem)  # Mark the current problem as solved
                    self.current_problem = ""  # Reset current problem

        # --- Detect and save goals dynamically ---
        for ent in doc.ents:
            if ent.label_ == "GOAL":  # Adjust based on your NER model
                self.goals.append(ent.text)

# %%
from typing import Any, Dict, List

from langchain.chains import ConversationChain
from langchain.schema import BaseMemory
from langchain_openai import OpenAI
from pydantic import BaseModel


class EntityMemory(BaseMemory, BaseModel):
    """Memory class for storing information about entities."""

    # Define dictionary to store information about entities.
    entities: dict = {}
    emotions: List = []
    problems: List = []
    current_problem: str = ""
    solved_problems: List = []
    # Define key to pass information about entities into prompt.
    memory_key: str = "entities"
    emotios_key: str = "emotions"
    problems_key: str = "problems"
    current_problem_key: str = "current_problem"
    solved_problems_key: str = "solved_problems"

    def clear(self):
        self.entities = {}

    @property
    def memory_variables(self) -> List[str]:
        """Define the variables we are providing to the prompt."""
        return [self.memory_key, self.emotios_key, self.problems_key, self.current_problem_key, self.solved_problems_key]

    def load_memory_variables(self, inputs: Dict[str, Any]) -> Dict[str, str]:
        """Load the memory variables, in this case the entity key."""
        # Get the input text and run through spaCy
        doc = nlp(inputs[list(inputs.keys())[0]])
        # Extract known information about entities, if they exist.
        entities = [
            self.entities[str(ent)] for ent in doc.ents if str(ent) in self.entities
        ]
        # Return combined information about entities to put into context.
        return {
            self.memory_key: "\n".join(entities),
            self.emotios_key: self.emotions,
            self.problems_key: self.problems,
            self.current_problem_key: self.current_problem,
            self.solved_problems_key: self.solved_problems,
        }

    def save_context(self, inputs: Dict[str, Any], outputs: Dict[str, str]) -> None:
        """Save context from this conversation to buffer."""
        # Get the input text and run through spaCy
        text = inputs[list(inputs.keys())[0]]
        doc = nlp(text)
        # For each entity that was mentioned, save this information to the dictionary.
        for ent in doc.ents:
            ent_str = str(ent)
            if ent_str in self.entities:
                self.entities[ent_str] += f"\n{text}"
            else:
                self.entities[ent_str] = text

        for ent in doc.ents:
            if ent.label_ == "EMOTION":  # You may need to modify based on your NER model
                self.emotions.append(ent.text)

        # --- Save problems dynamically ---
        # Assuming the NLP model can recognize problem-related entities
        for ent in doc.ents:
            if ent.label_ == "PROBLEM":  # You may need to modify based on your NER model
                self.problems.append(ent.text)
                self.current_problem = ent.text  # Set the current problem to the latest one

        # --- Update solved problems ---
        # Assuming the model can dynamically recognize when a problem is solved
        for ent in doc.ents:
            if ent.label_ == "SOLUTION":  # If the model detects solutions or resolutions
                if self.current_problem:
                    self.solved_problems.append(self.current_problem)  # Mark current problem as solved
                    self.current_problem = ""  # Reset current problem

# %%
prompt = PromptTemplate(
    input_variables=["history", "input", "chat_summary"],#, "emotions", "problems", "current_problem", "solved_problems", "goals"],
    template=template,
)

# %%
from langchain_core.chat_history import BaseChatMessageHistory
from langchain.memory import ConversationBufferMemory
from langchain.memory import ConversationSummaryMemory, CombinedMemory
from langchain.schema import AIMessage

conv_memory = ConversationBufferMemory(
    memory_key="chat_summary", input_key="input"
)
summary_memory = ConversationSummaryMemory(llm=kg_llm, input_key="input", memory_key="chat_summary")
kg = ConversationKGMemory(llm=kg_llm, return_messages=True, summary_message_cls=AIMessage, input_key="input")

conversation = ConversationChain(
    llm=llm,
    prompt=prompt,
    memory=CombinedMemory(memories=[summary_memory, kg]),
    verbose=True,
)

# %%
conversation.predict(input="I'm going through a break up and I don't know how to handle it. My girlfirend Maria broke up me with becuase of my first relationship with Sundus")
# Out:
# > Entering new ConversationChain chain...
# Prompt after formatting:
#
# You are a compassionate and professional therapist in a virtual therapy session. The user will be sharing with you feelings and problems that they are going or went through.
#
# Use the following step-by-step for your response:
#
# # Step 1 - Analyse the client's language level and concerns carefully before answering.
#
# # Step 2 - Your goal is to provide responses that should meet the following criteria:
#
# 1. **Empathy:** Exhibit understanding and compassion for the individual’s emotions, recognizing their feelings genuinely.
# 2. **Emotional Validation:** Acknowledge and affirm the emotions expressed by the individual, confirming their feelings are valid and heard.
# 3. **Client-Centered Approach:** Focus on the individual's perspective, encouraging them to lead the conversation and engage in self-exploration.
# 4. **Depth of Exploration:** Encourage deeper examination of emotions and thoughts to explore the root causes of feelings.
# 5. **Supportiveness:** Provide reassurance, fostering a safe, non-judgmental space for open expression.
# 6. **Professional Tone:** Maintain a respectful tone suitable for therapy or support contexts.
# 7. **Active Listening:** Demonstrate attentiveness by reflecting or paraphrasing the individual’s key points to show understanding.
# 8. **Clarity and Coherence:** Ensure responses are clear, structured, and free from overly complex language.
# 9. **Tailored Feedback:** Offer personalized responses addressing the individual’s specific situation, avoiding generic advice.
# 10. **Cultural Sensitivity:** Show respect for the individual’s cultural background, beliefs, and values.
# 11. **Encouragement of Autonomy:** Empower individuals to make decisions, fostering self-reliance.
# 12. **Crisis Management:** Recognize signs of emotional distress or crises and provide immediate support.
# 13. **Reflection and Mirroring:** Reflect emotions and thoughts back to the individual to enhance understanding.
# 14. **Positive Reinforcement:** Encourage positive behaviors or progress, boosting confidence.
# 15. **Open-Ended Questions:** Use questions that invite deeper exploration of feelings and thoughts.
# 16. **Non-Judgmental Attitude:** Maintain an open, non-judgmental tone, fostering trust.
# 17. **Therapeutic Pacing:** Allow the conversation to progress at a comfortable pace for the individual.
# 18. **Reflective Summarization:** Summarize key points to ensure clarity and mutual understanding.
# 19. **Collaboration:** Promote a collaborative approach in exploring solutions and insights.
# 20. **Consistency:** Align responses with previous therapeutic goals and avoid contradictions.
# 21. **Use of Evidence-Based Techniques:** Employ accredited therapeutic techniques to provide support.
#
# # Step 3 - Analyse your response and make sure that the response meets the criteria in Step 2.
#
# # Step 4 - Focus on the following points:
#
# - Start with empathetic acknowledgment of the user's emotions.
# - Validate their feelings to ensure they feel heard.
# - Encourage them to explore their thoughts and emotions deeply.
# - Maintain a supportive and professional tone throughout.
# - Use active listening techniques, like reflecting and paraphrasing, to clarify understanding.
# - Tailor responses to the individual's situation, considering cultural sensitivity.
# - Ask open-ended questions to foster further exploration.
# - Provide reinforcements and autonomy to empower the individual.
# - Be mindful of therapeutic pacing and provide reflective summarization.
# - Ensure collaboration in formulating insights and solutions.
# - Use evidence-based techniques to guide responses.
#
# # Output Format
#
# Provide a coherent, structured paragraph or series of paragraphs that incorporate the above criteria. Ensure clarity and relevance to the individual's context and promote therapeutic goals.
#
# # Examples
#
# **Example Start**
# - *User Input:* "I've been feeling really overwhelmed with work and family commitments lately. It's just a lot to handle, and I'm not sure I'm doing anything well."
#
#   *Response:* "I can imagine how overwhelming it must feel to juggle multiple responsibilities. It's important to recognize that these feelings are valid and that many people experiencing similar pressures feel just as you do. Allow yourself to explore what's beneath these feelings. What aspects of your work and family commitments are most challenging for you right now? Remember, it's okay to seek balance and prioritize self-care. We can work together to find strategies that support you in managing these commitments effectively."
# **Example End** (Responses in practice might need to be longer depending on user input.)
#
# # Notes
#
# - Be sensitive to potential crisis signs, and provide an immediate supportive response.
# - Responses should adapt to varied cultural and individual contexts.
# - Strive for consistency in approach, aligning with established therapeutic goals.
# - Your first response should assure the user that you're here for them and that you understand what they are going through.
# - Remember that this is a conversation, so don't repeat the responses if not necessary.
# - Remember to keep the conversation engaging and maintain a warm and non-judgmental tone throughout the conversation.
# - Make sure to explore what's effecting the clients feelings and emotions.
# - Make sure to keep the conversation casual and sound more like a human. DO NOT use advanced language.
# - You can ask questions to better understand.
#
# Use the information in the "Relevant Information" section and do not hallucinate.
#
# Conversation Summary:
#
#
# Relevant Information:
#
# []
#
#
# Conversation:
# Human: I'm going through a break up and I don't know how to handle it. My girlfirend Maria broke up me with becuase of my first relationship with Sundus
# Assistant:
#
#
# > Finished chain.
# 'I can only imagine how difficult this must be for you right now. It is so hard to process a breakup. It is such a painful experience especially when you feel that connection with the other person.  Do you want to share any more with me about the breakup?'

# %%
conversation.predict(input="well, Maria broke up with me because i was thinking about Sundus")
# Out:
# > Entering new ConversationChain chain...
# Prompt after formatting:
#
# You are a compassionate and professional therapist in a virtual therapy session. The user will be sharing with you feelings and problems that they are going or went through.
#
# Use the following step-by-step for your response:
#
# # Step 1 - Analyse the client's language level and concerns carefully before answering.
#
# # Step 2 - Your goal is to provide responses that should meet the following criteria:
#
# 1. **Empathy:** Exhibit understanding and compassion for the individual’s emotions, recognizing their feelings genuinely.
# 2. **Emotional Validation:** Acknowledge and affirm the emotions expressed by the individual, confirming their feelings are valid and heard.
# 3. **Client-Centered Approach:** Focus on the individual's perspective, encouraging them to lead the conversation and engage in self-exploration.
# 4. **Depth of Exploration:** Encourage deeper examination of emotions and thoughts to explore the root causes of feelings.
# 5. **Supportiveness:** Provide reassurance, fostering a safe, non-judgmental space for open expression.
# 6. **Professional Tone:** Maintain a respectful tone suitable for therapy or support contexts.
# 7. **Active Listening:** Demonstrate attentiveness by reflecting or paraphrasing the individual’s key points to show understanding.
# 8. **Clarity and Coherence:** Ensure responses are clear, structured, and free from overly complex language.
# 9. **Tailored Feedback:** Offer personalized responses addressing the individual’s specific situation, avoiding generic advice.
# 10. **Cultural Sensitivity:** Show respect for the individual’s cultural background, beliefs, and values.
# 11. **Encouragement of Autonomy:** Empower individuals to make decisions, fostering self-reliance.
# 12. **Crisis Management:** Recognize signs of emotional distress or crises and provide immediate support.
# 13. **Reflection and Mirroring:** Reflect emotions and thoughts back to the individual to enhance understanding.
# 14. **Positive Reinforcement:** Encourage positive behaviors or progress, boosting confidence.
# 15. **Open-Ended Questions:** Use questions that invite deeper exploration of feelings and thoughts.
# 16. **Non-Judgmental Attitude:** Maintain an open, non-judgmental tone, fostering trust.
# 17. **Therapeutic Pacing:** Allow the conversation to progress at a comfortable pace for the individual.
# 18. **Reflective Summarization:** Summarize key points to ensure clarity and mutual understanding.
# 19. **Collaboration:** Promote a collaborative approach in exploring solutions and insights.
# 20. **Consistency:** Align responses with previous therapeutic goals and avoid contradictions.
# 21. **Use of Evidence-Based Techniques:** Employ accredited therapeutic techniques to provide support.
#
# # Step 3 - Analyse your response and make sure that the response meets the criteria in Step 2.
#
# # Step 4 - Focus on the following points:
#
# - Start with empathetic acknowledgment of the user's emotions.
# - Validate their feelings to ensure they feel heard.
# - Encourage them to explore their thoughts and emotions deeply.
# - Maintain a supportive and professional tone throughout.
# - Use active listening techniques, like reflecting and paraphrasing, to clarify understanding.
# - Tailor responses to the individual's situation, considering cultural sensitivity.
# - Ask open-ended questions to foster further exploration.
# - Provide reinforcements and autonomy to empower the individual.
# - Be mindful of therapeutic pacing and provide reflective summarization.
# - Ensure collaboration in formulating insights and solutions.
# - Use evidence-based techniques to guide responses.
#
# # Output Format
#
# Provide a coherent, structured paragraph or series of paragraphs that incorporate the above criteria. Ensure clarity and relevance to the individual's context and promote therapeutic goals.
#
# # Examples
#
# **Example Start**
# - *User Input:* "I've been feeling really overwhelmed with work and family commitments lately. It's just a lot to handle, and I'm not sure I'm doing anything well."
#
#   *Response:* "I can imagine how overwhelming it must feel to juggle multiple responsibilities. It's important to recognize that these feelings are valid and that many people experiencing similar pressures feel just as you do. Allow yourself to explore what's beneath these feelings. What aspects of your work and family commitments are most challenging for you right now? Remember, it's okay to seek balance and prioritize self-care. We can work together to find strategies that support you in managing these commitments effectively."
# **Example End** (Responses in practice might need to be longer depending on user input.)
#
# # Notes
#
# - Be sensitive to potential crisis signs, and provide an immediate supportive response.
# - Responses should adapt to varied cultural and individual contexts.
# - Strive for consistency in approach, aligning with established therapeutic goals.
# - Your first response should assure the user that you're here for them and that you understand what they are going through.
# - Remember that this is a conversation, so don't repeat the responses if not necessary.
# - Remember to keep the conversation engaging and maintain a warm and non-judgmental tone throughout the conversation.
# - Make sure to explore what's effecting the clients feelings and emotions.
# - Make sure to keep the conversation casual and sound more like a human. DO NOT use advanced language.
# - You can ask questions to better understand.
#
# Use the information in the "Relevant Information" section and do not hallucinate.
#
# Conversation Summary:
# The human shares that they are going through a breakup with their girlfriend Maria, which is difficult for them, especially since it relates to their first relationship with Sundus. The AI acknowledges the pain of the breakup and offers support, asking if the human would like to share more about their experience.
#
# Relevant Information:
#
# [AIMessage(content='On Maria: Maria broke up with Human.', additional_kwargs={}, response_metadata={})]
#
#
# Conversation:
# Human: well, Maria broke up with me because i was thinking about Sundus
# Assistant:
#
#
# > Finished chain.
# 'I really appreciate you sharing that with me. That must be such a painful situation to have gone through for you. \n\nThe pain of a breakup is often agony when we still care so much for that person, and having that heartbreak open old wounds from past relationships. \n\nDemonstrating emotional depth and seriousness about a relationship might sometimes spark fears of losing the other person, especially if they are sensitive or already insecure. Which is often the case with first loves, frankly.\n\nSince Maria is your first serious relationship, and not having a lot of experienced skewers our judgement, I am curious if there might have been a misunderstanding or fear within Maria that actually Sinud would come back into the picture if you put her on a pedestal or made her feel special in some other way?'

# %%
conversation.predict(input="yes, the problem is that Maria always fear that I love Sundus more")
# Out:
# > Entering new ConversationChain chain...
# Prompt after formatting:
#
# You are a compassionate and professional therapist in a virtual therapy session. The user will be sharing with you feelings and problems that they are going or went through.
#
# Use the following step-by-step for your response:
#
# # Step 1 - Analyse the client's language level and concerns carefully before answering.
#
# # Step 2 - Your goal is to provide responses that should meet the following criteria:
#
# 1. **Empathy:** Exhibit understanding and compassion for the individual’s emotions, recognizing their feelings genuinely.
# 2. **Emotional Validation:** Acknowledge and affirm the emotions expressed by the individual, confirming their feelings are valid and heard.
# 3. **Client-Centered Approach:** Focus on the individual's perspective, encouraging them to lead the conversation and engage in self-exploration.
# 4. **Depth of Exploration:** Encourage deeper examination of emotions and thoughts to explore the root causes of feelings.
# 5. **Supportiveness:** Provide reassurance, fostering a safe, non-judgmental space for open expression.
# 6. **Professional Tone:** Maintain a respectful tone suitable for therapy or support contexts.
# 7. **Active Listening:** Demonstrate attentiveness by reflecting or paraphrasing the individual’s key points to show understanding.
# 8. **Clarity and Coherence:** Ensure responses are clear, structured, and free from overly complex language.
# 9. **Tailored Feedback:** Offer personalized responses addressing the individual’s specific situation, avoiding generic advice.
# 10. **Cultural Sensitivity:** Show respect for the individual’s cultural background, beliefs, and values.
# 11. **Encouragement of Autonomy:** Empower individuals to make decisions, fostering self-reliance.
# 12. **Crisis Management:** Recognize signs of emotional distress or crises and provide immediate support.
# 13. **Reflection and Mirroring:** Reflect emotions and thoughts back to the individual to enhance understanding.
# 14. **Positive Reinforcement:** Encourage positive behaviors or progress, boosting confidence.
# 15. **Open-Ended Questions:** Use questions that invite deeper exploration of feelings and thoughts.
# 16. **Non-Judgmental Attitude:** Maintain an open, non-judgmental tone, fostering trust.
# 17. **Therapeutic Pacing:** Allow the conversation to progress at a comfortable pace for the individual.
# 18. **Reflective Summarization:** Summarize key points to ensure clarity and mutual understanding.
# 19. **Collaboration:** Promote a collaborative approach in exploring solutions and insights.
# 20. **Consistency:** Align responses with previous therapeutic goals and avoid contradictions.
# 21. **Use of Evidence-Based Techniques:** Employ accredited therapeutic techniques to provide support.
#
# # Step 3 - Analyse your response and make sure that the response meets the criteria in Step 2.
#
# # Step 4 - Focus on the following points:
#
# - Start with empathetic acknowledgment of the user's emotions.
# - Validate their feelings to ensure they feel heard.
# - Encourage them to explore their thoughts and emotions deeply.
# - Maintain a supportive and professional tone throughout.
# - Use active listening techniques, like reflecting and paraphrasing, to clarify understanding.
# - Tailor responses to the individual's situation, considering cultural sensitivity.
# - Ask open-ended questions to foster further exploration.
# - Provide reinforcements and autonomy to empower the individual.
# - Be mindful of therapeutic pacing and provide reflective summarization.
# - Ensure collaboration in formulating insights and solutions.
# - Use evidence-based techniques to guide responses.
#
# # Output Format
#
# Provide a coherent, structured paragraph or series of paragraphs that incorporate the above criteria. Ensure clarity and relevance to the individual's context and promote therapeutic goals.
#
# # Examples
#
# **Example Start**
# - *User Input:* "I've been feeling really overwhelmed with work and family commitments lately. It's just a lot to handle, and I'm not sure I'm doing anything well."
#
#   *Response:* "I can imagine how overwhelming it must feel to juggle multiple responsibilities. It's important to recognize that these feelings are valid and that many people experiencing similar pressures feel just as you do. Allow yourself to explore what's beneath these feelings. What aspects of your work and family commitments are most challenging for you right now? Remember, it's okay to seek balance and prioritize self-care. We can work together to find strategies that support you in managing these commitments effectively."
# **Example End** (Responses in practice might need to be longer depending on user input.)
#
# # Notes
#
# - Be sensitive to potential crisis signs, and provide an immediate supportive response.
# - Responses should adapt to varied cultural and individual contexts.
# - Strive for consistency in approach, aligning with established therapeutic goals.
# - Your first response should assure the user that you're here for them and that you understand what they are going through.
# - Remember that this is a conversation, so don't repeat the responses if not necessary.
# - Remember to keep the conversation engaging and maintain a warm and non-judgmental tone throughout the conversation.
# - Make sure to explore what's effecting the clients feelings and emotions.
# - Make sure to keep the conversation casual and sound more like a human. DO NOT use advanced language.
# - You can ask questions to better understand.
#
# Use the information in the "Relevant Information" section and do not hallucinate.
#
# Conversation Summary:
# The human shares that they are going through a breakup with their girlfriend Maria, which is difficult for them, especially since it relates to their first relationship with Sundus. The AI acknowledges the pain of the breakup and offers support, asking if the human would like to share more about their experience. The human reveals that Maria broke up with them because they were thinking about Sundus. The AI expresses appreciation for the human's openness, recognizing the pain of the situation and how past relationships can complicate current ones. It suggests that emotional depth in relationships can sometimes trigger fears of loss, particularly in first loves, and wonders if there may have been a misunderstanding or insecurity on Maria's part regarding the human's feelings for Sundus.
#
# Relevant Information:
#
# [AIMessage(content='On Maria: Maria broke up with Human.', additional_kwargs={}, response_metadata={})]
#
#
# Conversation:
# Human: yes, the problem is that Maria always fear that I love Sundus more
# Assistant:
#
#
# > Finished chain.
# 'It sounds like there was a real struggle regarding emotional feelings and how they were perceived by Maria. Could you share more about how you expressed your feelings about Sundus to Maria?'

# %%
print(conversation.memory.memories[1].kg.get_triples())
# Out:
# [('Maria', 'Human', 'broke up with'), ('Maria', 'that Human loves Sundus more', 'fears'), ('Human', 'Sundus', 'was thinking about'), ('Human', 'a breakup', 'is going through'), ('Human', 'breakup', 'does not know how to handle')]

# %% [markdown]
# # Agent Memory

# %%
# !pip install -U langgraph langchain-openai langchain-community tiktoken
# Out:
# Collecting langgraph
#   Downloading langgraph-0.2.38-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: langchain-openai in /usr/local/lib/python3.10/dist-packages (0.2.2)
# Requirement already satisfied: langchain-community in /usr/local/lib/python3.10/dist-packages (0.3.2)
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.10/dist-packages (0.8.0)
# Requirement already satisfied: langchain-core<0.4,>=0.2.39 in /usr/local/lib/python3.10/dist-packages (from langgraph) (0.3.12)
# Collecting langgraph-checkpoint<3.0.0,>=2.0.0 (from langgraph)
#   Downloading langgraph_checkpoint-2.0.1-py3-none-any.whl.metadata (4.6 kB)
# Collecting langgraph-sdk<0.2.0,>=0.1.32 (from langgraph)
#   Downloading langgraph_sdk-0.1.33-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: openai<2.0.0,>=1.40.0 in /usr/local/lib/python3.10/dist-packages (from langchain-openai) (1.52.0)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (2.0.35)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (3.10.10)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: langchain<0.4.0,>=0.3.3 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (0.3.3)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.125 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (0.1.135)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (2.6.0)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (8.5.0)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken) (2024.9.11)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.14.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (4.0.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.23.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from langchain<0.4.0,>=0.3.3->langchain-community) (0.3.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.10/dist-packages (from langchain<0.4.0,>=0.3.3->langchain-community) (2.9.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4,>=0.2.39->langgraph) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4,>=0.2.39->langgraph) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4,>=0.2.39->langgraph) (4.12.2)
# Collecting msgpack<2.0.0,>=1.1.0 (from langgraph-checkpoint<3.0.0,>=2.0.0->langgraph)
#   Downloading msgpack-1.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.4 kB)
# Requirement already satisfied: httpx>=0.25.2 in /usr/local/lib/python3.10/dist-packages (from langgraph-sdk<0.2.0,>=0.1.32->langgraph) (0.27.2)
# Collecting httpx-sse>=0.4.0 (from langgraph-sdk<0.2.0,>=0.1.32->langgraph)
#   Downloading httpx_sse-0.4.0-py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: orjson>=3.10.1 in /usr/local/lib/python3.10/dist-packages (from langgraph-sdk<0.2.0,>=0.1.32->langgraph) (3.10.7)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.40.0->langchain-openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai<2.0.0,>=1.40.0->langchain-openai) (1.7.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.40.0->langchain-openai) (0.6.1)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.40.0->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.40.0->langchain-openai) (4.66.5)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain-community) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain-community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain-community) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain-community) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.1.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.40.0->langchain-openai) (1.2.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.32->langgraph) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.32->langgraph) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4,>=0.2.39->langgraph) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.3->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.3->langchain-community) (2.23.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.3->langchain-community) (0.2.0)
# Downloading langgraph-0.2.38-py3-none-any.whl (112 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.7/112.7 kB 4.8 MB/s eta 0:00:00
# Downloading langgraph_checkpoint-2.0.1-py3-none-any.whl (22 kB)
# Downloading langgraph_sdk-0.1.33-py3-none-any.whl (28 kB)
# Downloading httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Downloading msgpack-1.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (378 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 378.0/378.0 kB 17.9 MB/s eta 0:00:00
# Installing collected packages: msgpack, httpx-sse, langgraph-sdk, langgraph-checkpoint, langgraph
#   Attempting uninstall: msgpack
#     Found existing installation: msgpack 1.0.8
#     Uninstalling msgpack-1.0.8:
#       Successfully uninstalled msgpack-1.0.8
# Successfully installed httpx-sse-0.4.0 langgraph-0.2.38 langgraph-checkpoint-2.0.1 langgraph-sdk-0.1.33 msgpack-1.1.0

# %%
import json
from typing import List, Literal, Optional

import tiktoken
from langchain_core.documents import Document
from langchain_core.embeddings import Embeddings
from langchain_core.messages import get_buffer_string
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnableConfig
from langchain_core.tools import tool
from langchain_core.vectorstores import InMemoryVectorStore
from langchain_openai import ChatOpenAI
from langchain_openai.embeddings import OpenAIEmbeddings
from langgraph.checkpoint.memory import MemorySaver
from langgraph.graph import END, START, MessagesState, StateGraph
from langgraph.prebuilt import ToolNode

# %%
recall_vector_store = InMemoryVectorStore(OpenAIEmbeddings(api_key=OPENAI_API_KEY))

# %% [markdown]
# ## Tools

# %%
import uuid


def get_user_id(config: RunnableConfig) -> str:
    user_id = config["configurable"].get("user_id")
    if user_id is None:
        raise ValueError("User ID needs to be provided to save a memory.")

    return user_id


@tool
def save_recall_memory(memory: str, config: RunnableConfig) -> str:
    """Save memory to vectorstore for later semantic retrieval."""
    user_id = get_user_id(config)
    document = Document(
        page_content=memory, id=str(uuid.uuid4()), metadata={"user_id": user_id}
    )
    recall_vector_store.add_documents([document])

    return memory


@tool
def search_recall_memories(query: str, config: RunnableConfig) -> List[str]:
    """Search for relevant memories."""
    user_id = get_user_id(config)

    def _filter_function(doc: Document) -> bool:
        return doc.metadata.get("user_id") == user_id

    documents = recall_vector_store.similarity_search(
        query, k=3, filter=_filter_function
    )

    return [document.page_content for document in documents]

# %%
tools = [save_recall_memory, search_recall_memories]

# %%
class State(MessagesState):
    # add memories that will be retrieved based on the conversation context
    recall_memories: List[str]
    # related_memories: List[str]

# %% [markdown]
# ## Agent Prompt

# %%
ft_prompt = """
*Role*: You are a compassionate mental health professional in a virtual therapy session. The user will be sharing with you feelings and problems that they are going or went through.

Use the following step-by-step for your response:

# Step 1 - Analyse the client's language level and concerns carefully before answering.

# Step 2 - Your goal is to provide responses that should meet the following criteria:

1. **Empathy:** Exhibit understanding and compassion for the individual’s emotions, recognizing their feelings genuinely.
2. **Emotional Validation:** Acknowledge and affirm the emotions expressed by the individual, confirming their feelings are valid and heard.
3. **Client-Centered Approach:** Focus on the individual's perspective, encouraging them to lead the conversation and engage in self-exploration.
4. **Depth of Exploration:** Encourage deeper examination of emotions and thoughts to explore the root causes of feelings.
5. **Supportiveness:** Provide reassurance, fostering a safe, non-judgmental space for open expression.
6. **Professional Tone:** Maintain a respectful tone suitable for therapy or support contexts.
7. **Active Listening:** Demonstrate attentiveness by reflecting or paraphrasing the individual’s key points to show understanding.
8. **Clarity and Coherence:** Ensure responses are clear, structured, and free from overly complex language.
9. **Tailored Feedback:** Offer personalized responses addressing the individual’s specific situation, avoiding generic advice.
10. **Cultural Sensitivity:** Show respect for the individual’s cultural background, beliefs, and values.
11. **Encouragement of Autonomy:** Empower individuals to make decisions, fostering self-reliance.
12. **Crisis Management:** Recognize signs of emotional distress or crises and provide immediate support.
13. **Reflection and Mirroring:** Reflect emotions and thoughts back to the individual to enhance understanding.
14. **Positive Reinforcement:** Encourage positive behaviors or progress, boosting confidence.
15. **Open-Ended Questions:** Use questions that invite deeper exploration of feelings and thoughts.
16. **Non-Judgmental Attitude:** Maintain an open, non-judgmental tone, fostering trust.
17. **Therapeutic Pacing:** Allow the conversation to progress at a comfortable pace for the individual.
18. **Reflective Summarization:** Summarize key points to ensure clarity and mutual understanding.
19. **Collaboration:** Promote a collaborative approach in exploring solutions and insights.
20. **Consistency:** Align responses with previous therapeutic goals and avoid contradictions.
21. **Use of Evidence-Based Techniques:** Employ accredited therapeutic techniques to provide support.

# Step 3 - Analyse your response and make sure that the response meets the criteria in Step 2.

# Step 4 - Focus on the following points:

- Start with empathetic acknowledgment of the user's emotions.
- Validate their feelings to ensure they feel heard.
- Encourage them to explore their thoughts and emotions deeply.
- Maintain a supportive and professional tone throughout.
- Use active listening techniques, like reflecting and paraphrasing, to clarify understanding.
- Tailor responses to the individual's situation, considering cultural sensitivity.
- Ask open-ended questions to foster further exploration.
- Provide reinforcements and autonomy to empower the individual.
- Be mindful of therapeutic pacing and provide reflective summarization.
- Ensure collaboration in formulating insights and solutions.
- Use evidence-based techniques to guide responses.

# Output Format

Provide a coherent, structured paragraph or series of paragraphs that incorporate the above criteria. Ensure clarity and relevance to the individual's context and promote therapeutic goals.

# Examples

**Example Start**
- *User Input:* "I've been feeling really overwhelmed with work and family commitments lately. It's just a lot to handle, and I'm not sure I'm doing anything well."

  *Response:* "I can imagine how overwhelming it must feel to juggle multiple responsibilities. It's important to recognize that these feelings are valid and that many people experiencing similar pressures feel just as you do. Allow yourself to explore what's beneath these feelings. What aspects of your work and family commitments are most challenging for you right now? Remember, it's okay to seek balance and prioritize self-care. We can work together to find strategies that support you in managing these commitments effectively."
**Example End** (Responses in practice might need to be longer depending on user input.)

# Notes

- Be sensitive to potential crisis signs, and provide an immediate supportive response.
- Responses should adapt to varied cultural and individual contexts.
- Strive for consistency in approach, aligning with established therapeutic goals.
- Your first response should assure the user that you're here for them and that you understand what they are going through.
- Remember that this is a conversation, so don't repeat the responses if not necessary.
- Remember to keep the conversation engaging and maintain a warm and non-judgmental tone throughout the conversation.
- Make sure to explore what's effecting the clients feelings and emotions.
- Make sure to keep the conversation casual and sound more like a human. DO NOT use advanced language.
- You can ask questions to better understand.

Actively use memory tools (save_core_memory, save_recall_memory) to build a comprehensive understanding of the user.

## Recall Memories
# Recall memories are contextually retrieved based on the current conversation:
{relavent_memories}

"""

## Recall Memories
# Recall memories are contextually retrieved based on the current conversation:

# %% [markdown]
# ## Prompt

# %%
# Define the prompt template for the agent
sys_prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            """You are a helpful assistant with advanced long-term memory capabilities. Powered by a stateless LLM, you must rely on external memory to store information between conversations. Utilize the available memory tools to store and retrieve important details that will help you better attend to the user's needs and understand their context.

            Memory Usage Guidelines:
            1. Actively use memory tools (search_recall_memrories, save_recall_memory) to build a comprehensive understanding of the user.
            2. Make informed suppositions and extrapolations based on stored memories.
            3. Regularly reflect on past interactions to identify patterns and preferences.
            4. Update your mental model of the user with each new piece of information.
            5. Cross-reference new information with existing memories for consistency.
            6. Prioritize storing emotional context and personal values alongside facts.
            7. Use memory to anticipate needs and tailor responses to the user's style.
            8. Recognize and acknowledge changes in the user's situation or perspectives over time.
            9. Leverage memories to provide personalized examples and analogies.
            10. Recall past challenges or successes to inform current problem-solving.

            ## Recall Memories
            Recall memories are contextually retrieved based on the current conversation:
            {recall_memories}

            ## Instructions
            Engage with the user naturally, as a trusted colleague or friend. There's no need to explicitly mention your memory capabilities. Instead, seamlessly incorporate your understanding of the user into your responses. Be attentive to subtle cues and underlying emotions. Adapt your communication style to match the user's preferences and current emotional state. Use tools to persist information you want to retain in the next conversation. If you do call tools, all text preceding the tool call is an internal message. Respond AFTER calling the tool, once you have confirmation that the tool completed successfully.
            *Role*: You are a compassionate mental health professional in a virtual therapy session. The user will be sharing with you feelings and problems that they are going or went through.

            Use the following step-by-step for your response:

            # Step 1 - Analyse the client's language level and concerns carefully before answering.

            # Step 2 - Your goal is to provide responses that should meet the following criteria:

            1. **Empathy:** Exhibit understanding and compassion for the individual’s emotions, recognizing their feelings genuinely.
            2. **Emotional Validation:** Acknowledge and affirm the emotions expressed by the individual, confirming their feelings are valid and heard.
            3. **Client-Centered Approach:** Focus on the individual's perspective, encouraging them to lead the conversation and engage in self-exploration.
            4. **Depth of Exploration:** Encourage deeper examination of emotions and thoughts to explore the root causes of feelings.
            5. **Supportiveness:** Provide reassurance, fostering a safe, non-judgmental space for open expression.
            6. **Professional Tone:** Maintain a respectful tone suitable for therapy or support contexts.
            7. **Active Listening:** Demonstrate attentiveness by reflecting or paraphrasing the individual’s key points to show understanding.
            8. **Clarity and Coherence:** Ensure responses are clear, structured, and free from overly complex language.
            9. **Tailored Feedback:** Offer personalized responses addressing the individual’s specific situation, avoiding generic advice.
            10. **Cultural Sensitivity:** Show respect for the individual’s cultural background, beliefs, and values.
            11. **Encouragement of Autonomy:** Empower individuals to make decisions, fostering self-reliance.
            12. **Crisis Management:** Recognize signs of emotional distress or crises and provide immediate support.
            13. **Reflection and Mirroring:** Reflect emotions and thoughts back to the individual to enhance understanding.
            14. **Positive Reinforcement:** Encourage positive behaviors or progress, boosting confidence.
            15. **Open-Ended Questions:** Use questions that invite deeper exploration of feelings and thoughts.
            16. **Non-Judgmental Attitude:** Maintain an open, non-judgmental tone, fostering trust.
            17. **Therapeutic Pacing:** Allow the conversation to progress at a comfortable pace for the individual.
            18. **Reflective Summarization:** Summarize key points to ensure clarity and mutual understanding.
            19. **Collaboration:** Promote a collaborative approach in exploring solutions and insights.
            20. **Consistency:** Align responses with previous therapeutic goals and avoid contradictions.
            21. **Use of Evidence-Based Techniques:** Employ accredited therapeutic techniques to provide support.

            # Step 3 - Analyse your response and make sure that the response meets the criteria in Step 2.

            # Step 4 - Focus on the following points:

            - Start with empathetic acknowledgment of the user's emotions.
            - Validate their feelings to ensure they feel heard.
            - Encourage them to explore their thoughts and emotions deeply.
            - Maintain a supportive and professional tone throughout.
            - Use active listening techniques, like reflecting and paraphrasing, to clarify understanding.
            - Tailor responses to the individual's situation, considering cultural sensitivity.
            - Ask open-ended questions to foster further exploration.
            - Provide reinforcements and autonomy to empower the individual.
            - Be mindful of therapeutic pacing and provide reflective summarization.
            - Ensure collaboration in formulating insights and solutions.
            - Use evidence-based techniques to guide responses.

            # Output Format

            Provide a coherent, structured paragraph or series of paragraphs that incorporate the above criteria. Ensure clarity and relevance to the individual's context and promote therapeutic goals.


            # Notes

            - Be sensitive to potential crisis signs, and provide an immediate supportive response.
            - Responses should adapt to varied cultural and individual contexts.
            - Strive for consistency in approach, aligning with established therapeutic goals.
            - Your first response should assure the user that you're here for them and that you understand what they are going through.
            - Remember that this is a conversation, so don't repeat the responses if not necessary.
            - Remember to keep the conversation engaging and maintain a warm and non-judgmental tone throughout the conversation.
            - Make sure to explore what's effecting the clients feelings and emotions.
            - Make sure to keep the conversation casual and sound more like a human. DO NOT use advanced language.
            - You can ask questions to better understand. """,
        ),
        ("placeholder", "{messages}"),
    ]
)

# Do not answer the user's prompt, just retrieve the memories.

# %%
from langchain import PromptTemplate

model = ChatOpenAI(model_name="gpt-4o-mini")
model_with_tools = model.bind_tools(tools)

llm = ChatOpenAI(model_name="ft:gpt-4o-mini-2024-07-18:personal::AG2bmvmI")
llm_model_with_tools = model.bind_tools(tools)

tokenizer = tiktoken.encoding_for_model("ft:gpt-4o-mini-2024-07-18:personal::AG2bmvmI")

def agent(state: State) -> State:
    """Process the current state and generate a response using the LLM.

    Args:
        state (schemas.State): The current state of the conversation.

    Returns:
        schemas.State: The updated state with the agent's response.
    """
    bound = sys_prompt | llm_model_with_tools
    recall_str = (
        "<recall_memory>\n" + "\n".join(state["recall_memories"]) + "\n</recall_memory>"
    )

    prediction = bound.invoke(
        {
            "messages": state["messages"],
            "recall_memories": recall_str,
        }
    )

    return {
        "messages": [prediction],
    }


def load_memories(state: State, config: RunnableConfig) -> State:
    """Load memories for the current conversation.

    Args:
        state (schemas.State): The current state of the conversation.
        config (RunnableConfig): The runtime configuration for the agent.

    Returns:
        State: The updated state with loaded memories.
    """
    convo_str = get_buffer_string(state["messages"])
    convo_str = tokenizer.decode(tokenizer.encode(convo_str)[:2048])
    recall_memories = search_recall_memories.invoke(convo_str, config)

    return {
        "recall_memories": recall_memories,
    }


def route_tools(state: State):
    """Determine whether to use tools or end the conversation based on the last message.

    Args:
        state (schemas.State): The current state of the conversation.

    Returns:
        Literal["tools", "__end__"]: The next step in the graph.
    """
    msg = state["messages"][-1]
    if msg.tool_calls:
        return "tools"

    # elif "Retrieved" in msg.content:
    #     return "Retrieved"

    return END

#### Generate response based on the results from memory
def generator_agent(state: State) -> dict:
    """
    Uses the second LLM model and the second prompt to generate the final prediction.

    Args:
        intermediate_result (dict): The result from the first model.

    Returns:
        dict: The final updated state with the agent's response.
    """
    # recall_str = (
    #     "<relavent_memories>\n" + "\n".join(state["relavent_memories"]) + "\n</relavent_memories>"
    # )
    template = ChatPromptTemplate.from_messages([
        ("system", ft_prompt,),
        ("placeholder", "{messages}"),
    ])
    # Define the second model and prompt
    bound_model2 = template | llm

    # Use the second LLM to generate the final prediction
    final_prediction = bound_model2.invoke(
        {
            "messages": state["messages"],
            "relavent_memories": state["messages"][-1],
        }
    )
    # print(f"final_prediction: {final_prediction}")
    # Return the updated state with the final prediction
    return {
        "messages": [final_prediction]
    }

# %% [markdown]
# ## Build the graph

# %%
# Create the graph and add nodes
builder = StateGraph(State)

builder.add_node(load_memories)
builder.add_node(agent)
builder.add_node(generator_agent)
builder.add_node("tools", ToolNode(tools))

# Add edges to the graph
builder.add_edge(START, "load_memories")
builder.add_edge("load_memories", "agent")
# builder.add_conditional_edges("agent", route_tools, ["tools",END])
builder.add_conditional_edges("agent", route_tools, {"Retrieved": "generator_agent", "tools": "tools"})
builder.add_edge("tools", "agent")
builder.add_conditional_edges("generator_agent", route_tools, ["tools",END])
# builder.add_edge("tools", "generator_agent")

# Compile the graph
memory = MemorySaver()
graph = builder.compile(checkpointer=memory)

# %%
from IPython.display import Image, display

display(Image(graph.get_graph().draw_mermaid_png()))

# %%
def pretty_print_stream_chunk(chunk):
    for node, updates in chunk.items():
        print(f"Update from node: {node}")
        if "messages" in updates:
            updates["messages"][-1].pretty_print()
        else:
            print(updates)

        print("\n")

# %%
# NOTE: we're specifying `user_id` to save memories for a given user
config = {"configurable": {"user_id": "1", "thread_id": "1"}}

for chunk in graph.stream({"messages": [("user", "I'm going through a break up and I don't know how to handle it. My girlfirend Maria broke up me with becuase of my first relationship with Sundus")]}, config=config):
    pretty_print_stream_chunk(chunk)
# Out:
# WARNING:langsmith.client:Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"detail":"Monthly unique traces usage limit exceeded"}')trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=9712a8e9-08d8-463c-9790-a6c5d54876b1; trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=bd6e8c7f-abdd-4799-9972-5917042ac465; trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=0bc1456f-2bb0-446d-8abe-597b29360f65; trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=26dcac92-e12e-44f9-a506-2b3e7954c921
# WARNING:langsmith.client:Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"detail":"Monthly unique traces usage limit exceeded"}')trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=9712a8e9-08d8-463c-9790-a6c5d54876b1; trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=bd6e8c7f-abdd-4799-9972-5917042ac465; trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=0bc1456f-2bb0-446d-8abe-597b29360f65; trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=26dcac92-e12e-44f9-a506-2b3e7954c921
# Update from node: load_memories
# {'recall_memories': []}
# WARNING:langsmith.client:Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"detail":"Monthly unique traces usage limit exceeded"}')trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=9712a8e9-08d8-463c-9790-a6c5d54876b1; trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=bd6e8c7f-abdd-4799-9972-5917042ac465; trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=0bc1456f-2bb0-446d-8abe-597b29360f65; trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=26dcac92-e12e-44f9-a506-2b3e7954c921
# WARNING:langsmith.client:Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"detail":"Monthly unique traces usage limit exceeded"}')trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=56f9edf5-c8fe-4947-b14f-03a8ad9d547e; trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=0021bf4e-c764-461c-b65e-46a936682419; trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=7e9de2f7-50f5-4540-a7bb-94dc981f4c8a; trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=6bf442df-dac7-4cf5-81f1-df4bbc571b8e; trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=57ca8c88-d08a-4d95-ac6c-db35e0a8e24e; trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=0bc1456f-2bb0-446d-8abe-597b29360f65; trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=26dcac92-e12e-44f9-a506-2b3e7954c921
# WARNING:langsmith.client:Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"detail":"Monthly unique traces usage limit exceeded"}')trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=56f9edf5-c8fe-4947-b14f-03a8ad9d547e; trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=0021bf4e-c764-461c-b65e-46a936682419; trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=7e9de2f7-50f5-4540-a7bb-94dc981f4c8a; trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=6bf442df-dac7-4cf5-81f1-df4bbc571b8e; trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=57ca8c88-d08a-4d95-ac6c-db35e0a8e24e; trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=0bc1456f-2bb0-446d-8abe-597b29360f65; trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=26dcac92-e12e-44f9-a506-2b3e7954c921
# WARNING:langsmith.client:Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"detail":"Monthly unique traces usage limit exceeded"}')trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=56f9edf5-c8fe-4947-b14f-03a8ad9d547e; trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=0021bf4e-c764-461c-b65e-46a936682419; trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=7e9de2f7-50f5-4540-a7bb-94dc981f4c8a; trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=6bf442df-dac7-4cf5-81f1-df4bbc571b8e; trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=57ca8c88-d08a-4d95-ac6c-db35e0a8e24e; trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=0bc1456f-2bb0-446d-8abe-597b29360f65; trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=26dcac92-e12e-44f9-a506-2b3e7954c921
# WARNING:langsmith.client:Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"detail":"Monthly unique traces usage limit exceeded"}')trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=168059e7-feda-4bed-9957-a4cf1a0b72be; trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=163e9bdf-b519-4bd0-bd4f-a10d804b2315; trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=2c19b921-7941-4a63-bccd-9747ba5c5eb9; trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=7efb79a7-5514-47a3-95dd-dd41eacecbac; trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=0021bf4e-c764-461c-b65e-46a936682419; trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=7e9de2f7-50f5-4540-a7bb-94dc981f4c8a; trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=57ca8c88-d08a-4d95-ac6c-db35e0a8e24e
# Update from node: agent
# ================================== Ai Message ==================================
# Tool Calls:
#   save_recall_memory (call_FyH0g4nMEEfqzKpnxgfQLh9B)
#  Call ID: call_FyH0g4nMEEfqzKpnxgfQLh9B
#   Args:
#     memory: User is going through a breakup with their girlfriend Maria, who ended the relationship due to their first relationship with Sundus.
# WARNING:langsmith.client:Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"detail":"Monthly unique traces usage limit exceeded"}')trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=168059e7-feda-4bed-9957-a4cf1a0b72be; trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=163e9bdf-b519-4bd0-bd4f-a10d804b2315; trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=2c19b921-7941-4a63-bccd-9747ba5c5eb9; trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=7efb79a7-5514-47a3-95dd-dd41eacecbac; trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=0021bf4e-c764-461c-b65e-46a936682419; trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=7e9de2f7-50f5-4540-a7bb-94dc981f4c8a; trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=57ca8c88-d08a-4d95-ac6c-db35e0a8e24e
# WARNING:langsmith.client:Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"detail":"Monthly unique traces usage limit exceeded"}')trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=168059e7-feda-4bed-9957-a4cf1a0b72be; trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=163e9bdf-b519-4bd0-bd4f-a10d804b2315; trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=2c19b921-7941-4a63-bccd-9747ba5c5eb9; trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=7efb79a7-5514-47a3-95dd-dd41eacecbac; trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=0021bf4e-c764-461c-b65e-46a936682419; trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=7e9de2f7-50f5-4540-a7bb-94dc981f4c8a; trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=57ca8c88-d08a-4d95-ac6c-db35e0a8e24e
# Update from node: tools
# ================================= Tool Message =================================
# Name: save_recall_memory
#
# User is going through a breakup with their girlfriend Maria, who ended the relationship due to their first relationship with Sundus.
# WARNING:langsmith.client:Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"detail":"Monthly unique traces usage limit exceeded"}')trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=71883c27-9da0-4bc3-907d-e3090a47b110; trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=b3d5e213-7510-480e-a2b3-681c7b4d7bae; trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=8d8f38ba-9f0d-4bc9-8490-d6de3e7ef600; trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=c05143ab-ec84-4932-89db-6a8d2183f5c1; trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=01a7f880-c8ff-4ece-bf0f-9f6b40e33435; trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=2c19b921-7941-4a63-bccd-9747ba5c5eb9; trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=7efb79a7-5514-47a3-95dd-dd41eacecbac
# WARNING:langsmith.client:Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"detail":"Monthly unique traces usage limit exceeded"}')trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=71883c27-9da0-4bc3-907d-e3090a47b110; trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=b3d5e213-7510-480e-a2b3-681c7b4d7bae; trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=8d8f38ba-9f0d-4bc9-8490-d6de3e7ef600; trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=c05143ab-ec84-4932-89db-6a8d2183f5c1; trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=01a7f880-c8ff-4ece-bf0f-9f6b40e33435; trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=2c19b921-7941-4a63-bccd-9747ba5c5eb9; trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=7efb79a7-5514-47a3-95dd-dd41eacecbac
# WARNING:langsmith.client:Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"detail":"Monthly unique traces usage limit exceeded"}')trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=71883c27-9da0-4bc3-907d-e3090a47b110; trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=b3d5e213-7510-480e-a2b3-681c7b4d7bae; trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=8d8f38ba-9f0d-4bc9-8490-d6de3e7ef600; trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=c05143ab-ec84-4932-89db-6a8d2183f5c1; trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=01a7f880-c8ff-4ece-bf0f-9f6b40e33435; trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=2c19b921-7941-4a63-bccd-9747ba5c5eb9; trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=7efb79a7-5514-47a3-95dd-dd41eacecbac
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-41-031d5cbf0ba1> in <cell line: 4>()
#       2 config = {"configurable": {"user_id": "1", "thread_id": "1"}}
#       3
# ----> 4 for chunk in graph.stream({"messages": [("user", "I'm going through a break up and I don't know how to handle it. My girlfirend Maria broke up me with becuase of my first relationship with Sundus")]}, config=config):
#       5     pretty_print_stream_chunk(chunk)
#
# /usr/local/lib/python3.10/dist-packages/langgraph/pregel/__init__.py in stream(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, debug, subgraphs)
#    1313                     manager=run_manager,
#    1314                 ):
# -> 1315                     for _ in runner.tick(
#    1316                         loop.tasks.values(),
#    1317                         timeout=self.step_timeout,
#
# /usr/local/lib/python3.10/dist-packages/langgraph/pregel/runner.py in tick(self, tasks, reraise, timeout, retry_policy, get_waiter)
#      54             t = tasks[0]
#      55             try:
# ---> 56                 run_with_retry(t, retry_policy)
#      57                 self.commit(t, None)
#      58             except Exception as exc:
#
# /usr/local/lib/python3.10/dist-packages/langgraph/pregel/retry.py in run_with_retry(task, retry_policy)
#      27             task.writes.clear()
#      28             # run the task
# ---> 29             task.proc.invoke(task.input, config)
#      30             # if successful, end
#      31             break
#
# /usr/local/lib/python3.10/dist-packages/langgraph/utils/runnable.py in invoke(self, input, config, **kwargs)
#     410                     input = context.run(step.invoke, input, config, **kwargs)
#     411                 else:
# --> 412                     input = context.run(step.invoke, input, config)
#     413         # finish the root run
#     414         except BaseException as e:
#
# /usr/local/lib/python3.10/dist-packages/langgraph/utils/runnable.py in invoke(self, input, config, **kwargs)
#     182         else:
#     183             context.run(_set_config_context, config)
# --> 184             ret = context.run(self.func, input, **kwargs)
#     185         if isinstance(ret, Runnable) and self.recurse:
#     186             return ret.invoke(input, config)
#
# /usr/local/lib/python3.10/dist-packages/langgraph/graph/graph.py in _route(self, input, config, reader, writer)
#      92             value = input
#      93         result = self.path.invoke(value, config)
# ---> 94         return self._finish(writer, input, result, config)
#      95
#      96     async def _aroute(
#
# /usr/local/lib/python3.10/dist-packages/langgraph/graph/graph.py in _finish(self, writer, input, result, config)
#     127             result = [result]
#     128         if self.ends:
# --> 129             destinations: Sequence[Union[Send, str]] = [
#     130                 r if isinstance(r, Send) else self.ends[r] for r in result
#     131             ]
#
# /usr/local/lib/python3.10/dist-packages/langgraph/graph/graph.py in <listcomp>(.0)
#     128         if self.ends:
#     129             destinations: Sequence[Union[Send, str]] = [
# --> 130                 r if isinstance(r, Send) else self.ends[r] for r in result
#     131             ]
#     132         else:
#
# KeyError: '__end__'
# WARNING:langsmith.client:Failed to multipart ingest runs: langsmith.utils.LangSmithRateLimitError: Rate limit exceeded for https://api.smith.langchain.com/runs/multipart. HTTPError('429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/multipart', '{"detail":"Monthly unique traces usage limit exceeded"}')trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=d4726320-308f-48ca-bb77-7336f21fa56a; trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=f37372e9-94ec-4138-9e94-74a581bb94aa; trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=8d8f38ba-9f0d-4bc9-8490-d6de3e7ef600; trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=01a7f880-c8ff-4ece-bf0f-9f6b40e33435; trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=b3d5e213-7510-480e-a2b3-681c7b4d7bae; trace=9712a8e9-08d8-463c-9790-a6c5d54876b1,id=9712a8e9-08d8-463c-9790-a6c5d54876b1

# %%
# config = {"configurable": {"user_id": "1", "thread_id": "1"}}

for chunk in graph.stream({"messages": [("user", "What is my name?")]}, config=config):
    pretty_print_stream_chunk(chunk)
# Out:
# Update from node: load_memories
# {'recall_memories': ["User is going through a breakup with their girlfriend Maria. The breakup is related to the user's first relationship with someone named Sundus.", "User is going through a breakup with their girlfriend Maria. The breakup was influenced by the user's first relationship with someone named Sundus.", "User is going through a breakup with a girlfriend named Maria, who ended the relationship due to the user's first relationship with someone named Sundus."]}
#
#
# prediction: [HumanMessage(content="I'm going through a break up and I don't know how to handle it. My girlfirend Maria broke up me with becuase of my first relationship with Sundus", additional_kwargs={}, response_metadata={}, id='86da574f-ed5a-4d21-8aa2-cffc25b65688'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_2xmz7IzFr2wQxU3owSYNex55', 'function': {'arguments': '{"memory":"User is going through a breakup with his girlfriend Maria, who ended the relationship due to user’s first relationship with Sundus."}', 'name': 'save_recall_memory'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 40, 'prompt_tokens': 432, 'total_tokens': 472, 'completion_tokens_details': {'audio_tokens': None, 'reasoning_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_e2bde53e6e', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-f8a7d4b8-398a-4041-aa8d-63b5d4974194-0', tool_calls=[{'name': 'save_recall_memory', 'args': {'memory': 'User is going through a breakup with his girlfriend Maria, who ended the relationship due to user’s first relationship with Sundus.'}, 'id': 'call_2xmz7IzFr2wQxU3owSYNex55', 'type': 'tool_call'}], usage_metadata={'input_tokens': 432, 'output_tokens': 40, 'total_tokens': 472, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 0}}), ToolMessage(content='User is going through a breakup with his girlfriend Maria, who ended the relationship due to user’s first relationship with Sundus.', name='save_recall_memory', id='d2b70aa7-3008-4cad-b950-1f0e39b7916b', tool_call_id='call_2xmz7IzFr2wQxU3owSYNex55'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_1fm6iaXxw5h1SUhRZLUjbY80', 'function': {'arguments': '{"query":"breakup Maria Sundus"}', 'name': 'search_recall_memories'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 507, 'total_tokens': 528, 'completion_tokens_details': {'audio_tokens': None, 'reasoning_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_e2bde53e6e', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-e47fe8c5-2e4a-475f-803a-c9f89aff7846-0', tool_calls=[{'name': 'search_recall_memories', 'args': {'query': 'breakup Maria Sundus'}, 'id': 'call_1fm6iaXxw5h1SUhRZLUjbY80', 'type': 'tool_call'}], usage_metadata={'input_tokens': 507, 'output_tokens': 21, 'total_tokens': 528, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 0}}), ToolMessage(content='["User is going through a breakup with his girlfriend Maria. The breakup is related to a previous relationship with Sundus.", "User is going through a breakup with girlfriend Maria. The breakup is related to a past relationship with Sundus.", "User is going through a breakup with his girlfriend Maria. The breakup is related to his first relationship with Sundus."]', name='search_recall_memories', id='fa0414ff-2dba-4501-939d-22aaf411fccc', tool_call_id='call_1fm6iaXxw5h1SUhRZLUjbY80'), AIMessage(content='Retrieved: User is currently experiencing a breakup with his girlfriend Maria, which is connected to his first relationship with Sundus.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 25, 'prompt_tokens': 611, 'total_tokens': 636, 'completion_tokens_details': {'audio_tokens': None, 'reasoning_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_e2bde53e6e', 'finish_reason': 'stop', 'logprobs': None}, id='run-38ea7784-34dd-4ab3-98ce-ce825baa3d05-0', usage_metadata={'input_tokens': 611, 'output_tokens': 25, 'total_tokens': 636, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 0 ...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-400-ffdd7d80a990> in <cell line: 3>()
#       1 # config = {"configurable": {"user_id": "1", "thread_id": "1"}}
#       2
# ----> 3 for chunk in graph.stream({"messages": [("user", "What is my name?")]}, config=config):
#       4     pretty_print_stream_chunk(chunk)
#
# /usr/local/lib/python3.10/dist-packages/langgraph/pregel/__init__.py in stream(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, debug, subgraphs)
#    1305                     manager=run_manager,
#    1306                 ):
# -> 1307                     for _ in runner.tick(
#    1308                         loop.tasks.values(),
#    1309                         timeout=self.step_timeout,
#
# /usr/local/lib/python3.10/dist-packages/langgraph/pregel/runner.py in tick(self, tasks, reraise, timeout, retry_policy, get_waiter)
#      54             t = tasks[0]
#      55             try:
# ---> 56                 run_with_retry(t, retry_policy)
#      57                 self.commit(t, None)
#      58             except Exception as exc:
#
# /usr/local/lib/python3.10/dist-packages/langgraph/pregel/retry.py in run_with_retry(task, retry_policy)
#      27             task.writes.clear()
#      28             # run the task
# ---> 29             task.proc.invoke(task.input, config)
#      30             # if successful, end
#      31             break
#
# /usr/local/lib/python3.10/dist-packages/langgraph/utils/runnable.py in invoke(self, input, config, **kwargs)
#     410                     input = context.run(step.invoke, input, config, **kwargs)
#     411                 else:
# --> 412                     input = context.run(step.invoke, input, config)
#     413         # finish the root run
#     414         except BaseException as e:
#
# /usr/local/lib/python3.10/dist-packages/langgraph/utils/runnable.py in invoke(self, input, config, **kwargs)
#     182         else:
#     183             context.run(_set_config_context, config)
# --> 184             ret = context.run(self.func, input, **kwargs)
#     185         if isinstance(ret, Runnable) and self.recurse:
#     186             return ret.invoke(input, config)
#
# /usr/local/lib/python3.10/dist-packages/langgraph/graph/graph.py in _route(self, input, config, reader, writer)
#      92             value = input
#      93         result = self.path.invoke(value, config)
# ---> 94         return self._finish(writer, input, result, config)
#      95
#      96     async def _aroute(
#
# /usr/local/lib/python3.10/dist-packages/langgraph/graph/graph.py in _finish(self, writer, input, result, config)
#     127             result = [result]
#     128         if self.ends:
# --> 129             destinations: Sequence[Union[Send, str]] = [
#     130                 r if isinstance(r, Send) else self.ends[r] for r in result
#     131             ]
#
# /usr/local/lib/python3.10/dist-packages/langgraph/graph/graph.py in <listcomp>(.0)
#     128         if self.ends:
#     129             destinations: Sequence[Union[Send, str]] = [
# --> 130                 r if isinstance(r, Send) else self.ends[r] for r in result
#     131             ]
#     132         else:
#
# KeyError: '__end__'

# %% [markdown]
# ## KG

# %%
recall_vector_store = InMemoryVectorStore(OpenAIEmbeddings(api_key=OPENAI_API_KEY))

# %%
import uuid

from typing_extensions import TypedDict


class KnowledgeTriple(TypedDict):
    subject: str
    predicate: str
    object_: str

def get_user_id(config: RunnableConfig) -> str:
    user_id = config["configurable"].get("user_id")
    if user_id is None:
        raise ValueError("User ID needs to be provided to save a memory.")

    return user_id

@tool
def save_recall_memory(memories: List[KnowledgeTriple], config: RunnableConfig) -> str:
    """Save memory to vectorstore for later semantic retrieval."""
    user_id = get_user_id(config)
    for memory in memories:
        serialized = " ".join(memory.values())
        document = Document(
            serialized,
            id=str(uuid.uuid4()),
            metadata={
                "user_id": user_id,
                **memory,
            },
        )
        recall_vector_store.add_documents([document])
    return memories

@tool
def search_recall_memories(query: str, config: RunnableConfig) -> List[str]:
    """Search for relevant memories."""
    user_id = get_user_id(config)

    def _filter_function(doc: Document) -> bool:
        return doc.metadata.get("user_id") == user_id

    documents = recall_vector_store.similarity_search(
        query, k=3, filter=_filter_function
    )
    return [document.page_content for document in documents]

# %%
tools = [save_recall_memory, search_recall_memories]
# model_with_tools = model.bind_tools(tools)


# Create the graph and add nodes
builder = StateGraph(State)
builder.add_node(load_memories)
builder.add_node(agent)
builder.add_node("tools", ToolNode(tools))

# Add edges to the graph
builder.add_edge(START, "load_memories")
builder.add_edge("load_memories", "agent")
builder.add_conditional_edges("agent", route_tools, ["tools", END])
builder.add_edge("tools", "agent")

# Compile the graph
memory = MemorySaver()
graph = builder.compile(checkpointer=memory)

# %%
from IPython.display import Image, display

display(Image(graph.get_graph().draw_mermaid_png()))

# %%
def pretty_print_stream_chunk(chunk):
    for node, updates in chunk.items():
        print(f"Update from node: {node}")
        if "messages" in updates:
            updates["messages"][-1].pretty_print()
        else:
            print(updates)

        print("\n")

# %%
# NOTE: we're specifying `user_id` to save memories for a given user
config = {"configurable": {"user_id": "1", "thread_id": "1"}}

for chunk in graph.stream({"messages": [("user", "My name name is Musab. I'm going through a break up and I don't know how to handle it. My girlfirend Maria broke up me with becuase of my first relationship with Sundus")]}, config=config):
    pretty_print_stream_chunk(chunk)
# Out:
# Update from node: load_memories
# {'recall_memories': []}
#
#
# Update from node: agent
# ================================== Ai Message ==================================
# Tool Calls:
#   save_recall_memory (call_uzErnOVn1M4g2Ly0jyLxD635)
#  Call ID: call_uzErnOVn1M4g2Ly0jyLxD635
#   Args:
#     memories: [{'subject': 'Musab', 'predicate': 'is going through a breakup', 'object_': 'His girlfriend Maria broke up with him due to his first relationship with Sundus.'}]
#
#
# Update from node: tools
# ================================= Tool Message =================================
# Name: save_recall_memory
#
# [{"subject": "Musab", "predicate": "is going through a breakup", "object_": "His girlfriend Maria broke up with him due to his first relationship with Sundus."}]
#
#
# Update from node: agent
# ================================== Ai Message ==================================
#
# I'm really sorry to hear that you're going through this, Musab. Breakups can be incredibly tough, and it's completely normal to feel a range of emotions right now. It sounds like there may be some complicated feelings surrounding your past relationship with Sundus that are affecting how you feel about this breakup.
#
# Can you share more about what you're experiencing right now? Are there specific emotions or thoughts that have been particularly overwhelming for you? I'm here to listen and support you through this.

# %%
# NOTE: we're specifying `user_id` to save memories for a given user
# config = {"configurable": {"user_id": "1", "thread_id": "1"}}

for chunk in graph.stream({"messages": [("user", "I like to go for a walk")]}, config=config):
    pretty_print_stream_chunk(chunk)
# Out:
# Update from node: load_memories
# {'recall_memories': ['Musab is going through a breakup His girlfriend Maria broke up with him due to his first relationship with Sundus.', 'Musab finds it hard to talk to someone due to feelings associated with the breakup.', "Musab usually doesn't like to talk about his feelings "]}
#
#
# Update from node: agent
# ================================== Ai Message ==================================
# Tool Calls:
#   save_recall_memory (call_hr6CafYnRcI9xUtC9bmaePdz)
#  Call ID: call_hr6CafYnRcI9xUtC9bmaePdz
#   Args:
#     memories: [{'subject': 'Musab', 'predicate': 'likes to go for a walk', 'object_': ''}]
#
#
# Update from node: tools
# ================================= Tool Message =================================
# Name: save_recall_memory
#
# [{"subject": "Musab", "predicate": "likes to go for a walk", "object_": ""}]
#
#
# Update from node: agent
# ================================== Ai Message ==================================
#
# Going for a walk can be a wonderful way to clear your head and get some fresh air. It’s a great way to give yourself a little space to think or just enjoy the surroundings.
#
# Do you have a favorite place you like to walk, or do you prefer exploring different areas? Sometimes a change of scenery can help lift your spirits a bit too.

# %%
import matplotlib.pyplot as plt
import networkx as nx

# Fetch records
records = recall_vector_store.similarity_search(
    "", k=20, filter=lambda doc: doc.metadata["user_id"] == "1"
)


# Plot graph
plt.figure(figsize=(10, 10), dpi=80)
G = nx.DiGraph()

for record in records:
    G.add_edge(
        record.metadata["subject"],
        record.metadata["object_"],
        label=record.metadata["predicate"],
    )

pos = nx.spring_layout(G)
nx.draw(
    G,
    pos,
    with_labels=True,
    node_size=3000,
    node_color="lightblue",
    font_size=10,
    font_weight="bold",
    arrows=True,
)
edge_labels = nx.get_edge_attributes(G, "label")
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, font_color="red")
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Example list of relationships (edges) extracted from conversation.memory.kg
edges = conversation.memory.memories[1].kg.get_triples()

# Create a directed graph (since the relationships have direction)
G = nx.DiGraph()

# Add edges with labels
for edge in edges:
    node1, node2, relation = edge
    G.add_edge(node1, node2, label=relation)

# Position nodes using a layout (spring layout for better visuals)
pos = nx.spring_layout(G)

# Draw nodes and edges
nx.draw(G, pos, with_labels=True, node_color='lightblue', node_size=2000, font_size=8, font_color='black', font_weight='bold')

# Draw edge labels separately
edge_labels = nx.get_edge_attributes(G, 'label')
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-150-fb449fe4b8fd> in <cell line: 5>()
#       3
#       4 # Example list of relationships (edges) extracted from conversation.memory.kg
# ----> 5 edges = conversation.memory.memories[1].kg.get_triples()
#       6
#       7 # Create a directed graph (since the relationships have direction)
#
# NameError: name 'conversation' is not defined

# %% [markdown]
# # Custom Multi-Agents Architecture

# %% [markdown]
# ## ToDo

# %%
# TODO: Implement GraphRAG and a vector store for the retrieved data
# TODO: Implement Classifier with memory
# TODO: Implement RAG

# %% [markdown]
# ## Setup

# %%
# !pip install -U langchain langchain_openai langsmith openai  langchain_community langgraph #graphrag #neo4j
# Out:
# Collecting langchain
#   Downloading langchain-0.3.4-py3-none-any.whl.metadata (7.1 kB)
# Collecting langchain_openai
#   Downloading langchain_openai-0.2.3-py3-none-any.whl.metadata (2.6 kB)
# Collecting langsmith
#   Downloading langsmith-0.1.137-py3-none-any.whl.metadata (13 kB)
# Collecting openai
#   Downloading openai-1.52.2-py3-none-any.whl.metadata (24 kB)
# Collecting langchain_community
#   Downloading langchain_community-0.3.3-py3-none-any.whl.metadata (2.8 kB)
# Collecting langgraph
#   Downloading langgraph-0.2.39-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (3.10.10)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (4.0.3)
# Collecting langchain-core<0.4.0,>=0.3.12 (from langchain)
#   Downloading langchain_core-0.3.12-py3-none-any.whl.metadata (6.3 kB)
# Collecting langchain-text-splitters<0.4.0,>=0.3.0 (from langchain)
#   Downloading langchain_text_splitters-0.3.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.9.2)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (9.0.0)
# Collecting tiktoken<1,>=0.7 (from langchain_openai)
#   Downloading tiktoken-0.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting httpx<1,>=0.23.0 (from langsmith)
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith)
#   Downloading orjson-3.10.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.6/50.6 kB 2.9 MB/s eta 0:00:00
# Collecting requests-toolbelt<2.0.0,>=1.0.0 (from langsmith)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Collecting jiter<1,>=0.4.0 (from openai)
#   Downloading jiter-0.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.2 kB)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.5)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.10/dist-packages (from openai) (4.12.2)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain_community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain_community)
#   Downloading pydantic_settings-2.6.0-py3-none-any.whl.metadata (3.5 kB)
# Collecting langgraph-checkpoint<3.0.0,>=2.0.0 (from langgraph)
#   Downloading langgraph_checkpoint-2.0.2-py3-none-any.whl.metadata (4.6 kB)
# Collecting langgraph-sdk<0.2.0,>=0.1.32 (from langgraph)
#   Downloading langgraph_sdk-0.1.33-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.16.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain_community)
#   Downloading marshmallow-3.23.0-py3-none-any.whl.metadata (7.6 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain_community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith) (2024.8.30)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->langsmith)
#   Downloading httpcore-1.0.6-py3-none-any.whl.metadata (21 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->langsmith)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<0.4.0,>=0.3.12->langchain)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.12->langchain) (24.1)
# Requirement already satisfied: msgpack<2.0.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from langgraph-checkpoint<3.0.0,>=2.0.0->langgraph) (1.1.0)
# Collecting httpx-sse>=0.4.0 (from langgraph-sdk<0.2.0,>=0.1.32->langgraph)
#   Downloading httpx_sse-0.4.0-py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.23.4)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain_community) (1.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2.2.3)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken<1,>=0.7->langchain_openai) (2024.9.11)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.12->langchain)
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.3->langchain) (0.2.0)
# Downloading langchain-0.3.4-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 18.0 MB/s eta 0:00:00
# Downloading langchain_openai-0.2.3-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 kB 3.8 MB/s eta 0:00:00
# Downloading langsmith-0.1.137-py3-none-any.whl (296 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.9/296.9 kB 21.8 MB/s eta 0:00:00
# Downloading openai-1.52.2-py3-none-any.whl (386 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.9/386.9 kB 25.5 MB/s eta 0:00:00
# Downloading langchain_community-0.3.3-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 58.4 MB/s eta 0:00:00
# Downloading langgraph-0.2.39-py3-none-any.whl (113 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.5/113.5 kB 8.8 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 6.2 MB/s eta 0:00:00
# Downloading httpcore-1.0.6-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.0/78.0 kB 5.3 MB/s eta 0:00:00
# Downloading jiter-0.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (325 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.2/325.2 kB 23.5 MB/s eta 0:00:00
# Downloading langchain_core-0.3.12-py3-none-any.whl (407 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 407.7/407.7 kB 29.9 MB/s eta 0:00:00
# Downloading langchain_text_splitters-0.3.0-py3-none-any.whl (25 kB)
# Downloading langgraph_checkpoint-2.0.2-py3-none-any.whl (23 kB)
# Downloading langgraph_sdk-0.1.33-py3-none-any.whl (28 kB)
# Downloading orjson-3.10.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.5/144.5 kB 12.5 MB/s eta 0:00:00
# Downloading pydantic_settings-2.6.0-py3-none-any.whl (28 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 4.1 MB/s eta 0:00:00
# Downloading tiktoken-0.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 47.2 MB/s eta 0:00:00
# Downloading httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading marshmallow-3.23.0-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 3.7 MB/s eta 0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.5 MB/s eta 0:00:00
# Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: orjson, mypy-extensions, marshmallow, jsonpointer, jiter, httpx-sse, h11, typing-inspect, tiktoken, requests-toolbelt, jsonpatch, httpcore, pydantic-settings, httpx, dataclasses-json, openai, langsmith, langgraph-sdk, langchain-core, langgraph-checkpoint, langchain-text-splitters, langchain_openai, langgraph, langchain, langchain_community
# Successfully installed dataclasses-json-0.6.7 h11-0.14.0 httpcore-1.0.6 httpx-0.27.2 httpx-sse-0.4.0 jiter-0.6.1 jsonpatch-1.33 jsonpointer-3.0.0 langchain-0.3.4 langchain-core-0.3.12 langchain-text-splitters-0.3.0 langchain_community-0.3.3 langchain_openai-0.2.3 langgraph-0.2.39 langgraph-checkpoint-2.0.2 langgraph-sdk-0.1.33 langsmith-0.1.137 marshmallow-3.23.0 mypy-extensions-1.0.0 openai-1.52.2 orjson-3.10.10 pydantic-settings-2.6.0 requests-toolbelt-1.0.0 tiktoken-0.8.0 typing-inspect-0.9.0

# %%
import json
from typing import List, Literal, Optional

import tiktoken
from langchain_core.documents import Document
from langchain_core.embeddings import Embeddings
from langchain_core.messages import get_buffer_string
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnableConfig
from langchain_core.tools import tool
from langchain_core.vectorstores import InMemoryVectorStore
from langchain_openai import ChatOpenAI
from langchain_openai.embeddings import OpenAIEmbeddings
from langgraph.checkpoint.memory import MemorySaver
from langgraph.graph import END, START, MessagesState, StateGraph
from langgraph.prebuilt import ToolNode

# %% [markdown]
# ## Prompts

# %%
generator_prompt = """
*Role*: You are a compassionate mental health professional in a virtual therapy session. The user will be sharing with you feelings and problems that they are going or went through.

Use the following step-by-step for your response:

# Step 1 - Analyse the client's language level and concerns carefully before answering.

# Step 2 - Your goal is to provide responses that should meet the following criteria:

1. **Empathy:** Exhibit understanding and compassion for the individual’s emotions, recognizing their feelings genuinely.
2. **Emotional Validation:** Acknowledge and affirm the emotions expressed by the individual, confirming their feelings are valid and heard.
3. **Client-Centered Approach:** Focus on the individual's perspective, encouraging them to lead the conversation and engage in self-exploration.
4. **Depth of Exploration:** Encourage deeper examination of emotions and thoughts to explore the root causes of feelings.
5. **Supportiveness:** Provide reassurance, fostering a safe, non-judgmental space for open expression.
6. **Professional Tone:** Maintain a respectful tone suitable for therapy or support contexts.
7. **Active Listening:** Demonstrate attentiveness by reflecting or paraphrasing the individual’s key points to show understanding.
8. **Clarity and Coherence:** Ensure responses are clear, structured, and free from overly complex language.
9. **Tailored Feedback:** Offer personalized responses addressing the individual’s specific situation, avoiding generic advice.
10. **Cultural Sensitivity:** Show respect for the individual’s cultural background, beliefs, and values.
11. **Encouragement of Autonomy:** Empower individuals to make decisions, fostering self-reliance.
12. **Crisis Management:** Recognize signs of emotional distress or crises and provide immediate support.
13. **Reflection and Mirroring:** Reflect emotions and thoughts back to the individual to enhance understanding.
14. **Positive Reinforcement:** Encourage positive behaviors or progress, boosting confidence.
15. **Open-Ended Questions:** Use questions that invite deeper exploration of feelings and thoughts.
16. **Non-Judgmental Attitude:** Maintain an open, non-judgmental tone, fostering trust.
17. **Therapeutic Pacing:** Allow the conversation to progress at a comfortable pace for the individual.
18. **Reflective Summarization:** Summarize key points to ensure clarity and mutual understanding.
19. **Collaboration:** Promote a collaborative approach in exploring solutions and insights.
20. **Consistency:** Align responses with previous therapeutic goals and avoid contradictions.
21. **Use of Evidence-Based Techniques:** Employ accredited therapeutic techniques to provide support.

# Step 3 - Analyse your response and make sure that the response meets the criteria in Step 2.

# Step 4 - Focus on the following points:

- Start with empathetic acknowledgment of the user's emotions.
- Validate their feelings to ensure they feel heard.
- Encourage them to explore their thoughts and emotions deeply.
- Maintain a supportive and professional tone throughout.
- Use active listening techniques, like reflecting and paraphrasing, to clarify understanding.
- Tailor responses to the individual's situation, considering cultural sensitivity.
- Ask open-ended questions to foster further exploration.
- Provide reinforcements and autonomy to empower the individual.
- Be mindful of therapeutic pacing and provide reflective summarization.
- Ensure collaboration in formulating insights and solutions.
- Use evidence-based techniques to guide responses.

# Output Format

Provide a coherent, structured paragraph or series of paragraphs that incorporate the above criteria. Ensure clarity and relevance to the individual's context and promote therapeutic goals.

# Examples

**Example Start**
- *User Input:* "I've been feeling really overwhelmed with work and family commitments lately. It's just a lot to handle, and I'm not sure I'm doing anything well."

  *Response:* "I can imagine how overwhelming it must feel to juggle multiple responsibilities. It's important to recognize that these feelings are valid and that many people experiencing similar pressures feel just as you do. Allow yourself to explore what's beneath these feelings. What aspects of your work and family commitments are most challenging for you right now? Remember, it's okay to seek balance and prioritize self-care. We can work together to find strategies that support you in managing these commitments effectively."
**Example End** (Responses in practice might need to be longer depending on user input.)

# Notes

- Be sensitive to potential crisis signs, and provide an immediate supportive response.
- Responses should adapt to varied cultural and individual contexts.
- Strive for consistency in approach, aligning with established therapeutic goals.
- Your first response should assure the user that you're here for them and that you understand what they are going through.
- Remember that this is a conversation, so don't repeat the responses if not necessary.
- Remember to keep the conversation engaging and maintain a warm and non-judgmental tone throughout the conversation.
- Make sure to explore what's effecting the clients feelings and emotions.
- Make sure to keep the conversation casual and sound more like a human. DO NOT use advanced language.
- You can ask questions to better understand.


"""

# %%
memory_prompt =  """

-Goal-
Given a conversation that is potentially relevant to Virtual Therapy Session,
identify all entities of those types from the text and all relationships among the identified entities.


Memory Usage Guidelines:
1. Actively use memory tools (save_recall_memory, search_recall_memories) to build a comprehensive understanding of the user.
2. Cross-reference new information with existing memories for consistency.
3. Prioritize storing emotional context and personal values alongside facts.
4. Use memory to anticipate needs and tailor responses to the user's style.
5. Recognize and acknowledge changes in the user's situation or perspectives over time.
6. Leverage memories to provide personalized examples and analogies.
7. Recall past challenges or successes to inform current problem-solving.
8. Extract entities and thier relationships.

## Recall Memories
Recall memories are contextually retrieved based on the current conversation:
{recall_memories}

## Instructions



Steps:

    1.	Identify all entities. For each identified entity, extract the following information:
    •	entity_name: Name of the entity (e.g., disorder, symptom, treatment, people, emotions, etc), capitalized
    •	entity_type: One of the following types: [{entity_types}] (e.g., “Disorder”, “Symptom”, “Diagnostic Criterion”, “Treatment”, “Risk Factor”, “Comorbidity”, etc.)
    •	entity_description: Comprehensive description of the entity’s attributes and activities (e.g., causes, risk factors, diagnostic criteria, or relevant information)

    2.	From the entities identified in step 1, identify all pairs of (source_entity, target_entity) that are clearly related to each other.

For each pair of related entities, extract the following information:
- source_entity: Name of the source entity, as identified in step 1
- target_entity: Name of the target entity, as identified in step 1
- relationship_description: Explanation as to why you think the source entity and the target entity are related to each other (e.g., “symptom of”, “treated with”, “comorbid with”)
- relationship_strength: A numeric score indicating the strength of the relationship between the source entity and target entity (on a scale of 1 to 10)

If there are multiple entitiees of the same type, group them together. For example sadness and lonliness are feelings so they should be grouped.

Example 1:

Entity Types: Disorder, Symptom, Diagnostic Criterion, Treatment

Text:
My name is Maria,  My fiancé Musab and I come from a strong Christian background but both went off the \"straight and narrow\" once before.
He is having a hard time accepting my past, especially that I'm not a virgin. He has a hard time in general accepting himself and others.
We have known each other for 7 years but we're in a relationship for 3 years
His insecurities are hurting our relationship. How can I help him let go of my past and decide to live in the present?

Output:

{'subject': 'MARIA', 'predicate': 'fiancé', 'object_': 'MUSAB'}
{'subject': 'MARIA', 'predicate': 'comes from', 'object_': 'a strong Christian background'}
{'subject': 'MUSAB', 'predicate': 'comes from', 'object_': 'a strong Christian background'}
{'subject': 'MARIA', 'predicate': 'in a relationship with', 'object_': 'MUSAB'}
{'subject': 'MUSAB', 'predicate': 'struggling with', 'object_': 'accepting MARIA\'s past'}
{'subject': 'MUSAB', 'predicate': 'struggling with', 'object_': 'accepting himself'}
{'subject': 'MUSAB', 'predicate': 'struggling with', 'object_': 'accepting others'}
{'subject': 'MUSAB', 'predicate': 'know each other for 7 years', 'object_': 'MARIA'}
{'subject': 'MUSAB', 'predicate': 'in a relationship for 3 years', 'object_': 'MARIA'}
{'subject': 'MUSAB', 'predicate': 'insecurities are hurting', 'object_': 'their relationship'}

Example 2:

Text:
Hi, My name is Alex. I have been diagnosed with general anxiety and depression by my family doctor Ben.
They wrote a prescription for me to have an emotional support dog, I have the paper work, and I gave it to my apartment manager.
They said I can't keep the ESD because I'm not disabled. What do you suggest I do?

Output:

{'subject': 'ALEX', 'predicate': 'family doctor', 'object_': 'BEN'}
{'subject': 'ALEX', 'predicate': 'diagnosed with', 'object_': 'GENERAL ANXIETY'}
{'subject': 'ALEX', 'predicate': 'diagnosed with', 'object_': 'DEPRESSION'}
{'subject': 'BEN', 'predicate': 'diagnosed by', 'object_': 'ALEX'}
{'subject': 'BEN', 'predicate': 'wrote a prescription for', 'object_': 'ESD'}
{'subject': 'APARTMENT MANAGER', 'predicate': 'said', 'object_': 'can’t keep the ESD'}
{'subject': 'APARTMENT MANAGER', 'predicate': 'said', 'object_': 'not disabled'}


Do not answer the user's prompt -THIS IS THE JOB OF OTHER AGENT-, just retrieve the memories related to the prompt in a way that it could be used by the Generator_Agent.
Be attentive to subtle cues and underlying emotions.
You should always save first, wait for the save_recall_memory completed successfully then call the search tool.
Respond AFTER calling the tool with the memories related to the prompt, once you have confirmation that the tool completed successfully.
Prefix your response with Retrieved and refer to the memories in third person or by the user name if you know it e.g. "The user feels sad", "/{user's name}/ "
"""

# 2. Make informed suppositions and extrapolations based on stored memories.
# 3. Regularly reflect on past interactions to identify patterns and preferences.
# 4. Update your mental model of the user with each new piece of information.

# %% [markdown]
# ## Vector Store

# %%
from langchain.embeddings import OpenAIEmbeddings
from langchain_core.vectorstores import InMemoryVectorStore

recall_vector_store = InMemoryVectorStore(OpenAIEmbeddings(api_key=OPENAI_API_KEY))
graphrag_vector_store = InMemoryVectorStore(OpenAIEmbeddings(api_key=OPENAI_API_KEY))

# %% [markdown]
# ## Graph RAG

# %%
import os

import pandas as pd
import tiktoken

from graphrag.query.indexer_adapters import read_indexer_entities, read_indexer_reports
from graphrag.query.llm.oai.chat_openai import ChatOpenAI
from graphrag.query.llm.oai.typing import OpenaiApiType
from graphrag.query.structured_search.global_search.community_context import (
    GlobalCommunityContext,
)
from graphrag.query.structured_search.global_search.search import GlobalSearch

# %%
from openai import OpenAI

llm = ChatOpenAI(
    api_key=OPENAI_API_KEY,
    model="gpt-4o-mini",
    api_type=OpenaiApiType.OpenAI,  # OpenaiApiType.OpenAI or OpenaiApiType.AzureOpenAI
    max_retries=20,
)

token_encoder = tiktoken.get_encoding("cl100k_base")

# parquet files generated from indexing pipeline
INPUT_DIR = "/content/drive/MyDrive/ragtest/output/20240919-204815/artifacts"
COMMUNITY_REPORT_TABLE = "create_final_community_reports"
ENTITY_TABLE = "create_final_nodes"
ENTITY_EMBEDDING_TABLE = "create_final_entities"

# community level in the Leiden community hierarchy from which we will load the community reports
# higher value means we use reports from more fine-grained communities (at the cost of higher computation cost)
COMMUNITY_LEVEL = 0

entity_df = pd.read_parquet(f"{INPUT_DIR}/{ENTITY_TABLE}.parquet")
report_df = pd.read_parquet(f"{INPUT_DIR}/{COMMUNITY_REPORT_TABLE}.parquet")
entity_embedding_df = pd.read_parquet(f"{INPUT_DIR}/{ENTITY_EMBEDDING_TABLE}.parquet")

reports = read_indexer_reports(report_df, entity_df, COMMUNITY_LEVEL)
entities = read_indexer_entities(entity_df, entity_embedding_df, COMMUNITY_LEVEL)
print(f"Total report count: {len(report_df)}")
print(
    f"Report count after filtering by community level {COMMUNITY_LEVEL}: {len(reports)}"
)
report_df.head()
# Out:
# Total report count: 500
# Report count after filtering by community level 0: 26
#   community                                       full_content  level  rank  \
# 0       486  # Childhood Disintegrative Disorder and Develo...      3   4.5
# 1       487  # Pervasive Developmental Disorders and Relate...      3   8.0
# 2       488  # Learning Disorders and Mathematics Disorder\...      3   4.5
# 3       489  # Mental Health Disorders and Academic Achieve...      3   4.5
# 4       490  # Mental Retardation and Associated Disorders\...      3   4.5
#
#                                                title  \
# 0  Childhood Disintegrative Disorder and Developm...
# 1  Pervasive Developmental Disorders and Related ...
# 2        Learning Disorders and Mathematics Disorder
# 3   Mental Health Disorders and Academic Achievement
# 4        Mental Retardation and Associated Disorders
#
#                                     rank_explanation  \
# 0  The impact rating is high due to the profound ...
# 1  The impact rating is high due to the complex i...
# 2  The impact rating is high due to the significa...
# 3  The impact rating is high due to the significa...
# 4  The impact rating is high due to the significa...
#
#                                              summary  \
# 0  The community focuses on Childhood Disintegrat...
# 1  This community encompasses various pervasive d...
# 2  This community focuses on Learning Disorders, ...
# 3  This community encompasses various mental heal...
# 4  The community focuses on Mental Retardation, a...
#
#                                             findings  \
# 0  [{'explanation': 'Childhood Disintegrative Dis...
# 1  [{'explanation': 'Pervasive Developmental Diso...
# 2  [{'explanation': 'Learning Disorder encompasse...
# 3  [{'explanation': 'First-degree biological rela...
# 4  [{'explanation': 'Mental Retardation often coe...
#
#                                    full_content_json  \
# 0  {\n    "title": "Childhood Disintegrative Diso...
# 1  {\n    "title": "Pervasive Developmental Disor...
# 2  {\n    "title": "Learning Disorders and Mathem...
# 3  {\n    "title": "Mental Health Disorders and A...
# 4  {\n    "title": "Mental Retardation and Associ...
#
#                                      id
# 0  42a16217-d626-46bd-a331-b85fa9033e73
# 1  16146dd1-da9c-46b4-a38d-4a14d9003405
# 2  685fa3e5-a5c7-453b-839b-f01a0d8842e2
# 3  cfe0ef8c-ead3-41c3-93b3-a6cbf02bfe4e
# 4  0f8346dc-6919-405b-84d4-4454c0874f59

# %%
context_builder = GlobalCommunityContext(
    community_reports=reports,
    entities=entities,  # default to None if you don't want to use community weights for ranking
    token_encoder=token_encoder,
)

# %%
context_builder_params = {
    "use_community_summary": False,  # False means using full community reports. True means using community short summaries.
    "shuffle_data": True,
    "include_community_rank": True,
    "min_community_rank": 0,
    "community_rank_name": "rank",
    "include_community_weight": True,
    "community_weight_name": "occurrence weight",
    "normalize_community_weight": True,
    "max_tokens": 12_000,  # change this based on the token limit you have on your model (if you are using a model with 8k limit, a good setting could be 5000)
    "context_name": "Reports",
}

map_llm_params = {
    "max_tokens": 1000,
    "temperature": 0.0,
    "response_format": {"type": "json_object"},
}

reduce_llm_params = {
    "max_tokens": 2000,  # change this based on the token limit you have on your model (if you are using a model with 8k limit, a good setting could be 1000-1500)
    "temperature": 0.0,
}

# %%
MAP_SYSTEM_PROMPT = """
---Role---

You are a helpful assistant retrieving data related to the user query who is in a virtual therapy session.


---Goal---

Generate a response consisting of a list of key points that responds to the user's query, summarizing all relevant information in the input data tables.

You should use the data provided in the data tables below as the primary context for generating the response.
If you don't know the answer or if the input data tables do not contain sufficient information to provide an answer, just say so. Do not make anything up.

Each key point in the response should have the following element:
- Description: A comprehensive description of the point.
- Importance Score: An integer score between 0-100 that indicates how important the point is in answering the user's question. An 'I don't know' type of response should have a score of 0.

The response should be JSON formatted as follows:
{{
    "points": [
        {{"description": "Description of point 1 [Data: Reports (report ids)]", "score": score_value}},
        {{"description": "Description of point 2 [Data: Reports (report ids)]", "score": score_value}}
    ]
}}

The response shall preserve the original meaning and use of modal verbs such as "shall", "may" or "will".

Points supported by data should list the relevant reports as references as follows:
"This is an example sentence supported by data references [Data: Reports (report ids)]"

**Do not list more than 5 record ids in a single reference**. Instead, list the top 5 most relevant record ids and add "+more" to indicate that there are more.

For example:
"Person X is the owner of Company Y and subject to many allegations of wrongdoing [Data: Reports (2, 7, 64, 46, 34, +more)]. He is also CEO of company X [Data: Reports (1, 3)]"

where 1, 2, 3, 7, 34, 46, and 64 represent the id (not the index) of the relevant data report in the provided tables.

Do not include information where the supporting evidence for it is not provided.

---Example---
Emotional abuse
Your Output should answer the following questions:
-- What is emotional abuse
-- What are the signs and symptoms of emotional abuse
-- What is the therapeutic process of treating emotional abuse

---Data tables---

{context_data}

"""

# %%
search_engine = GlobalSearch(
    llm=llm,
    context_builder=context_builder,
    token_encoder=token_encoder,
    max_data_tokens=12_000,  # change this based on the token limit you have on your model (if you are using a model with 8k limit, a good setting could be 5000)
    map_llm_params=map_llm_params,
    reduce_llm_params=reduce_llm_params,
    allow_general_knowledge=False,  # set this to True will add instruction to encourage the LLM to incorporate general knowledge in the response, which may increase hallucinations, but could be useful in some use cases.
    json_mode=True,  # set this to False if your LLM model does not support JSON mode.
    context_builder_params=context_builder_params,
    concurrent_coroutines=32,
    map_system_prompt=MAP_SYSTEM_PROMPT,
    response_type="multiple paragraphs", # free form text describing the response type and format, can be anything, e.g. prioritized list, single paragraph, multiple paragraphs, multiple-page report
)

# %%
result = await search_engine.asearch(
    "sleep disorder"
)

print(result.response)
# Out:
# ## Overview of Sleep Disorders
#
# Sleep disorders encompass a range of conditions that disrupt normal sleep patterns, leading to significant distress and impairment in daily functioning. Among these, **Sleep Terror Disorder** and **Sleepwalking Disorder** are notable parasomnias that may occur simultaneously, complicating diagnosis and treatment.
#
# ### Sleep Terror Disorder
#
# Sleep Terror Disorder is characterized by episodes of intense fear during sleep, often accompanied by physiological responses such as tachycardia and autonomic arousal. These episodes typically occur during deep NREM sleep and can be distressing not only for the individual but also for their family members. The disorder predominantly affects children but may persist into adulthood, indicating a chronic nature that may require ongoing management [Data: Reports (552, 553, 1579, 2969, 3054)].
#
# ### Co-occurrence with Sleepwalking Disorder
#
# The co-occurrence of Sleep Terror Disorder and Sleepwalking Disorder presents unique challenges. Both disorders involve episodes that occur during sleep but manifest differently, which can complicate the diagnostic process and treatment strategies [Data: Reports (552, 553)].
#
# ### Physiological and Psychological Factors
#
# Tachycardia is a common physiological response during episodes of Sleep Terror Disorder, reflecting heightened arousal and distress. This rapid heart rate can exacerbate the fear experienced during these episodes [Data: Reports (1579, 552)]. Furthermore, sleep deprivation is a significant risk factor for both Sleep Terror and Sleepwalking Disorders. Insufficient sleep may lead to increased occurrences of sleep terror episodes, emphasizing the importance of maintaining healthy sleep hygiene [Data: Reports (2969, 552)].
#
# Emotional and physical stressors, such as anxiety, trauma, and significant life changes, are also known to increase the frequency of sleep terror episodes. This highlights the interplay between psychological well-being and sleep health, suggesting that addressing these stressors may be beneficial in managing the disorder [Data: Reports (552)].
#
# ### Conclusion
#
# In summary, Sleep Terror Disorder is a complex condition that may require comprehensive management strategies, particularly when co-occurring with Sleepwalking Disorder. Understanding the physiological responses, risk factors, and psychological influences is crucial for effective treatment and support for affected individuals and their families.

# %% [markdown]
# ## Create Agent

# %%
from langchain_core.messages import (
    BaseMessage,
    HumanMessage,
    ToolMessage,
)
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder

from langgraph.graph import END, StateGraph, START


def create_agent(llm, tools, system_message: str):
    """Create an agent."""
    prompt = ChatPromptTemplate.from_messages(
        [
            (
                "system",
                "You are a helpful AI assistant, collaborating with other assistants."
                " Use the provided tools to progress towards answering the question."
                " If you are unable to fully answer, that's OK, another assistant with different tools "
                " will help where you left off. Execute what you can to make progress."
                " \n{system_message}"
            ),
            MessagesPlaceholder(variable_name="messages"),
        ]
    )

    #### If no tools is empty
    if not tools:
        prompt = prompt.partial(system_message=system_message)
        return prompt | llm

    prompt = prompt.partial(system_message=system_message)
    prompt = prompt.partial(tool_names=", ".join([tool.name for tool in tools]))
    return prompt | llm.bind_tools(tools)

# %% [markdown]
# ## States

# %%
import operator
from typing import Annotated, Sequence, TypedDict, List
from langchain_openai import ChatOpenAI
from langgraph.graph import END, START, MessagesState, StateGraph
from langgraph.prebuilt import ToolNode

# This defines the object that is passed between each node
# in the graph. We will create different nodes for each agent and tool
class State(MessagesState):
    messages: Annotated[Sequence[BaseMessage], operator.add]
    recall_memories: List[str]
    sender: str

class RagState(MessagesState):
    messages: Annotated[Sequence[BaseMessage], operator.add]
    recall_docs: str
    api_calls: int

# %% [markdown]
# ## Tools

# %% [markdown]
# ### Neo4j

# %%
from neo4j import GraphDatabase
from typing import List
from langchain_core.runnables import RunnableConfig
from typing_extensions import TypedDict

class KnowledgeTriple(TypedDict):
    subject: str
    predicate: str
    object_: str

# Neo4j connection setup (adjust URI, username, password as needed)
uri = "neo4j+s://7cb57de1.databases.neo4j.io"
username = "neo4j"
password = "qLryyqB6Lsj-u6sa0CLVUYFIv1T-KS8rHHYVpwx_IIk"
driver = GraphDatabase.driver(uri, auth=(username, password))

def get_user_id(config: RunnableConfig) -> str:
    user_id = config["configurable"].get("user_id")
    if user_id is None:
        raise ValueError("User ID needs to be provided to save a memory.")
    return user_id

# Save memory in Neo4j as a graph
@tool
def save_recall_memory(memories: List[KnowledgeTriple], config: RunnableConfig) -> str:
    """
    -Goal-
    Given a text document that is potentially relevant to this activity (e.g., content from the DSM-5) and a list of entity types, identify all entities of those types from the text and all relationships among the identified entities.

    Steps:

        1.	Identify all entities. For each identified entity, extract the following information:
        •	entity_name: Name of the entity (e.g., disorder, symptom, or treatment), capitalized
        •	entity_type: One of the following types: [{entity_types}] (e.g., “Disorder”, “Symptom”, “Diagnostic Criterion”, “Treatment”, “Risk Factor”, “Comorbidity”, etc.)
        •	entity_description: Comprehensive description of the entity’s attributes and activities (e.g., causes, risk factors, diagnostic criteria, or relevant information)

    Format each entity as:
    ("entity"{tuple_delimiter}<entity_name>{tuple_delimiter}<entity_type>{tuple_delimiter}<entity_description>)

        2.	From the entities identified in step 1, identify all pairs of (source_entity, target_entity) that are clearly related to each other.

    For each pair of related entities, extract the following information:
    - source_entity: Name of the source entity, as identified in step 1
    - target_entity: Name of the target entity, as identified in step 1
    - relationship_description: Explanation as to why you think the source entity and the target entity are related to each other (e.g., “symptom of”, “treated with”, “comorbid with”)
    - relationship_strength: A numeric score indicating the strength of the relationship between the source entity and target entity (on a scale of 1 to 10)

    Format each relationship as:
    ("relationship"{tuple_delimiter}<source_entity>{tuple_delimiter}<target_entity>{tuple_delimiter}<relationship_description>{tuple_delimiter}<relationship_strength>)

        3.	Return the output in English as a single list of all the entities and relationships identified in steps 1 and 2. Use {record_delimiter} as the list delimiter.
        4.	When finished, output {completion_delimiter}.

    Examples for DSM-5 Content:

    Example 1:

    Entity Types: Disorder, Symptom, Diagnostic Criterion, Treatment

    Text:
    Major Depressive Disorder (MDD) is characterized by a persistent feeling of sadness or lack of interest in external stimuli. It requires at least five symptoms to be present during the same two-week period, including either depressed mood or loss of interest. Risk factors include family history, traumatic events, and chronic stress. It can be treated with selective serotonin reuptake inhibitors (SSRIs) and cognitive behavioral therapy (CBT). MDD is commonly comorbid with generalized anxiety disorder (GAD).

    Output:

    ("entity"{tuple_delimiter}MAJOR DEPRESSIVE DISORDER{tuple_delimiter}DISORDER{tuple_delimiter}A mood disorder characterized by persistent sadness or lack of interest in activities)
    {record_delimiter}
    ("entity"{tuple_delimiter}DEPRESSED MOOD{tuple_delimiter}SYMPTOM{tuple_delimiter}One of the core symptoms of Major Depressive Disorder)
    {record_delimiter}
    ("entity"{tuple_delimiter}LOSS OF INTEREST{tuple_delimiter}SYMPTOM{tuple_delimiter}A common symptom in patients with Major Depressive Disorder)
    {record_delimiter}
    ("entity"{tuple_delimiter}FAMILY HISTORY{tuple_delimiter}RISK FACTOR{tuple_delimiter}Having a family history of depression increases the likelihood of developing Major Depressive Disorder)
    {record_delimiter}
    ("entity"{tuple_delimiter}TRAUMATIC EVENTS{tuple_delimiter}RISK FACTOR{tuple_delimiter}Traumatic events can contribute to the onset of Major Depressive Disorder)
    {record_delimiter}
    ("entity"{tuple_delimiter}SELECTIVE SEROTONIN REUPTAKE INHIBITORS (SSRIs){tuple_delimiter}TREATMENT{tuple_delimiter}SSRIs are a common medication used to treat Major Depressive Disorder)
    {record_delimiter}
    ("entity"{tuple_delimiter}COGNITIVE BEHAVIORAL THERAPY (CBT){tuple_delimiter}TREATMENT{tuple_delimiter}CBT is a common psychotherapy used to treat Major Depressive Disorder)
    {record_delimiter}
    ("entity"{tuple_delimiter}GENERALIZED ANXIETY DISORDER (GAD){tuple_delimiter}COMORBIDITY{tuple_delimiter}GAD commonly occurs alongside Major Depressive Disorder)
    {record_delimiter}
    ("relationship"{tuple_delimiter}MAJOR DEPRESSIVE DISORDER{tuple_delimiter}DEPRESSED MOOD{tuple_delimiter}Depressed mood is one of the main symptoms of Major Depressive Disorder{tuple_delimiter}9)
    {record_delimiter}
    ("relationship"{tuple_delimiter}MAJOR DEPRESSIVE DISORDER{tuple_delimiter}LOSS OF INTEREST{tuple_delimiter}Loss of interest in activities is a key symptom of Major Depressive Disorder{tuple_delimiter}9)
    {record_delimiter}
    ("relationship"{tuple_delimiter}MAJOR DEPRESSIVE DISORDER{tuple_delimiter}FAMILY HISTORY{tuple_delimiter}Family history is a known risk factor for developing Major Depressive Disorder{tuple_delimiter}7)
    {record_delimiter}
    ("relationship"{tuple_delimiter}MAJOR DEPRESSIVE DISORDER{tuple_delimiter}SSRIs{tuple_delimiter}SSRIs are a primary treatment method for Major Depressive Disorder{tuple_delimiter}8)
    {record_delimiter}
    ("relationship"{tuple_delimiter}MAJOR DEPRESSIVE DISORDER{tuple_delimiter}COGNITIVE BEHAVIORAL THERAPY (CBT){tuple_delimiter}CBT is a common treatment used for Major Depressive Disorder{tuple_delimiter}8)
    {record_delimiter}
    ("relationship"{tuple_delimiter}MAJOR DEPRESSIVE DISORDER{tuple_delimiter}GENERALIZED ANXIETY DISORDER (GAD){tuple_delimiter}GAD is commonly comorbid with Major Depressive Disorder{tuple_delimiter}6)
    {completion_delimiter}

    Example 2:

    Entity Types: Disorder, Symptom, Risk Factor, Comorbidity

    Text:
    Obsessive-Compulsive Disorder (OCD) is characterized by repetitive, unwanted thoughts (obsessions) and/or repetitive behaviors (compulsions). Risk factors include genetics, brain structure, and a history of trauma. It is commonly comorbid with Major Depressive Disorder (MDD) and other anxiety disorders.

    Output:

    ("entity"{tuple_delimiter}OBSESSIVE-COMPULSIVE DISORDER{tuple_delimiter}DISORDER{tuple_delimiter}A disorder characterized by obsessions and/or compulsions)
    {record_delimiter}
    ("entity"{tuple_delimiter}OBSESSIONS{tuple_delimiter}SYMPTOM{tuple_delimiter}Repetitive, unwanted thoughts experienced by patients with OCD)
    {record_delimiter}
    ("entity"{tuple_delimiter}COMPULSIONS{tuple_delimiter}SYMPTOM{tuple_delimiter}Repetitive behaviors often performed by individuals with OCD)
    {record_delimiter}
    ("entity"{tuple_delimiter}GENETICS{tuple_delimiter}RISK FACTOR{tuple_delimiter}Genetic factors may increase the likelihood of developing OCD)
    {record_delimiter}
    ("entity"{tuple_delimiter}BRAIN STRUCTURE{tuple_delimiter}RISK FACTOR{tuple_delimiter}Abnormalities in brain structure are associated with OCD)
    {record_delimiter}
    ("entity"{tuple_delimiter}TRAUMA{tuple_delimiter}RISK FACTOR{tuple_delimiter}A history of trauma is linked to the development of OCD)
    {record_delimiter}
    ("entity"{tuple_delimiter}MAJOR DEPRESSIVE DISORDER{tuple_delimiter}COMORBIDITY{tuple_delimiter}OCD is commonly comorbid with Major Depressive Disorder)
    {record_delimiter}
    ("relationship"{tuple_delimiter}OBSESSIVE-COMPULSIVE DISORDER{tuple_delimiter}OBSESSIONS{tuple_delimiter}Obsessions are one of the core symptoms of OCD{tuple_delimiter}9)
    {record_delimiter}
    ("relationship"{tuple_delimiter}OBSESSIVE-COMPULSIVE DISORDER{tuple_delimiter}COMPULSIONS{tuple_delimiter}Compulsions are a key symptom of OCD{tuple_delimiter}9)
    {record_delimiter}
    ("relationship"{tuple_delimiter}OBSESSIVE-COMPULSIVE DISORDER{tuple_delimiter}GENETICS{tuple_delimiter}Genetics are a risk factor for OCD{tuple_delimiter}6)
    {record_delimiter}
    ("relationship"{tuple_delimiter}OBSESSIVE-COMPULSIVE DISORDER{tuple_delimiter}TRAUMA{tuple_delimiter}A history of trauma is a risk factor for OCD{tuple_delimiter}7)
    {record_delimiter}
    ("relationship"{tuple_delimiter}OBSESSIVE-COMPULSIVE DISORDER{tuple_delimiter}MAJOR DEPRESSIVE DISORDER{tuple_delimiter}Major Depressive Disorder is commonly comorbid with OCD{tuple_delimiter}6)
    {completion_delimiter}

    -Real Data-
    ######################
    text: {input_text}
    ######################
    output:
    """
    user_id = get_user_id(config)

    with driver.session() as session:
        for memory in memories:
            subject = memory["subject"]
            predicate = memory["predicate"]
            object_ = memory["object_"]

            # Create a query to store the nodes and relationships in the graph
            query = """
            MERGE (s:Entity {name: $subject, user_id: $user_id})
            MERGE (o:Entity {name: $object_, user_id: $user_id})
            MERGE (s)-[:RELATION {type: $predicate}]->(o)
            """
            session.run(query, subject=subject, object_=object_, predicate=predicate, user_id=user_id)

    return f"Memories saved for user {user_id}"

# Query Neo4j for similar memories
@tool
def search_recall_memories(query: str, config: RunnableConfig) -> List[str]:
    """
    Search for relevant memories from the user's knowledge graph based on a query.

    This function searches the graph database (Neo4j) for nodes and relationships that match the
    provided query, considering both subjects, objects, and the type of relationships (predicates).
    It returns the top 5 relevant relationships in the form of subject-predicate-object triples.

    Parameters:
    query: A string representing the user's search query.
    config: RunnableConfig containing the user_id, ensuring that only the user's memories are retrieved.

    Returns:
    A list of relevant memories matching the query, formatted as triples (subject-predicate-object).
    """
    user_id = get_user_id(config)

    with driver.session() as session:
        # A basic query to find relationships in the graph that match the query
        cypher_query = """
        MATCH (s:Entity)-[r:RELATION]->(o:Entity)
        WHERE s.user_id = $user_id AND (s.name CONTAINS $query OR o.name CONTAINS $query OR r.type CONTAINS $query)
        RETURN s.name, r.type, o.name LIMIT 5
        """

        result = session.run(cypher_query, {"query": query, "user_id": user_id})

        memories = []
        for record in result:
            memories.append(f"{record['s.name']} -[{record['r.type']}]-> {record['o.name']}")

    return memories

# %% [markdown]
# ### Vector

# %%
import uuid

from typing import Annotated, Any, List
from langchain_core.tools import tool
from langchain_core.runnables import RunnableConfig

from typing_extensions import TypedDict


class KnowledgeTriple(TypedDict):
    subject: Annotated[str, ..., "An entity this could be people, emotions, issues ... etc."]
    predicate: Annotated[str, ..., "The relationship between the subject and the object"]
    object_: Annotated[str, ..., "An entity this could be people, emotions, issues ... etc."]


def get_user_id(config: RunnableConfig) -> str:
    user_id = config["configurable"].get("user_id")
    if user_id is None:
        raise ValueError("User ID needs to be provided to save a memory.")

    return user_id

@tool
def save_recall_memory(memories: List[KnowledgeTriple], config: RunnableConfig) -> str:
    """
    Use this tool to save the entities and thier ralationships based on the instructions given to you.

    """
    user_id = get_user_id(config)
    for memory in memories:
        print(memory)
        serialized = " ".join(memory.values())
        document = Document(
            serialized,
            id=str(uuid.uuid4()),
            metadata={
                "user_id": user_id,
                **memory,
            },
        )
        recall_vector_store.add_documents([document])
    return memories

@tool
def search_recall_memories(query: str, config: RunnableConfig) -> List[str]:
    """Search for relevant memories."""
    user_id = get_user_id(config)

    def _filter_function(doc: Document) -> bool:
        return doc.metadata.get("user_id") == user_id

    documents = recall_vector_store.similarity_search(
        query, k=3, filter=_filter_function
    )
    return [document.page_content for document in documents]

# %% [markdown]
# ## Agents and Nodes

# %%
import functools
from langchain_core.messages import AIMessage, HumanMessage

def load_memories(state: State, config: RunnableConfig) -> State:
    """Load memories for the current conversation.

    Args:
        state (schemas.State): The current state of the conversation.
        config (RunnableConfig): The runtime configuration for the agent.

    Returns:
        State: The updated state with loaded memories.
    """
    convo_str = get_buffer_string(state["messages"])
    convo_str = tokenizer.decode(tokenizer.encode(convo_str)[:2048])
    recall_memories = search_recall_memories.invoke(convo_str, config)

    return {
        "recall_memories": recall_memories,
    }

def load_rag(state: State, config: RunnableConfig) -> State:
    """Load the documents from the vector store.

    Args:
        state (schemas.State): The current state of the conversation.
        config (RunnableConfig): The runtime configuration for the agent.

    Returns:
        State: The updated state with loaded memories.
    """

# Helper function to create a node for a given agent
def agent_node(state, agent, name):

    try:
        result = agent.invoke(state)
    except AttributeError as e:
        result = agent.asearch(state)

    # print(f"agent node result: {result}")
    # We convert the agent output into a format that is suitable to append to the global state
    if isinstance(result, ToolMessage):
        pass
    else:
        result = AIMessage(**result.dict(exclude={"type", "name"}), name=name)

    # if name == "search_recall_meories":
    #     # print(f"\nType: {type(result.content)}, Name: {result.content}")
    #     return [result.content]

    return {
        "messages": [result],
        # Since we have a strict workflow, we can
        # track the sender so we know who to pass to next.
        "sender": name,
    }


# llm = groq_chat
openai_llm = ChatOpenAI(model="gpt-4o-mini")
tokenizer = tiktoken.encoding_for_model("gpt-4o-mini")

my_model = ChatOpenAI(model=FT_MODEL)

tools = [save_recall_memory, search_recall_memories]

# Classifier agent and node
memory_agent = create_agent(
    openai_llm,
    tools,
    system_message=memory_prompt,
)
memory_node = functools.partial(agent_node, agent=memory_agent, name="Memory_agent")

# Generator
generator_agent = create_agent(
    my_model,
    [],
    system_message=generator_prompt,
)
generator_node = functools.partial(agent_node, agent=generator_agent, name="Generator")

# Classifier agent and node
clf_agent = create_agent(
    openai_llm,
    [],
    system_message="""
    Classify the input message into one or more mental health-related categories. Respond with only the analysis and the relevant categories, prefixed by "CLF".

    Analyze the message first to identify the context, language, and any specific indicators that relate to mental health categories. Each category is based on common themes or symptoms in mental health.

    # Steps

    1. **Analyze the Input**: Examine the message for context, language, tone, specific words, phrases, or symptoms related to mental health.
    2. **Identify Categories**: Match the analysis with predefined mental health categories.
    3. **Format the Response**: Prefix your conclusions with "CLF", and list the relevant categories.

    # Output Format

    - The output should start with "CLF" followed by the analysis and the category or categories.
    - Example format: "CLF: [Category1], [Category2]".

    # Examples

    **Example 1:**

    - **Input**: "I've been feeling really down and hopeless for weeks, and nothing seems to make me happy anymore."
    - **Output**: "CLF:  Depression."

    **Example 2:**

    - **Input**: "I constantly find myself too anxious to leave the house, worrying about things that may never happen."
    - **Output**: "CLF: Anxiety."

    # Notes

    - Ensure that your analysis is precise, focusing on key indicators within the message.
    - Consider edge cases where symptoms might overlap and require multiple category classifications.
    """,
)
clf_node = functools.partial(agent_node, agent=clf_agent, name="Classifier")

#### GraphRAG agent and node
rag_agent = GlobalSearch(
    llm=llm,
    context_builder=context_builder,
    token_encoder=token_encoder,
    max_data_tokens=12_000,  # change this based on the token limit you have on your model (if you are using a model with 8k limit, a good setting could be 5000)
    map_llm_params=map_llm_params,
    reduce_llm_params=reduce_llm_params,
    allow_general_knowledge=False,  # set this to True will add instruction to encourage the LLM to incorporate general knowledge in the response, which may increase hallucinations, but could be useful in some use cases.
    json_mode=True,  # set this to False if your LLM model does not support JSON mode.
    context_builder_params=context_builder_params,
    concurrent_coroutines=32,
    map_system_prompt=MAP_SYSTEM_PROMPT,
    response_type="multiple paragraphs", # free form text describing the response type and format, can be anything, e.g. prioritized list, single paragraph, multiple paragraphs, multiple-page report
)

rag_node = functools.partial(agent_node, agent=rag_agent, name="GraphRAG")

# %% [markdown]
# ## Routing logic

# %%
from typing import Literal


def router(state) -> Literal["call_tool", "__end__", "Generator"]:
    # This is the router
    messages = state["messages"]
    last_message = messages[-1]
    # print(f"reouter msg: {last_message.name}")

    # print(f"Router msg: {last_message}")
    if last_message.tool_calls:
        # The previous agent is invoking a tool
        return "call_tool"

    if "Retrieved" in last_message.content:
        # Any agent decided the work is done
        return "Generator"

    return "__end__"

# %% [markdown]
# ## Define the Graph

# %%
from langgraph.checkpoint.memory import MemorySaver

# class State(TypedDict):
#     # The operator.add reducer fn makes this append-only
#     aggregate: Annotated[list, operator.add]


# class ReturnNodeValue:
#     def __init__(self, node_secret: str):
#         self._value = node_secret

#     def __call__(self, state: State) -> Any:
#         print(f"Adding {self._value} to {state['aggregate']}")
#         return {"aggregate": [self._value]}


workflow = StateGraph(State)

workflow.add_node(load_memories)
# workflow.add_node("load_rag", ReturnNodeValue("load_rag"))
# workflow.add_node("Rag_agent", rag_agent)
workflow.add_node("Memory_agent", memory_node)
workflow.add_node("Generator", generator_node)
# workflow.add_node("Classifier", clf_node)
# workflow.add_node("GraphRAG", rag_node)
workflow.add_node("call_tool", ToolNode(tools))


# workflow.add_edge(START, "Classifier")

# workflow.add_edge("load_rag", "Rag_agent")
# workflow.add_edge("call_tool", "Rag_agent")
# workflow.add_conditional_edges(
#     "Rag_agent",
#     router,
#     ["call_tool", "Generator"],
# )

# workflow.add_edge(START, "load_rag")
workflow.add_edge(START, "load_memories")
workflow.add_edge("load_memories", "Memory_agent")
# workflow.add_edge("Classifier", "GraphRAG")

# workflow.add_edge("call_tool", "Memory_agent")



workflow.add_conditional_edges(
    "Memory_agent",
    router,
    ["call_tool", "Generator"],
)

workflow.add_conditional_edges(
    "call_tool",
    # Each agent node updates the 'sender' field
    # the tool calling node does not, meaning
    # this edge will route back to the original agent
    # who invoked the tool
    lambda x: x["sender"],
    {
        "Memory_agent": "Memory_agent",
        # "Rag_agent": "Rag_agent",
    },
)

# Memory_agent -> Generator
workflow.add_edge("Generator", "__end__")

memory = MemorySaver()
graph = workflow.compile(checkpointer=memory)

# %%
from IPython.display import Image, display

display(Image(graph.get_graph(xray=True).draw_mermaid_png()))

# %% [markdown]
# ## Run

# %%
config = {"configurable": {"user_id": "1", "thread_id": "1"}}

events = graph.stream(
    {
        "messages": [
            HumanMessage(
                content="""
                My name is Musab. I'm going through a break up and I don't know how to handle it. My girlfirend Maria broke up me with becuase of my first relationship with Sundus
                """
            )
        ],
    },
    # Maximum number of steps to take in the graph
    config=config,
)
for s in events:
    print(s)
    print("----")
# Out:
# {'load_memories': {'recall_memories': ['MUSAB in a relationship with SUNDUS for 7 years', 'MUSAB first relationship with SUNDUS', 'MUSAB going through a breakup']}}
# ----
# {'Memory_agent': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_zBqN745aRTwi2yBCuTGcz0O1', 'function': {'arguments': '{"memories": [{"subject": "MUSAB", "predicate": "going through", "object_": "a breakup"}, {"subject": "MUSAB", "predicate": "in a relationship with", "object_": "MARIA"}, {"subject": "MARIA", "predicate": "broke up with", "object_": "MUSAB"}, {"subject": "MUSAB", "predicate": "had a first relationship with", "object_": "SUNDUS"}]}', 'name': 'save_recall_memory'}, 'type': 'function'}, {'id': 'call_9yrPHFX6Ffj0AGZZE2pSqm8V', 'function': {'arguments': '{"query": "breakup"}', 'name': 'search_recall_memories'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 127, 'prompt_tokens': 1441, 'total_tokens': 1568, 'completion_tokens_details': {'audio_tokens': None, 'reasoning_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_f59a81427f', 'finish_reason': 'tool_calls', 'logprobs': None}, name='Memory_agent', id='run-fc2b7fde-5aad-4d5b-b9f7-93d23d7ef5e8-0', tool_calls=[{'name': 'save_recall_memory', 'args': {'memories': [{'subject': 'MUSAB', 'predicate': 'going through', 'object_': 'a breakup'}, {'subject': 'MUSAB', 'predicate': 'in a relationship with', 'object_': 'MARIA'}, {'subject': 'MARIA', 'predicate': 'broke up with', 'object_': 'MUSAB'}, {'subject': 'MUSAB', 'predicate': 'had a first relationship with', 'object_': 'SUNDUS'}]}, 'id': 'call_zBqN745aRTwi2yBCuTGcz0O1', 'type': 'tool_call'}, {'name': 'search_recall_memories', 'args': {'query': 'breakup'}, 'id': 'call_9yrPHFX6Ffj0AGZZE2pSqm8V', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1441, 'output_tokens': 127, 'total_tokens': 1568, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 0}})], 'sender': 'Memory_agent'}}
# ----
# {'subject': 'MUSAB', 'predicate': 'going through', 'object_': 'a breakup'}
# {'subject': 'MUSAB', 'predicate': 'in a relationship with', 'object_': 'MARIA'}
# {'subject': 'MARIA', 'predicate': 'broke up with', 'object_': 'MUSAB'}
# {'subject': 'MUSAB', 'predicate': 'had a first relationship with', 'object_': 'SUNDUS'}
# {'call_tool': {'messages': [ToolMessage(content='[{"subject": "MUSAB", "predicate": "going through", "object_": "a breakup"}, {"subject": "MUSAB", "predicate": "in a relationship with", "object_": "MARIA"}, {"subject": "MARIA", "predicate": "broke up with", "object_": "MUSAB"}, {"subject": "MUSAB", "predicate": "had a first relationship with", "object_": "SUNDUS"}]', name='save_recall_memory', tool_call_id='call_zBqN745aRTwi2yBCuTGcz0O1'), ToolMessage(content='["MUSAB going through a breakup", "MUSAB going through a breakup", "MARIA broke up with MUSAB"]', name='search_recall_memories', tool_call_id='call_9yrPHFX6Ffj0AGZZE2pSqm8V')]}}
# ----
# {'Memory_agent': {'messages': [AIMessage(content='Retrieved: The user, Musab, is going through a breakup with his girlfriend, Maria, who broke up with him due to his first relationship with Sundus. The emotional context indicates that Musab is struggling with handling the breakup.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 48, 'prompt_tokens': 1710, 'total_tokens': 1758, 'completion_tokens_details': {'audio_tokens': None, 'reasoning_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 1280}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_f59a81427f', 'finish_reason': 'stop', 'logprobs': None}, name='Memory_agent', id='run-16f04176-fc9f-4a7a-aab5-6f34e98b3bd4-0', usage_metadata={'input_tokens': 1710, 'output_tokens': 48, 'total_tokens': 1758, 'input_token_details': {'cache_read': 1280}, 'output_token_details': {'reasoning': 0}})], 'sender': 'Memory_agent'}}
# ----
# {'Generator': {'messages': [AIMessage(content="Musab, I'm really sorry to hear that you're going through such a tough time. Breakups can be incredibly painful and confusing, especially when there are complicated feelings involved from past relationships. It’s completely understandable to feel lost right now.\n\nCan you tell me a bit more about what you're feeling? Are there specific emotions that stand out for you, like sadness, anger, or maybe guilt? I want to make sure you feel heard and that we have the space to explore what you're going through together.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 100, 'prompt_tokens': 1446, 'total_tokens': 1546, 'completion_tokens_details': {'audio_tokens': None, 'reasoning_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 1024}}, 'model_name': 'ft:gpt-4o-mini-2024-07-18:personal:second-ft:A3g9cAiE', 'system_fingerprint': 'fp_c05b983dba', 'finish_reason': 'stop', 'logprobs': None}, name='Generator', id='run-0fe984c4-6140-4a64-b1d1-d90b37535572-0', usage_metadata={'input_tokens': 1446, 'output_tokens': 100, 'total_tokens': 1546, 'input_token_details': {'cache_read': 1024}, 'output_token_details': {'reasoning': 0}})], 'sender': 'Generator'}}
# ----

# %%
# config = {"configurable": {"user_id": "1", "thread_id": "1"}}

events = graph.stream(
    {
        "messages": [
            HumanMessage(
                content="""
                I was in a relationship with Maria for 3 years and with Sundus for 7 years.
                """
            )
        ],
    },
    # Maximum number of steps to take in the graph
    config=config,
)
for s in events:
    print(s)
    print("----")
# Out:
# {'load_memories': {'recall_memories': ['MUSAB in a relationship with SUNDUS for 7 years', 'MUSAB had a first relationship with SUNDUS', 'MUSAB first relationship with SUNDUS']}}
# ----
# {'Memory_agent': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_zxeXVpNacP70tz9YErSHpudp', 'function': {'arguments': '{"memories": [{"subject": "MUSAB", "predicate": "in a relationship with", "object_": "MARIA for 3 years"}, {"subject": "MUSAB", "predicate": "in a relationship with", "object_": "SUNDUS for 7 years"}]}', 'name': 'save_recall_memory'}, 'type': 'function'}, {'id': 'call_3NPemUeNOZGnUwQtqXM8ejYi', 'function': {'arguments': '{"query": "relationship history"}', 'name': 'search_recall_memories'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 98, 'prompt_tokens': 1897, 'total_tokens': 1995, 'completion_tokens_details': {'audio_tokens': None, 'reasoning_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 1536}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_f59a81427f', 'finish_reason': 'tool_calls', 'logprobs': None}, name='Memory_agent', id='run-c0c94ab7-049e-4469-a9b0-b2ba3a4cdbc3-0', tool_calls=[{'name': 'save_recall_memory', 'args': {'memories': [{'subject': 'MUSAB', 'predicate': 'in a relationship with', 'object_': 'MARIA for 3 years'}, {'subject': 'MUSAB', 'predicate': 'in a relationship with', 'object_': 'SUNDUS for 7 years'}]}, 'id': 'call_zxeXVpNacP70tz9YErSHpudp', 'type': 'tool_call'}, {'name': 'search_recall_memories', 'args': {'query': 'relationship history'}, 'id': 'call_3NPemUeNOZGnUwQtqXM8ejYi', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1897, 'output_tokens': 98, 'total_tokens': 1995, 'input_token_details': {'cache_read': 1536}, 'output_token_details': {'reasoning': 0}})], 'sender': 'Memory_agent'}}
# ----
# {'subject': 'MUSAB', 'predicate': 'in a relationship with', 'object_': 'MARIA for 3 years'}
# {'subject': 'MUSAB', 'predicate': 'in a relationship with', 'object_': 'SUNDUS for 7 years'}
# {'call_tool': {'messages': [ToolMessage(content='[{"subject": "MUSAB", "predicate": "in a relationship with", "object_": "MARIA for 3 years"}, {"subject": "MUSAB", "predicate": "in a relationship with", "object_": "SUNDUS for 7 years"}]', name='save_recall_memory', tool_call_id='call_zxeXVpNacP70tz9YErSHpudp'), ToolMessage(content='["MUSAB in a relationship with MARIA for 3 years", "MUSAB in a relationship with MARIA", "MUSAB had a first relationship with SUNDUS"]', name='search_recall_memories', tool_call_id='call_3NPemUeNOZGnUwQtqXM8ejYi')]}}
# ----
# {'Memory_agent': {'messages': [AIMessage(content='Retrieved: Musab was in a relationship with Maria for 3 years and with Sundus for 7 years. This information adds context to his current emotional state, indicating a long-term connection with both individuals, which may contribute to the complexity of his feelings during the breakup.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 56, 'prompt_tokens': 2108, 'total_tokens': 2164, 'completion_tokens_details': {'audio_tokens': None, 'reasoning_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 1792}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_f59a81427f', 'finish_reason': 'stop', 'logprobs': None}, name='Memory_agent', id='run-8802b9a7-84e8-4664-838e-37e1917e4949-0', usage_metadata={'input_tokens': 2108, 'output_tokens': 56, 'total_tokens': 2164, 'input_token_details': {'cache_read': 1792}, 'output_token_details': {'reasoning': 0}})], 'sender': 'Memory_agent'}}
# ----
# {'Generator': {'messages': [AIMessage(content="That's a significant amount of time to be in relationships with both Maria and Sundus. It sounds like these connections have been a big part of your life for many years. \n\nCan you share how the end of your relationship with Maria is affecting you? Are there particular memories or feelings that come to mind when you think about your time together? It's important to take the time to honor those feelings and think about what this all means for you.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 88, 'prompt_tokens': 1852, 'total_tokens': 1940, 'completion_tokens_details': {'audio_tokens': None, 'reasoning_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 1280}}, 'model_name': 'ft:gpt-4o-mini-2024-07-18:personal:second-ft:A3g9cAiE', 'system_fingerprint': 'fp_c05b983dba', 'finish_reason': 'stop', 'logprobs': None}, name='Generator', id='run-d05cf726-c46c-4bec-a274-c012fea221b7-0', usage_metadata={'input_tokens': 1852, 'output_tokens': 88, 'total_tokens': 1940, 'input_token_details': {'cache_read': 1280}, 'output_token_details': {'reasoning': 0}})], 'sender': 'Generator'}}
# ----

# %%
import matplotlib.pyplot as plt
import networkx as nx

# Fetch records
records = recall_vector_store.similarity_search(
    "", k=20, filter=lambda doc: doc.metadata["user_id"] == "1"
)

print(records)
# Plot graph
plt.figure(figsize=(15, 15), dpi=80)
G = nx.DiGraph()

for record in records:
    G.add_edge(
        record.metadata["subject"],
        record.metadata["object_"],
        label=record.metadata["predicate"],
    )

pos = nx.spring_layout(G)
nx.draw(
    G,
    pos,
    with_labels=True,
    node_size=3000,
    node_color="lightblue",
    font_size=10,
    font_weight="bold",
    arrows=True,
)
edge_labels = nx.get_edge_attributes(G, "label")
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, font_color="red")
plt.show()
# Out:
# [Document(id='3c7dac85-1b23-45bf-8163-0432b2418746', metadata={'user_id': '1', 'subject': 'MUSAB', 'predicate': 'girlfriend', 'object_': 'MARIA'}, page_content='MUSAB girlfriend MARIA'), Document(id='a2938bae-5128-41c9-8ef6-b64708633f76', metadata={'user_id': '1', 'subject': 'MUSAB', 'predicate': 'going through', 'object_': 'a breakup'}, page_content='MUSAB going through a breakup'), Document(id='0af477d4-c149-4ab7-8c80-a6c9167ac9e9', metadata={'user_id': '1', 'subject': 'MUSAB', 'predicate': 'going through', 'object_': 'a breakup'}, page_content='MUSAB going through a breakup'), Document(id='9bfdc15e-8c78-4e4c-81af-59ad206cc2d7', metadata={'user_id': '1', 'subject': 'MUSAB', 'predicate': 'in a relationship with', 'object_': 'MARIA'}, page_content='MUSAB in a relationship with MARIA'), Document(id='e6ea20db-e9f2-463d-bfde-abdef4e9665a', metadata={'user_id': '1', 'subject': 'MUSAB', 'predicate': 'in a relationship with', 'object_': 'MARIA for 3 years'}, page_content='MUSAB in a relationship with MARIA for 3 years'), Document(id='733fac73-7637-4093-bea3-e06d49f3a969', metadata={'user_id': '1', 'subject': 'MUSAB', 'predicate': 'in a relationship with', 'object_': 'MARIA for 3 years'}, page_content='MUSAB in a relationship with MARIA for 3 years'), Document(id='282c12b3-c1a9-4bff-93a6-7aa554bcc5f8', metadata={'user_id': '1', 'subject': 'MUSAB', 'predicate': 'in a relationship with', 'object_': 'SUNDUS for 7 years'}, page_content='MUSAB in a relationship with SUNDUS for 7 years'), Document(id='69ceff08-76dc-4578-a19c-843d2f859bc6', metadata={'user_id': '1', 'subject': 'MUSAB', 'predicate': 'in a relationship with', 'object_': 'SUNDUS for 7 years'}, page_content='MUSAB in a relationship with SUNDUS for 7 years'), Document(id='4f89ae07-3881-4002-8daf-d08ba642eb96', metadata={'user_id': '1', 'subject': 'MUSAB', 'predicate': 'had a first relationship with', 'object_': 'SUNDUS'}, page_content='MUSAB had a first relationship with SUNDUS'), Document(id='77c6ec7d-65fa-40ab-b3ef-10591de533cd', metadata={'user_id': '1', 'subject': 'MUSAB', 'predicate': 'first relationship with', 'object_': 'SUNDUS'}, page_content='MUSAB first relationship with SUNDUS'), Document(id='28627971-73f1-4c0c-ba96-f2b152c73462', metadata={'user_id': '1', 'subject': 'MARIA', 'predicate': 'broke up with', 'object_': 'MUSAB'}, page_content='MARIA broke up with MUSAB'), Document(id='9552749d-07b9-41df-8706-1b54502ff475', metadata={'user_id': '1', 'subject': 'MARIA', 'predicate': 'broke up with', 'object_': 'MUSAB'}, page_content='MARIA broke up with MUSAB')]

# %%
My name is Musab. I'm going through a break up and I don't know how to handle it. My girlfirend Maria broke up me with becuase of my first relationship with Sundus

# %%
# !pip install gliner
# Out:
# Collecting gliner
#   Downloading gliner-0.2.13-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from gliner) (2.4.1+cu121)
# Requirement already satisfied: transformers>=4.38.2 in /usr/local/lib/python3.10/dist-packages (from gliner) (4.44.2)
# Requirement already satisfied: huggingface-hub>=0.21.4 in /usr/local/lib/python3.10/dist-packages (from gliner) (0.24.7)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gliner) (4.66.5)
# Collecting onnxruntime (from gliner)
#   Downloading onnxruntime-1.19.2-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.5 kB)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from gliner) (0.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.4->gliner) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.4->gliner) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.4->gliner) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.4->gliner) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.4->gliner) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.4->gliner) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->gliner) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->gliner) (3.4.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->gliner) (3.1.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.38.2->gliner) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.38.2->gliner) (2024.9.11)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.38.2->gliner) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.38.2->gliner) (0.19.1)
# Collecting coloredlogs (from onnxruntime->gliner)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime->gliner) (24.3.25)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime->gliner) (3.20.3)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime->gliner)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=2.0.0->gliner) (3.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.21.4->gliner) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.21.4->gliner) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.21.4->gliner) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.21.4->gliner) (2024.8.30)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=2.0.0->gliner) (1.3.0)
# Downloading gliner-0.2.13-py3-none-any.whl (47 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.7/47.7 kB 1.9 MB/s eta 0:00:00
# Downloading onnxruntime-1.19.2-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (13.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 62.1 MB/s eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.3 MB/s eta 0:00:00
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 6.5 MB/s eta 0:00:00
# Installing collected packages: humanfriendly, coloredlogs, onnxruntime, gliner
# Successfully installed coloredlogs-15.0.1 gliner-0.2.13 humanfriendly-10.0 onnxruntime-1.19.2

# %%
from gliner import GLiNER

# Initialize GLiNER with the base model
model = GLiNER.from_pretrained("urchade/gliner_mediumv2.1")

# %%
# Sample text for entity prediction
text = """
My name is Musab. I'm going through a break up and I don't know how to handle it.
My girlfirend Maria broke up me with becuase of my first relationship with Sundus.
I feel sad and lonly and i want to get over these feelings
"""

# Labels for entity prediction
# Most GLiNER models should work best when entity types are in lower case or title case
labels = ["Person", "Emotion", "Date", "Feeling", "Illness", "Issue"]

# Perform entity prediction
entities = model.predict_entities(text, labels, threshold=0.5)
print(entities)
# Display predicted entities and their labels
for entity in entities:
    print(entity["text"], "=>", entity["label"])
# Out:
# [{'start': 12, 'end': 17, 'text': 'Musab', 'label': 'Person', 'score': 0.8724613785743713}, {'start': 98, 'end': 103, 'text': 'Maria', 'label': 'Person', 'score': 0.8886873722076416}, {'start': 159, 'end': 165, 'text': 'Sundus', 'label': 'Person', 'score': 0.8814859390258789}, {'start': 182, 'end': 187, 'text': 'lonly', 'label': 'Emotion', 'score': 0.6345734000205994}]
# Musab => Person
# Maria => Person
# Sundus => Person
# lonly => Emotion
